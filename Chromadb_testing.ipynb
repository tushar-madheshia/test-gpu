# %%
# !pip install  sentence_transformers  unstructured -q
# Out:
# ERROR: torchaudio 2.0.2+cpu has requirement torch==2.0.1, but you'll have torch 2.1.1 which is incompatible.
# ERROR: refractml 1.0.3 has requirement PyYAML==6.0, but you'll have pyyaml 6.0.1 which is incompatible.
# ERROR: refractml 1.0.3 has requirement urllib3==1.26.15, but you'll have urllib3 2.1.0 which is incompatible.
# ERROR: mosaic-utils 1.0.2 has requirement scikit-learn==1.2.1; python_version >= "3.8", but you'll have scikit-learn 1.3.2 which is incompatible.
# ERROR: jupyterlab 3.2.4 has requirement jupyter-server~=1.4, but you'll have jupyter-server 2.0.0a1 which is incompatible.
# ERROR: jupyterlab-server 2.23.0 has requirement jsonschema>=4.17.3, but you'll have jsonschema 3.2.0 which is incompatible.
# ERROR: google-auth 2.22.0 has requirement urllib3<2.0, but you'll have urllib3 2.1.0 which is incompatible.

# %%
#!pip install -U pip setuptools

# %%
# !sudo -H pip install chromadb
# Out:
# Collecting chromadb
#   Downloading https://files.pythonhosted.org/packages/0d/e9/117169df4027a5475ec6406c49f4c5f0ed2b7a7e46d10f02ab5fc049e9ca/chromadb-0.4.18-py3-none-any.whl (502kB)
#      |████████████████████████████████| 512kB 6.9MB/s eta 0:00:01
# Collecting typing-extensions>=4.5.0
#   Downloading https://files.pythonhosted.org/packages/24/21/7d397a4b7934ff4028987914ac1044d3b7d52712f30e2ac7a2ae5bc86dd0/typing_extensions-4.8.0-py3-none-any.whl
# Collecting chroma-hnswlib==0.7.3
#   Downloading https://files.pythonhosted.org/packages/1a/ed/90526fb263945e72760603958c43cdef1a8725d2f6de70dcb21a4b4fa977/chroma_hnswlib-0.7.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4MB)
#      |████████████████████████████████| 2.4MB 19.2MB/s eta 0:00:01
# Collecting tenacity>=8.2.3
#   Downloading https://files.pythonhosted.org/packages/f4/f1/990741d5bb2487d529d20a433210ffa136a367751e454214013b441c4575/tenacity-8.2.3-py3-none-any.whl
# Collecting pydantic>=1.9
#   Downloading https://files.pythonhosted.org/packages/0a/2b/64066de1c4cf3d4ed623beeb3bbf3f8d0cc26661f1e7d180ec5eb66b75a5/pydantic-2.5.2-py3-none-any.whl (381kB)
#      |████████████████████████████████| 389kB 91kB/s s eta 0:00:01
# Collecting graphlib-backport>=1.0.3; python_version < "3.9"
#   Downloading https://files.pythonhosted.org/packages/b0/2a/d77491343f72546943dd79974133a5261b9bc12a80806c34f51a058c0732/graphlib_backport-1.0.3-py3-none-any.whl
# Collecting pulsar-client>=3.1.0
#   Downloading https://files.pythonhosted.org/packages/54/6a/82247e2be137d60a486f37997c0098b7984ad9407fc5e92aa4acfe425428/pulsar_client-3.3.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4MB)
#      |████████████████████████████████| 5.4MB 102.4MB/s eta 0:00:01
# Requirement already satisfied: requests>=2.28 in /opt/conda/lib/python3.8/site-packages (from chromadb) (2.29.0)
# Collecting kubernetes>=28.1.0
#   Downloading https://files.pythonhosted.org/packages/f5/6a/1f69c2d8b1ff03f8d8e10d801f4ac3016ed4c1b00aa9795732c6ec900bba/kubernetes-28.1.0-py2.py3-none-any.whl (1.6MB)
#      |████████████████████████████████| 1.6MB 109.7MB/s eta 0:00:01
# Collecting pypika>=0.48.9
#   Downloading https://files.pythonhosted.org/packages/c7/2c/94ed7b91db81d61d7096ac8f2d325ec562fc75e35f3baea8749c85b28784/PyPika-0.48.9.tar.gz (67kB)
#      |████████████████████████████████| 71kB 7.8MB/s  eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: tokenizers>=0.13.2 in /opt/conda/lib/python3.8/site-packages (from chromadb) (0.13.3)
# Collecting bcrypt>=4.0.1
#   Downloading https://files.pythonhosted.org/packages/a0/13/259124a851d361a2549560f9a3ccd286d17ef936017314a58cf7dffce8f7/bcrypt-4.1.1-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (699kB)
#      |████████████████████████████████| 706kB 93.8MB/s eta 0:00:01
# Collecting overrides>=7.3.1
#   Downloading https://files.pythonhosted.org/packages/da/28/3fa6ef8297302fc7b3844980b6c5dbc71cdbd4b61e9b2591234214d5ab39/overrides-7.4.0-py3-none-any.whl
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0
#   Downloading https://files.pythonhosted.org/packages/75/59/ec3e39fe164c61306998cdd3cd30a857c4da2f8d3141204a929e57668eee/opentelemetry_exporter_otlp_proto_grpc-1.21.0-py3-none-any.whl
# Collecting typer>=0.9.0
#   Downloading https://files.pythonhosted.org/packages/bf/0e/c68adf10adda05f28a6ed7b9f4cd7b8e07f641b44af88ba72d9c89e4de7a/typer-0.9.0-py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 2.1MB/s  eta 0:00:01
# Requirement already satisfied: tqdm>=4.65.0 in /opt/conda/lib/python3.8/site-packages (from chromadb) (4.65.0)
# Collecting onnxruntime>=1.14.1
#   Downloading https://files.pythonhosted.org/packages/ce/de/689d34a5524721330e03389e5d3171cb759dd5b332d7ee2576f6a2fa678e/onnxruntime-1.16.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.4MB)
#      |████████████████████████████████| 6.4MB 90.2MB/s eta 0:00:01
# Collecting mmh3>=4.0.1
#   Downloading https://files.pythonhosted.org/packages/3f/23/50b0ef2bb470d964eda3b1874dfa5aac0ecd296eba5a8644d4db973d23c8/mmh3-4.0.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (72kB)
#      |████████████████████████████████| 81kB 6.4MB/s  eta 0:00:01
# Collecting posthog>=2.4.0
#   Downloading https://files.pythonhosted.org/packages/3b/82/441cb77a43499661228048dcd0d21e0ae3235b442d0f1b9b606e29c2a5ed/posthog-3.1.0-py2.py3-none-any.whl
# Collecting opentelemetry-sdk>=1.2.0
#   Downloading https://files.pythonhosted.org/packages/c3/08/ca8b1ef7a2fa3f1ea2f12770eca8976098066adb442b1da81fea3b370123/opentelemetry_sdk-1.21.0-py3-none-any.whl (105kB)
#      |████████████████████████████████| 112kB 121.1MB/s eta 0:00:01
# Collecting grpcio>=1.58.0
#   Downloading https://files.pythonhosted.org/packages/2f/29/03a7b9b054534c3aaeb9ee71685aca2e391a90f55412b3a52f02c598d319/grpcio-1.59.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3MB)
#      |████████████████████████████████| 5.3MB 56.0MB/s eta 0:00:01
# Collecting numpy>=1.22.5; python_version >= "3.8"
#   Downloading https://files.pythonhosted.org/packages/98/5d/5738903efe0ecb73e51eb44feafba32bdba2081263d40c5043568ff60faf/numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3MB)
#      |████████████████████████████████| 17.3MB 73.1MB/s eta 0:00:01
# Collecting uvicorn[standard]>=0.18.3
#   Downloading https://files.pythonhosted.org/packages/7e/17/4b7a76fffa7babf397481040d8aef2725b2b81ae19f1a31b5ca0c17d49e6/uvicorn-0.24.0.post1-py3-none-any.whl (59kB)
#      |████████████████████████████████| 61kB 6.2MB/s  eta 0:00:01
# Requirement already satisfied: PyYAML>=6.0.0 in /opt/conda/lib/python3.8/site-packages (from chromadb) (6.0)
# Collecting fastapi>=0.95.2
#   Downloading https://files.pythonhosted.org/packages/f3/4f/0ce34195b63240b6693086496c9bab4ef23999112184399a3e88854c7674/fastapi-0.104.1-py3-none-any.whl (92kB)
#      |████████████████████████████████| 102kB 9.5MB/s  eta 0:00:01
# Collecting opentelemetry-api>=1.2.0
#   Downloading https://files.pythonhosted.org/packages/51/3a/945e6c21f405ac4ea526f91ee09cc1568c04e0c95d3392903e6984c8f0e0/opentelemetry_api-1.21.0-py3-none-any.whl (57kB)
#      |████████████████████████████████| 61kB 6.0MB/s  eta 0:00:01
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0
#   Downloading https://files.pythonhosted.org/packages/0a/47/411f4dd5560f004c4d59e977fb6e1f511babfc399f3656b6eafd8f67c0ce/opentelemetry_instrumentation_fastapi-0.42b0-py3-none-any.whl
# Requirement already satisfied: importlib-resources in /opt/conda/lib/python3.8/site-packages (from chromadb) (5.12.0)
# Collecting annotated-types>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/28/78/d31230046e58c207284c6b2c4e8d96e6d3cb4e52354721b944d3e1ee4aa5/annotated_types-0.6.0-py3-none-any.whl
# Collecting pydantic-core==2.14.5
#   Downloading https://files.pythonhosted.org/packages/ba/95/d1104b88d5e3ad42db30935a4c258da2385139dd216ec8dfbc347a32dbff/pydantic_core-2.14.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 63.6MB/s eta 0:00:01
# Requirement already satisfied: certifi in /opt/conda/lib/python3.8/site-packages (from pulsar-client>=3.1.0->chromadb) (2023.5.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.8/site-packages (from requests>=2.28->chromadb) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests>=2.28->chromadb) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests>=2.28->chromadb) (1.26.15)
# Requirement already satisfied: oauthlib>=3.2.2 in /opt/conda/lib/python3.8/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: requests-oauthlib in /opt/conda/lib/python3.8/site-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: google-auth>=1.0.1 in /opt/conda/lib/python3.8/site-packages (from kubernetes>=28.1.0->chromadb) (2.22.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/conda/lib/python3.8/site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/conda/lib/python3.8/site-packages (from kubernetes>=28.1.0->chromadb) (1.6.0)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.8/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Collecting googleapis-common-protos~=1.52
#   Downloading https://files.pythonhosted.org/packages/21/49/12996dc0238e017504dceea1d121a48bd49fb3f4416f40d59fc3e924b4f3/googleapis_common_protos-1.61.0-py2.py3-none-any.whl (230kB)
#      |████████████████████████████████| 235kB 118.5MB/s eta 0:00:01
# Collecting backoff<3.0.0,>=1.10.0; python_version >= "3.7"
#   Downloading https://files.pythonhosted.org/packages/df/73/b6e24bd22e6720ca8ee9a85a0c4a2971af8497d8f3193fa05390cbd46e09/backoff-2.2.1-py3-none-any.whl
# Collecting opentelemetry-exporter-otlp-proto-common==1.21.0
#   Downloading https://files.pythonhosted.org/packages/2a/60/ec618caf8fd8a4ac50500565eb49038ec42b7b168df9a316494085a740a6/opentelemetry_exporter_otlp_proto_common-1.21.0-py3-none-any.whl
# Collecting opentelemetry-proto==1.21.0
#   Downloading https://files.pythonhosted.org/packages/69/c2/d11b5fbf95adf68440ff4c953e2d8d027c9c62ece79b78372af95af590c9/opentelemetry_proto-1.21.0-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 3.7MB/s  eta 0:00:01
# Collecting deprecated>=1.2.6
#   Downloading https://files.pythonhosted.org/packages/20/8d/778b7d51b981a96554f29136cd59ca7880bf58094338085bcf2a979a0e6a/Deprecated-1.2.14-py2.py3-none-any.whl
# Collecting click<9.0.0,>=7.1.1
#   Downloading https://files.pythonhosted.org/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl (97kB)
#      |████████████████████████████████| 102kB 4.1MB/s  eta 0:00:01
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.8/site-packages (from onnxruntime>=1.14.1->chromadb) (4.23.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.8/site-packages (from onnxruntime>=1.14.1->chromadb) (23.0)
# Collecting flatbuffers
#   Downloading https://files.pythonhosted.org/packages/6f/12/d5c79ee252793ffe845d58a913197bfa02ae9a0b5c9bc3dc4b58d477b9e7/flatbuffers-23.5.26-py2.py3-none-any.whl
# Collecting coloredlogs
#   Downloading https://files.pythonhosted.org/packages/a7/06/3d6badcf13db419e25b07041d9c7b4a2c331d3f4e7134445ec5df57714cd/coloredlogs-15.0.1-py2.py3-none-any.whl (46kB)
#      |████████████████████████████████| 51kB 3.7MB/s  eta 0:00:01
# Requirement already satisfied: sympy in /opt/conda/lib/python3.8/site-packages (from onnxruntime>=1.14.1->chromadb) (1.11.1)
# Collecting monotonic>=1.5
#   Downloading https://files.pythonhosted.org/packages/9a/67/7e8406a29b6c45be7af7740456f7f37025f0506ae2e05fb9009a53946860/monotonic-1.6-py2.py3-none-any.whl
# Collecting opentelemetry-semantic-conventions==0.42b0
#   Downloading https://files.pythonhosted.org/packages/c3/0c/4c99cbe85b65fbba5a638cb7d913cb3acead3d83b4c47763be28d418bb95/opentelemetry_semantic_conventions-0.42b0-py3-none-any.whl
# Collecting h11>=0.8
#   Downloading https://files.pythonhosted.org/packages/95/04/ff642e65ad6b90db43e668d70ffb6736436c7ce41fcc549f4e9472234127/h11-0.14.0-py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 4.1MB/s  eta 0:00:01
# Collecting httptools>=0.5.0; extra == "standard"
#   Downloading https://files.pythonhosted.org/packages/c8/4d/1e14e818a086ce800a57c5025707ecbc66083921754b77f5e41879e132cd/httptools-0.6.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (354kB)
#      |████████████████████████████████| 358kB 106.7MB/s eta 0:00:01
# Collecting python-dotenv>=0.13; extra == "standard"
#   Downloading https://files.pythonhosted.org/packages/44/2f/62ea1c8b593f4e093cc1a7768f0d46112107e790c3e478532329e434f00b/python_dotenv-1.0.0-py3-none-any.whl
# Collecting websockets>=10.4; extra == "standard"
#   Downloading https://files.pythonhosted.org/packages/e9/bc/646bfbd9badbf59efb48db7265b097e9f626c3530c9d1329a826ef4db6a0/websockets-12.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130kB)
#      |████████████████████████████████| 133kB 103.0MB/s eta 0:00:01
# Collecting watchfiles>=0.13; extra == "standard"
#   Downloading https://files.pythonhosted.org/packages/da/42/90669adbc6293b6543a77ea104c84d8db56a0021cdd51274c8404f10e7d0/watchfiles-0.21.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3MB)
#      |████████████████████████████████| 1.4MB 97.7MB/s eta 0:00:01
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0; sys_platform != "win32" and (sys_platform != "cygwin" and platform_python_implementation != "PyPy") and extra == "standard"
#   Downloading https://files.pythonhosted.org/packages/13/b6/a5cb14acb1417c1660d722c554757e134462f09eb917e6c49907d990d63a/uvloop-0.19.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0MB)
#      |████████████████████████████████| 4.0MB 92.5MB/s eta 0:00:01
# Collecting anyio<4.0.0,>=3.7.1
#   Downloading https://files.pythonhosted.org/packages/19/24/44299477fe7dcc9cb58d0a57d5a7588d6af2ff403fdd2d47a246c91a3246/anyio-3.7.1-py3-none-any.whl (80kB)
#      |████████████████████████████████| 81kB 835kB/s  eta 0:00:01
# Collecting starlette<0.28.0,>=0.27.0
#   Downloading https://files.pythonhosted.org/packages/58/f8/e2cca22387965584a409795913b774235752be4176d276714e15e1a58884/starlette-0.27.0-py3-none-any.whl (66kB)
#      |████████████████████████████████| 71kB 2.6MB/s s eta 0:00:01
# Requirement already satisfied: importlib-metadata<7.0,>=6.0 in /opt/conda/lib/python3.8/site-packages (from opentelemetry-api>=1.2.0->chromadb) (6.7.0)
# Collecting opentelemetry-util-http==0.42b0
#   Downloading https://files.pythonhosted.org/packages/3f/33/7528bd28710e3fd669ee7c5d98bc3392eb4588d451e28352696bb23c1520/opentelemetry_util_http-0.42b0-py3-none-any.whl
# Collecting opentelemetry-instrumentation-asgi==0.42b0
#   Downloading https://files.pythonhosted.org/packages/a9/ef/ac6ef3e2c03750588dab596247204e7f960b509af37f0001ac1e4ac23f2a/opentelemetry_instrumentation_asgi-0.42b0-py3-none-any.whl
# Collecting opentelemetry-instrumentation==0.42b0
#   Downloading https://files.pythonhosted.org/packages/84/33/8e6b97dcb807c1ba5fd84910c091ae4b1b52d74ea24b0574e19f58cce99c/opentelemetry_instrumentation-0.42b0-py3-none-any.whl
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /opt/conda/lib/python3.8/site-packages (from importlib-resources->chromadb) (3.15.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.8/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.8/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Collecting wrapt<2,>=1.10
#   Downloading https://files.pythonhosted.org/packages/ef/c6/56e718e2c58a4078518c14d97e531ef1e9e8a5c1ddafdc0d264a92be1a1a/wrapt-1.16.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (83kB)
#      |████████████████████████████████| 92kB 8.6MB/s s eta 0:00:01
# Collecting humanfriendly>=9.1
#   Downloading https://files.pythonhosted.org/packages/f0/0f/310fb31e39e2d734ccaa2c0fb981ee41f7bd5056ce9bc29b2248bd569169/humanfriendly-10.0-py2.py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 8.3MB/s s eta 0:00:01
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.8/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.2.1)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.8/site-packages (from anyio<4.0.0,>=3.7.1->fastapi>=0.95.2->chromadb) (1.3.0)
# Requirement already satisfied: exceptiongroup; python_version < "3.11" in /opt/conda/lib/python3.8/site-packages (from anyio<4.0.0,>=3.7.1->fastapi>=0.95.2->chromadb) (1.1.1)
# Collecting asgiref~=3.0
#   Downloading https://files.pythonhosted.org/packages/9b/80/b9051a4a07ad231558fcd8ffc89232711b4e618c15cb7a392a17384bbeef/asgiref-3.7.2-py3-none-any.whl
# Requirement already satisfied: setuptools>=16.0 in /opt/conda/lib/python3.8/site-packages (from opentelemetry-instrumentation==0.42b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (67.8.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/conda/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.5.0)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (PEP 517) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-cp38-none-any.whl size=53723 sha256=f06cd19dd7b5a1bc86d53f4a437f701b7b72a3a147b91d0b3c77da2b89ded2ce
#   Stored in directory: /root/.cache/pip/wheels/90/54/8b/fb9a88971be610a53c7aeebd5d0c69646a2c24d9f770e2e7ac
# Successfully built pypika
# Installing collected packages: typing-extensions, numpy, chroma-hnswlib, tenacity, annotated-types, pydantic-core, pydantic, graphlib-backport, pulsar-client, kubernetes, pypika, bcrypt, overrides, googleapis-common-protos, backoff, wrapt, deprecated, opentelemetry-api, opentelemetry-proto, opentelemetry-exporter-otlp-proto-common, opentelemetry-semantic-conventions, opentelemetry-sdk, grpcio, opentelemetry-exporter-otlp-proto-grpc, click, typer, flatbuffers, humanfriendly, coloredlogs, onnxruntime, mmh3, monotonic, posthog, h11, httptools, python-dotenv, websockets, anyio, watchfiles, uvloop, uvicorn, starlette, fastapi, opentelemetry-util-http, asgiref, opentelemetry-instrumentation, opentelemetry-instrumentation-asgi, opentelemetry-instrumentation-fastapi, chromadb
#   Found existing installation: typing-extensions 4.1.1
#     Uninstalling typing-extensions-4.1.1:
#       Successfully uninstalled typing-extensions-4.1.1
#   Found existing installation: numpy 1.21.1
#     Uninstalling numpy-1.21.1:
#       Successfully uninstalled numpy-1.21.1
#   Found existing installation: grpcio 1.56.2
#     Uninstalling grpcio-1.56.2:
#       Successfully uninstalled grpcio-1.56.2
#   Found existing installation: anyio 3.7.0
#     Uninstalling anyio-3.7.0:
#       Successfully uninstalled anyio-3.7.0
# Successfully installed annotated-types-0.6.0 anyio-3.7.1 asgiref-3.7.2 backoff-2.2.1 bcrypt-4.1.1 chroma-hnswlib-0.7.3 chromadb-0.4.18 click-8.1.7 coloredlogs-15.0.1 deprecated-1.2.14 fastapi-0.104.1 flatbuffers-23.5.26 googleapis-common-protos-1.61.0 graphlib-backport-1.0.3 grpcio-1.59.3 h11-0.14.0 httptools-0.6.1 humanfriendly-10.0 kubernetes-28.1.0 mmh3-4.0.1 monotonic-1.6 numpy-1.24.4 onnxruntime-1.16.3 opentelemetry-api-1.21.0 opentelemetry-exporter-otlp-proto-common-1.21.0 opentelemetry-exporter-otlp-proto-grpc-1.21.0 opentelemetry-instrumentation-0.42b0 opentelemetry-instrumentation-asgi-0.42b0 opentelemetry-instrumentation-fastapi-0.42b0 opentelemetry-proto-1.21.0 opentelemetry-sdk-1.21.0 opentelemetry-semantic-conventions-0.42b0 opentelemetry-util-http-0.42b0 overrides-7.4.0 posthog-3.1.0 pulsar-client-3.3.0 pydantic-2.5.2 pydantic-core-2.14.5 pypika-0.48.9 python-dotenv-1.0.0 starlette-0.27.0 tenacity-8.2.3 typer-0.9.0 typing-extensions-4.8.0 uvicorn-0.24.0.post1 uvloop-0.19.0 watchfiles-0.21.0 websockets-12.0 wrapt-1.16.0

# %%
#!pip install chromadb

# %%
# !pip install  openai langchain
# Out:
# Collecting openai
#   Downloading https://files.pythonhosted.org/packages/3e/d3/309769dad11d5f75b81c7252d9dc849ed440d0921215e759af169054f3b6/openai-1.3.7-py3-none-any.whl (221kB)
#      |████████████████████████████████| 225kB 7.6MB/s eta 0:00:01
# Collecting langchain
#   Downloading https://files.pythonhosted.org/packages/ff/f2/e43aee1d628f4b46f06dcfd5072b2acb14f9d9196c40997ced0fbad972de/langchain-0.0.345-py3-none-any.whl (2.0MB)
#      |████████████████████████████████| 2.0MB 19.7MB/s eta 0:00:01
# Collecting pydantic<3,>=1.9.0
#   Downloading https://files.pythonhosted.org/packages/0a/2b/64066de1c4cf3d4ed623beeb3bbf3f8d0cc26661f1e7d180ec5eb66b75a5/pydantic-2.5.2-py3-none-any.whl (381kB)
#      |████████████████████████████████| 389kB 51.9MB/s eta 0:00:01
# Collecting distro<2,>=1.7.0
#   Downloading https://files.pythonhosted.org/packages/f4/2c/c90a3adaf0ddb70afe193f5ebfb539612af57cffe677c3126be533df3098/distro-1.8.0-py3-none-any.whl
# Collecting tqdm>4
#   Using cached https://files.pythonhosted.org/packages/00/e5/f12a80907d0884e6dff9c16d0c0114d81b8cd07dc3ae54c5e962cc83037e/tqdm-4.66.1-py3-none-any.whl
# Collecting sniffio
#   Downloading https://files.pythonhosted.org/packages/c3/a0/5dba8ed157b0136607c7f2151db695885606968d1fae123dc3391e0cfdbf/sniffio-1.3.0-py3-none-any.whl
# Collecting typing-extensions<5,>=4.5
#   Using cached https://files.pythonhosted.org/packages/24/21/7d397a4b7934ff4028987914ac1044d3b7d52712f30e2ac7a2ae5bc86dd0/typing_extensions-4.8.0-py3-none-any.whl
# Collecting anyio<4,>=3.5.0
#   Downloading https://files.pythonhosted.org/packages/19/24/44299477fe7dcc9cb58d0a57d5a7588d6af2ff403fdd2d47a246c91a3246/anyio-3.7.1-py3-none-any.whl (80kB)
#      |████████████████████████████████| 81kB 2.4MB/s  eta 0:00:01
# Collecting httpx<1,>=0.23.0
#   Downloading https://files.pythonhosted.org/packages/a2/65/6940eeb21dcb2953778a6895281c179efd9100463ff08cb6232bb6480da7/httpx-0.25.2-py3-none-any.whl (74kB)
#      |████████████████████████████████| 81kB 8.2MB/s  eta 0:00:01
# Collecting langchain-core<0.1,>=0.0.9
#   Downloading https://files.pythonhosted.org/packages/7c/4f/9ad1deef19e886500ba9a80e4025104d769fd14e5cab531f72c5bb06d10a/langchain_core-0.0.9-py3-none-any.whl (177kB)
#      |████████████████████████████████| 184kB 50.9MB/s eta 0:00:01
# Collecting dataclasses-json<0.7,>=0.5.7
#   Using cached https://files.pythonhosted.org/packages/ae/53/8c006de775834cd4ea64a445402dc195caeebb77dc76b7defb9b3887cb0d/dataclasses_json-0.6.3-py3-none-any.whl
# Collecting jsonpatch<2.0,>=1.33
#   Downloading https://files.pythonhosted.org/packages/73/07/02e16ed01e04a374e644b575638ec7987ae846d25ad97bcc9945a3ee4b0e/jsonpatch-1.33-py2.py3-none-any.whl
# Collecting tenacity<9.0.0,>=8.1.0
#   Downloading https://files.pythonhosted.org/packages/f4/f1/990741d5bb2487d529d20a433210ffa136a367751e454214013b441c4575/tenacity-8.2.3-py3-none-any.whl
# Collecting async-timeout<5.0.0,>=4.0.0; python_version < "3.11"
#   Downloading https://files.pythonhosted.org/packages/a7/fa/e01228c2938de91d47b307831c62ab9e4001e747789d0b05baf779a6488c/async_timeout-4.0.3-py3-none-any.whl
# Collecting aiohttp<4.0.0,>=3.8.3
#   Downloading https://files.pythonhosted.org/packages/25/19/91b9f2b737c9117cf8f622ee02a84788ac6fcda0aa4b736dad1321c6dd93/aiohttp-3.9.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3MB)
#      |████████████████████████████████| 1.3MB 66.8MB/s eta 0:00:01
# Collecting numpy<2,>=1
#   Using cached https://files.pythonhosted.org/packages/98/5d/5738903efe0ecb73e51eb44feafba32bdba2081263d40c5043568ff60faf/numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Collecting SQLAlchemy<3,>=1.4
#   Downloading https://files.pythonhosted.org/packages/a4/90/9bc93131211b628e4339700713647aeecbc194e66ac6de869711c631b0cd/SQLAlchemy-2.0.23-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1MB)
#      |████████████████████████████████| 3.1MB 85.5MB/s eta 0:00:01
# Collecting langsmith<0.1.0,>=0.0.63
#   Downloading https://files.pythonhosted.org/packages/ea/09/e1458ea0a26037740aac27319479aaa79053a06413b5d715d56d37371b55/langsmith-0.0.69-py3-none-any.whl (48kB)
#      |████████████████████████████████| 51kB 5.3MB/s  eta 0:00:01
# Collecting requests<3,>=2
#   Using cached https://files.pythonhosted.org/packages/70/8e/0e2d847013cb52cd35b38c009bb167a1a26b2ce6cd6965bf26b47bc0bf44/requests-2.31.0-py3-none-any.whl
# Collecting PyYAML>=5.3
#   Using cached https://files.pythonhosted.org/packages/c8/6b/6600ac24725c7388255b2f5add93f91e58a5d7efaf4af244fdbcc11a541b/PyYAML-6.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Collecting pydantic-core==2.14.5
#   Downloading https://files.pythonhosted.org/packages/ba/95/d1104b88d5e3ad42db30935a4c258da2385139dd216ec8dfbc347a32dbff/pydantic_core-2.14.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 92.5MB/s eta 0:00:01
# Collecting annotated-types>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/28/78/d31230046e58c207284c6b2c4e8d96e6d3cb4e52354721b944d3e1ee4aa5/annotated_types-0.6.0-py3-none-any.whl
# Collecting idna>=2.8
#   Using cached https://files.pythonhosted.org/packages/c2/e7/a82b05cf63a603df6e68d59ae6a68bf5064484a0718ea5033660af4b54a9/idna-3.6-py3-none-any.whl
# Collecting exceptiongroup; python_version < "3.11"
#   Downloading https://files.pythonhosted.org/packages/b8/9a/5028fd52db10e600f1c4674441b968cf2ea4959085bfb5b99fb1250e5f68/exceptiongroup-1.2.0-py3-none-any.whl
# Collecting certifi
#   Using cached https://files.pythonhosted.org/packages/64/62/428ef076be88fa93716b576e4a01f919d25968913e817077a386fcbe4f42/certifi-2023.11.17-py3-none-any.whl
# Collecting httpcore==1.*
#   Downloading https://files.pythonhosted.org/packages/56/ba/78b0a99c4da0ff8b0f59defa2f13ca4668189b134bd9840b6202a93d9a0f/httpcore-1.0.2-py3-none-any.whl (76kB)
#      |████████████████████████████████| 81kB 7.0MB/s s eta 0:00:01
# Collecting typing-inspect<1,>=0.4.0
#   Using cached https://files.pythonhosted.org/packages/65/f3/107a22063bf27bdccf2024833d3445f4eea42b2e598abfbd46f6a63b6cb0/typing_inspect-0.9.0-py3-none-any.whl
# Collecting marshmallow<4.0.0,>=3.18.0
#   Using cached https://files.pythonhosted.org/packages/ed/3c/cebfdcad015240014ff08b883d1c0c427f2ba45ae8c6572851b6ef136cad/marshmallow-3.20.1-py3-none-any.whl
# Collecting jsonpointer>=1.9
#   Downloading https://files.pythonhosted.org/packages/12/f6/0232cc0c617e195f06f810534d00b74d2f348fe71b2118009ad8ad31f878/jsonpointer-2.4-py2.py3-none-any.whl
# Collecting yarl<2.0,>=1.0
#   Downloading https://files.pythonhosted.org/packages/08/ea/2af03dbc232ed09f12316df63ec9820dc97c263a632df446c3e1e38f9091/yarl-1.9.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (307kB)
#      |████████████████████████████████| 317kB 89.5MB/s eta 0:00:01
# Collecting multidict<7.0,>=4.5
#   Downloading https://files.pythonhosted.org/packages/fe/0c/8469202f8f4b0e65816f91c3febc4bda7316c995b59ecdf3b15c574f7a24/multidict-6.0.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (121kB)
#      |████████████████████████████████| 122kB 89.4MB/s eta 0:00:01
# Collecting frozenlist>=1.1.1
#   Downloading https://files.pythonhosted.org/packages/0b/36/c276486f89bee9098332710af2207344f360c6c6f104a4931a7566039b1d/frozenlist-1.4.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (220kB)
#      |████████████████████████████████| 225kB 103.9MB/s eta 0:00:01
# Collecting attrs>=17.3.0
#   Downloading https://files.pythonhosted.org/packages/f0/eb/fcb708c7bf5056045e9e98f62b93bd7467eb718b0202e7698eb11d66416c/attrs-23.1.0-py3-none-any.whl (61kB)
#      |████████████████████████████████| 61kB 1.5MB/s  eta 0:00:01
# Collecting aiosignal>=1.1.2
#   Downloading https://files.pythonhosted.org/packages/76/ac/a7305707cb852b7e16ff80eaf5692309bde30e2b1100a1fcacdc8f731d97/aiosignal-1.3.1-py3-none-any.whl
# Collecting greenlet!=0.4.17; platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32")))))
#   Downloading https://files.pythonhosted.org/packages/56/4a/b4245b371aef65b59bfde97106038f05b90c0cb8521f27d7225310161bbc/greenlet-3.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (664kB)
#      |████████████████████████████████| 665kB 88.8MB/s eta 0:00:01
# Collecting urllib3<3,>=1.21.1
#   Using cached https://files.pythonhosted.org/packages/96/94/c31f58c7a7f470d5665935262ebd7455c7e4c7782eb525658d3dbf4b9403/urllib3-2.1.0-py3-none-any.whl
# Collecting charset-normalizer<4,>=2
#   Using cached https://files.pythonhosted.org/packages/3d/09/d82fe4a34c5f0585f9ea1df090e2a71eb9bb1e469723053e1ee9f57c16f3/charset_normalizer-3.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Collecting h11<0.15,>=0.13
#   Downloading https://files.pythonhosted.org/packages/95/04/ff642e65ad6b90db43e668d70ffb6736436c7ce41fcc549f4e9472234127/h11-0.14.0-py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 6.0MB/s  eta 0:00:01
# Collecting mypy-extensions>=0.3.0
#   Using cached https://files.pythonhosted.org/packages/2a/e2/5d3f6ada4297caebe1a2add3b126fe800c96f56dbe5d1988a2cbe0b267aa/mypy_extensions-1.0.0-py3-none-any.whl
# Collecting packaging>=17.0
#   Using cached https://files.pythonhosted.org/packages/ec/1a/610693ac4ee14fcdf2d9bf3c493370e4f2ef7ae2e19217d7a237ff42367d/packaging-23.2-py3-none-any.whl
# ERROR: torchaudio 2.0.2+cpu has requirement torch==2.0.1, but you'll have torch 2.1.1 which is incompatible.
# ERROR: refractml 1.0.3 has requirement PyYAML==6.0, but you'll have pyyaml 6.0.1 which is incompatible.
# ERROR: refractml 1.0.3 has requirement urllib3==1.26.15, but you'll have urllib3 2.1.0 which is incompatible.
# ERROR: mosaic-utils 1.0.2 has requirement scikit-learn==1.2.1; python_version >= "3.8", but you'll have scikit-learn 1.3.2 which is incompatible.
# ERROR: kubernetes 28.1.0 has requirement urllib3<2.0,>=1.24.2, but you'll have urllib3 2.1.0 which is incompatible.
# ERROR: jupyterlab 3.2.4 has requirement jupyter-server~=1.4, but you'll have jupyter-server 2.0.0a1 which is incompatible.
# ERROR: jupyterlab-server 2.23.0 has requirement jsonschema>=4.17.3, but you'll have jsonschema 3.2.0 which is incompatible.
# ERROR: google-auth 2.22.0 has requirement urllib3<2.0, but you'll have urllib3 2.1.0 which is incompatible.
# Installing collected packages: typing-extensions, pydantic-core, annotated-types, pydantic, distro, tqdm, sniffio, idna, exceptiongroup, anyio, certifi, h11, httpcore, httpx, openai, urllib3, charset-normalizer, requests, langsmith, tenacity, jsonpointer, jsonpatch, langchain-core, mypy-extensions, typing-inspect, packaging, marshmallow, dataclasses-json, async-timeout, multidict, yarl, frozenlist, attrs, aiosignal, aiohttp, numpy, greenlet, SQLAlchemy, PyYAML, langchain
# Successfully installed PyYAML-6.0.1 SQLAlchemy-2.0.23 aiohttp-3.9.1 aiosignal-1.3.1 annotated-types-0.6.0 anyio-3.7.1 async-timeout-4.0.3 attrs-23.1.0 certifi-2023.11.17 charset-normalizer-3.3.2 dataclasses-json-0.6.3 distro-1.8.0 exceptiongroup-1.2.0 frozenlist-1.4.0 greenlet-3.0.1 h11-0.14.0 httpcore-1.0.2 httpx-0.25.2 idna-3.6 jsonpatch-1.33 jsonpointer-2.4 langchain-0.0.345 langchain-core-0.0.9 langsmith-0.0.69 marshmallow-3.20.1 multidict-6.0.4 mypy-extensions-1.0.0 numpy-1.24.4 openai-1.3.7 packaging-23.2 pydantic-2.5.2 pydantic-core-2.14.5 requests-2.31.0 sniffio-1.3.0 tenacity-8.2.3 tqdm-4.66.1 typing-extensions-4.8.0 typing-inspect-0.9.0 urllib3-2.1.0 yarl-1.9.3
# WARNING: Target directory /tmp/pip_packages/mypy_extensions-1.0.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/__pycache__ already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/requests-2.31.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/typing_extensions.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/numpy already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/urllib3 already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/PyYAML-6.0.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/mypy_extensions.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/numpy.libs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/_yaml already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/marshmallow already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/numpy-1.24.4.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/dataclasses_json-0.6.3.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/certifi already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/typing_inspect.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/packaging-23.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/yaml already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/typing_extensions-4.8.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/urllib3-2.1.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/packaging already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/dataclasses_json already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/idna-3.6.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/idna already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/tqdm-4.66.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/marshmallow-3.20.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/charset_normalizer-3.3.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/tqdm already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/certifi-2023.11.17.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/requests already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/charset_normalizer already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/typing_inspect-0.9.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/bin already exists. Specify --upgrade to force replacement.

# %%
from langchain.document_loaders import DirectoryLoader

directory = '/data/chromadb_testing'

def load_docs(directory):
  loader = DirectoryLoader(directory)
  documents = loader.load()
  return documents

documents = load_docs(directory)
len(documents)
# Out:
# 3

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

def split_docs(documents,chunk_size=1000,chunk_overlap=20):
  text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
  docs = text_splitter.split_documents(documents)
  return docs

docs = split_docs(documents)
print(len(docs))
# Out:
# 3

# %%
from langchain.vectorstores import Chroma
db = Chroma.from_documents(docs, embeddings)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 from langchain.vectorstores import Chroma
# ----> 2 db = Chroma.from_documents(docs, embeddings)
#
# NameError: name 'embeddings' is not defined

# %%
from langchain.embeddings import SentenceTransformerEmbeddings
embeddings = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")

# %%
# !sudo chown mosaic-ai:mosaic-ai /home/mosaic-ai/.cache

# %%
from langchain.vectorstores import Chroma
db = Chroma.from_documents(docs, embeddings)

# %%
query = "user guide"
matching_docs = db.similarity_search(query)

matching_docs[0]

# %%
persist_directory = "/data/chroma_db"

vectordb = Chroma.from_documents(
    documents=docs, embedding=embeddings, persist_directory=persist_directory
)

vectordb.persist()
