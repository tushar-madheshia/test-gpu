# %%
token = "eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJ4WTdTd3k5UE1xaXRDQmNSMm5qcVl6bmoxS3NqZzV3TmdOV0xDVzdyUkhvIn0.....FyY0ngyfgCzkOc_HS8vJDMc73vYyp5pbfIIr1XLqDfqBLObG5AiSHSZDKhlD8_EwWt23cOM7_2OKKRDvQBfjCLqQrmZgVrFoOqq80hyE92p_WXu2zMH1SxAfBDeT5pp-jr37VhSXX7tr58O4t4D02WoshBCPDoPA8OnoLelS_L2TNSPc-wjV7qj5iWKnsJeWdWXg59KDahbhMUQ9DYU5cdOV37MfKC58iGdOnFMiQEIt4DPpu93gLgMQZYkA691I5gqs2-zgRVlHca3njWawPfMXALORIOTjKrPMfarZm6dCJ2Q4vfkAg80VuqbkICFFCEQEpL76xhKEFLWN6dL3Xw"

# %%
import requests 
def Api_call(question,context):
    data = {"payload":[{"question":question,"context":context,"date_info":{"start_date": "01/01/2020","end_date": "15/09/2023"}}]}
    headers={"Content-type":"application/json","Accept":"application/json","Authorization":token} 
    url='https://refract.fosfor.com/openchatimqlgeneratorforgpu01/6ed23fdd-6fff-4354-9047-913b00cf916a/score' 
    response = requests.post(url, json=data, headers=headers) 
    res = response.json()
    return res["data"][0]["score_response"]

# %%
context = {
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]}],
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}],
    #"DIMENSSION":{"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}]
}
question = "sales"
res=Api_call(question,context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "sale": [
#                                 {
#                                     "ENTITY": "Sales",
#                                     "MEASURE CONSTRAINT": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "segment": [
#                                 {
#                                     "ENTITY": "Segment",
#                                     "RANK": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": {
#                             "high": [
#                                 {
#                                     "ENTITY": "High",
#                                     "PARENT": "Order Priority",
#                                     "EXCLUDE": ""
#                                 }
#                             ]
#                         },
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": [
#                             {
#                                 "asked time element": [
#                                     {
#                                         "ENTITY": "Order Date",
#                                         "DATE RANGE": "01/01/2018 - 31/12/2021",
#                                         "CONVERTED TIME ELEMENT": "year"
#                                     }
#                                 ]
#                             }
#                         ]
#                     }

# %%
context = {'MEASURE': [
                {'ENTITY': 'WD Out-Stock%', 'other names': ['wd out-stock%']}, 
                {'ENTITY': 'Total Stock (Units (000))', 'other names': ['total stock']}, 
                {'ENTITY': 'ND Out-Stock%', 'other names': ['nd out stock', 'nd out-stock%']}
                ], 
           'DIMENSION': [], 
           'FILTER': [
               {'ENTITY': 'HORLICKS', 'other names': ['horlicks'], 'parent': 'Brand'}
                ], 
           'DERIVED MEASURE': [
               {'ENTITY': 'ratio', 'other names': ['percent']}, 
               {'ENTITY': 'why', 'other names': ['reason for']}
           ], 
           'DATE VARIABLE': [
               {'ENTITY': 'month', 'other names': ['when', 'mom', 'trend', 'date', 'yoy', 'month', 'months', 'time']}
               ]
          }

# %%
context = {
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                {"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]}],
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                #{"ENTITY": "Sales", "other names": ["sales", "sale"]}],
    "DIMENSSION":{"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}]
}
question = "what is purchase across segments"
res=Api_call(question,context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "purchase": [
#                                 {
#                                     "ENTITY": "Purchase Vol",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "segment": [
#                                 {
#                                     "ENTITY": "Segment",
#                                     "RANK": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": {},
#                         "DERIVED MEASURE": {},
#                         "DATE VARIABLE": {
#                             "Order Date": [
#                                 {
#                                     "ENTITY": "Order Date",
#                                     "DATE RANGE": "01/01/2020 - 15/09/2023",
#                                     "CONVERTED TIME ELEMENT": "01/01/2020 - 15/09/2023"
#                                 }
#                             ]
#                         }
#                     }

# %%
context  ={
    "MEASURE": [
                {"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                #{"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        {"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  #{"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               {"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               {"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
        #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
                        #{"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
                        #{"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
                        #{"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
                        #{"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                         #{"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ]
    #"DATE VARIABLE": [
        #{"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}]
}
question = "discount rate of phone and binders"
res = Api_call(question,context=context)
# Out:
# ['\n                    {\n                        "MEASURE": {\n                            "discount": [\n                                {\n                                    "ENTITY": "Discount",\n                                    "MEASURE CONSTRAINT": [\n                                        {\n                                            "COMPARISON VALUE": "",\n                                            "COMPARSION OPERATOR": ""\n                                        }\n                                    ],\n                                    "ADJECTIVE": [],\n                                    "TONE": ""\n                                }\n                            ]\n                        },\n                        "DIMENSION": {\n                            "Sub-Category": [\n                                {\n                                    "ENTITY": "Sub-Category",\n                                    "RANK": [],\n                                    "ADJECTIVE": [],\n                                    "TONE": ""\n                                }\n                            ]\n                        },\n                        "FILTER": {\n                            "Phone": [\n                                {\n                                    "ENTITY": "Phone",\n                                    "PARENT": "Sub-Category",\n                                    "EXCLUDE": ""\n                                }\n                            ],\n                            "Binder": [\n                                {\n                                    "ENTITY": "Binder",\n                                    "PARENT": "Sub-Category",\n                                    "EXCLUDE": ""\n                                }\n                            ]\n                        },\n                        "DERIVED MEASURE": [],\n                        "DATE VARIABLE": {}\n                    }\n                    ']

# %%
res= ['\n                    {\n                        "MEASURE": {\n                            "discount": [\n                                {\n                                    "ENTITY": "Discount",\n                                    "MEASURE CONSTRAINT": [\n                                        {\n                                            "COMPARISON VALUE": "",\n                                            "COMPARSION OPERATOR": ""\n                                        }\n                                    ],\n                                    "ADJECTIVE": [],\n                                    "TONE": ""\n                                }\n                            ]\n                        },\n                        "DIMENSION": {\n                            "Sub-Category": [\n                                {\n                                    "ENTITY": "Sub-Category",\n                                    "RANK": [],\n                                    "ADJECTIVE": [],\n                                    "TONE": ""\n                                }\n                            ]\n                        },\n                        "FILTER": {\n                            "Phone": [\n                                {\n                                    "ENTITY": "Phone",\n                                    "PARENT": "Sub-Category",\n                                    "EXCLUDE": ""\n                                }\n                            ],\n                            "Binder": [\n                                {\n                                    "ENTITY": "Binder",\n                                    "PARENT": "Sub-Category",\n                                    "EXCLUDE": ""\n                                }\n                            ]\n                        },\n                        "DERIVED MEASURE": [],\n                        "DATE VARIABLE": {}\n                    }\n                    ']
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "discount": [
#                                 {
#                                     "ENTITY": "Discount",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "Sub-Category": [
#                                 {
#                                     "ENTITY": "Sub-Category",
#                                     "RANK": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": {
#                             "Phone": [
#                                 {
#                                     "ENTITY": "Phone",
#                                     "PARENT": "Sub-Category",
#                                     "EXCLUDE": ""
#                                 }
#                             ],
#                             "Binder": [
#                                 {
#                                     "ENTITY": "Binder",
#                                     "PARENT": "Sub-Category",
#                                     "EXCLUDE": ""
#                                 }
#                             ]
#                         },
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": {}
#                     }

# %%
context  ={
    "MEASURE": [
                {"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                #{"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        {"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  #{"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               {"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               {"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               {"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
        #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
                        #{"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
                        #{"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
                        #{"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
                        #{"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                         #{"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ]
    #"DATE VARIABLE": [
        #{"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}]
}

question = "discount rate of overall sub-category in corporate"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "discount": [
#                                 {
#                                     "ENTITY": "Discount",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARISON OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "Sub-Category": [
#                                 {
#                                     "ENTITY": "Sub-Category",
#                                     "RANK": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": {
#                             "Phone": [
#                                 {
#                                     "ENTITY": "Phone",
#                                     "PARENT": "Sub-Category",
#                                     "EXCLUDE": ""
#                                 }
#                             ],
#                             "Binder": [
#                                 {
#                                     "ENTITY": "Binder",
#                                     "PARENT": "Sub-Category",
#                                     "EXCLUDE": ""
#                                 }
#                             ],
#                             "Corporate": [
#                                 {
#                                     "ENTITY": "Corporate",
#                                     "PARENT": "Segment",
#                                     "EXCLUDE": ""
#                                 }
#                             ]
#                         },
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": {}
#                     }

# %%
context  ={
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        {"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  {"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        {"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               {"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
        #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
                        #{"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
                        #{"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
                        #{"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
                        #{"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                         #{"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ]
    #"DATE VARIABLE": [
        #{"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}]
}

question = "maximum sales of phone for consumer segment"
res = Api_call(qxuestion,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "sales": [
#                                 {
#                                     "ENTITY": "Sales",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "sub-category": [
#                                 {
#                                     "ENTITY": "Sub-Category",
#                                     "RANK": [
#                                         {
#                                             "RANK ADJECTIVE": "maximum",
#                                             "RANK VALUE": "1"
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ],
#                             "segment": [
#                                 {
#                                     "ENTITY": "Segment",
#                                     "RANK": [
#                                         {
#                                             "RANK ADJECTIVE": "maximum",
#                                             "RANK VALUE": "1"
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": [
#                             {
#                                 "ENTITY": "Consumer",
#                                 "PARENT": "Segment",
#                                 "EXCLUDE": ""
#                             },
#                             {
#                                 "ENTITY": "Phone",
#                                 "PARENT": "Sub-Category",
#                                 "EXCLUDE": ""
#                             }
#                         ],
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": {}
#                     }

# %%
context  ={
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  {"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
        #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
                        #{"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
                        #{"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
                        #{"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
                        #{"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                         #{"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ]
    #"DATE VARIABLE": [
        #{"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}]
}

question = "forecast of sales"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "sales": [
#                                 {
#                                     "ENTITY": "Sales",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "segment": [
#                                 {
#                                     "ENTITY": "Segment",
#                                     "RANK": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": [],
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": {
#                             "asked time element": [
#                                 {
#                                     "ENTITY": "asked time element",
#                                     "DATE RANGE": "date range",
#                                     "CONVERTED TIME ELEMENT": "converted time element"
#                                 }
#                             ]
#                         }
#                     }

# %%
context  ={
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                {"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                #{"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  {"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        {"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
        #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
                        #{"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
                        #{"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
                        #{"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
                        #{"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                         #{"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ]
    #"DATE VARIABLE": [
        #{"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}]
}


question = "quantity across segments except consumer"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "quantity": [
#                                 {
#                                     "ENTITY": "Quantity",
#                                     "MEASURE CONSTRAINT": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "segment": [
#                                 {
#                                     "ENTITY": "Segment",
#                                     "RANK": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": {
#                             "consumer": [
#                                 {
#                                     "ENTITY": "Consumer",
#                                     "PARENT": "Segment",
#                                     "EXCLUDE": "True"
#                                 }
#                             ]
#                         },
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": {}
#                     }

# %%
context  ={
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                {"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                #{"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  {"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        {"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               {"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
        #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
                        #{"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
                        #{"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
                        #{"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
                        #{"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                         #{"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ]
    #"DATE VARIABLE": [
        #{"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}]
}


question = "which segment has highest purchase"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "sales": [
#                                 {
#                                     "ENTITY": "Sales Volume (Units (000))",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "segment": [
#                                 {
#                                     "ENTITY": "Segment",
#                                     "RANK": [
#                                         {
#                                             "RANK ADJECTIVE": "",
#                                             "RANK VALUE": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": [],
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": [
#                             {
#                                 "asked time element": [
#                                     {
#                                         "ENTITY": "month",
#                                         "DATE RANGE": "01/01/2021 - 01/31/2021",
#                                         "CONVERTED TIME ELEMENT": "month"
#                                     }
#                                 ]
#                             }
#                         ]
#                     }

# %%
{\'MEASURE\': [{\'ENTITY\': \'Sales\', \'other names\': [\'sales\'], \'dataset_id\': \'65113e0de69a671c98f59929_1\'}], \'DIMENSION\': [{\'ENTITY\': \'Segment\', \'other names\': [\'segment\'], \'dataset_id\': \'65113e0de69a671c98f59929_1\'}], \'FILTER\': [{\'ENTITY\': \'Phones\', \'other names\': [\'phone\'], \'dataset_id\': \'65113e0de69a671c98f59929_1\', \'parent\': \'Sub-Category\'}, {\'ENTITY\': \'Consumer\', \'other names\': [\'consumer\'], \'dataset_id\': \'65113e0de69a671c98f59929_1\', \'parent\': \'Segment\'}], \'DERIVED MEASURE\': [{\'ENTITY\': \'why\', \'other names\': [\'reason for\'], \'dataset_id\': \'non_data_metrics\'}], \'DATE VARIABLE\': [{\'ENTITY\': \'Order Date\', \'other names\': [\'when\', \'trend\', \'mom\', \'date\', \'time\', \'yoy\', \'order date\'], \'dataset_id\': \'65113e0de69a671c98f59929_1\'}]}\n

# %%
context  ={
    "MEASURE": [
                {"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                #{"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        {"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  #{"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               {"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               {"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
        #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
                        #{"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
                        {"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
                        #{"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
                        #{"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                         #{"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ]
    #"DATE VARIABLE": [
        #{"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}]
}


question = "which category contributing to 5% of discount"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "discount": [
#                                 {
#                                     "ENTITY": "Discount",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "5",
#                                             "COMPARSION OPERATOR": "%"
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "Sub-Category": [
#                                 {
#                                     "ENTITY": "Sub-Category",
#                                     "RANK": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": {
#                             "Phone": [
#                                 {
#                                     "ENTITY": "Phone",
#                                     "PARENT": "Sub-Category",
#                                     "EXCLUDE": ""
#                                 }
#                             ],
#                             "Binder": [
#                                 {
#                                     "ENTITY": "Binder",
#                                     "PARENT": "Sub-Category",
#                                     "EXCLUDE": ""
#                                 }
#                             ]
#                         },
#                         "DERIVED MEASURE": {},
#                         "DATE VARIABLE": {}
#                     }

# %%
context  ={
    "MEASURE": [
                {"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                #{"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  {"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
        #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
                        #{"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
                        #{"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
                        #{"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
                        #{"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
                        #{"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
                         #                "correlated",
                          #               "correlation", "correlations", "relate", "related", "relation", "relations",
                           #              "relationship",
                            #             "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}]
}


question = "top 2 segments basis discount"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "discount": [
#                                 {
#                                     "ENTITY": "Discount",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "segment": [
#                                 {
#                                     "ENTITY": "Segment",
#                                     "RANK": [
#                                         {
#                                             "RANK ADJECTIVE": "top",
#                                             "RANK VALUE": "2"
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": [],
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": [
#                             {
#                                 "asked time element": [
#                                     {
#                                         "ENTITY": "Order Date",
#                                         "DATE RANGE": "01/01/2020 - 15/09/2023",
#                                         "CONVERTED TIME ELEMENT": "Order Date"
#                                     }
#                                 ]
#                             }
#                         ]
#                     }

# %%
context  ={
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  {"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
#         {"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
#                         {"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
#                         {"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                         {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}]
}


question = "monthly sales of segments in 2021"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "sales": [
#                                 {
#                                     "ENTITY": "Sales",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "segment": [
#                                 {
#                                     "ENTITY": "Segment",
#                                     "RANK": [
#                                         {
#                                             "RANK ADJECTIVE": "top",
#                                             "RANK VALUE": "1"
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": [],
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": {
#                             "asked time element": [
#                                 {
#                                     "ENTITY": "Order Date",
#                                     "DATE RANGE": "01/01/2021 - 31/01/2021",
#                                     "CONVERTED TIME ELEMENT": "01/01/2021 - 31/01/2021"
#                                 }
#                             ]
#                         }
#                     }

# %%
context  = {
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  {"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
#         {"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
#                         {"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
#                         {"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                         {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]

        }


question = "show me the 2 top segments basis sales"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "sales": [
#                                 {
#                                     "ENTITY": "Sales",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "segment": [
#                                 {
#                                     "ENTITY": "Segment",
#                                     "RANK": [
#                                         {
#                                             "RANK ADJECTIVE": "top",
#                                             "RANK VALUE": "2"
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": [],
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": []
#                     }

# %%
context  = {
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  {"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
#         {"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
#                         {"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
#                         {"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                         {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }


question = "top 2 and bottom 3 segments by sales"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "sales": [
#                                 {
#                                     "ENTITY": "Sales",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "segment": [
#                                 {
#                                     "ENTITY": "Segment",
#                                     "RANK": [
#                                         {
#                                             "RANK ADJECTIVE": "top",
#                                             "RANK VALUE": "2"
#                                         },
#                                         {
#                                             "RANK ADJECTIVE": "bottom",
#                                             "RANK VALUE": "3"
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": [],
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": [
#                             {
#                                 "asked time element": [
#                                     {
#                                         "ENTITY": "Order Date",
#                                         "DATE RANGE": "date range",
#                                         "CONVERTED TIME ELEMENT": "date range"
#                                     }
#                                 ]
#                             }
#                         ]
#                     }

# %%
context  = {
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                {"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                #{"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        {"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  {"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
#         {"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
#                         {"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
#                         {"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                         {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "top 2 segments and bottom 3 sub-category basis quantity"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "quantity": [
#                                 {
#                                     "ENTITY": "Quantity",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "segment": [
#                                 {
#                                     "ENTITY": "Segment",
#                                     "RANK": [
#                                         {
#                                             "RANK ADJECTIVE": "top",
#                                             "RANK VALUE": "2"
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ],
#                             "sub-category": [
#                                 {
#                                     "ENTITY": "Sub-Category",
#                                     "RANK": [
#                                         {
#                                             "RANK ADJECTIVE": "bottom",
#                                             "RANK VALUE": "3"
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": [],
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": [
#                             {
#                                 "asked time element": [
#                                     {
#                                         "ENTITY": "Order Date",
#                                         "DATE RANGE": "date range",
#                                         "CONVERTED TIME ELEMENT": "date range"
#                                     }
#                                 ]
#                             }
#                         ]
#                     }

# %%
context  = {
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                {"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                #{"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        {"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  {"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  {"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        {"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               {"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               {"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
#         {"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
#                         {"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
#                         {"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                         {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "quantity across segments except consumer and corporate in dubai"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "quantity": [
#                                 {
#                                     "ENTITY": "Quantity",
#                                     "MEASURE CONSTRAINT": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "segment": [
#                                 {
#                                     "ENTITY": "Segment",
#                                     "RANK": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ],
#                             "country": [
#                                 {
#                                     "ENTITY": "Country",
#                                     "RANK": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ],
#                             "sub-category": [
#                                 {
#                                     "ENTITY": "Sub-Category",
#                                     "RANK": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": {
#                             "consumer": [
#                                 {
#                                     "ENTITY": "Consumer",
#                                     "PARENT": "Segment",
#                                     "EXCLUDE": "True"
#                                 }
#                             ],
#                             "corporate": [
#                                 {
#                                     "ENTITY": "Corporate",
#                                     "PARENT": "Segment",
#                                     "EXCLUDE": "True"
#                                 }
#                             ],
#                             "dubai": [
#                                 {
#                                     "ENTITY": "Dubai",
#                                     "PARENT": "Country",
#                                     "EXCLUDE": ""
#                                 }
#                             ]
#                         },
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": {
#                             "asked time element": [
#                                 {
#                                     "ENTITY": "Order Date",
#                                     "DATE RANGE": "",
#                                     "CONVERTED TIME ELEMENT": ""
#                                 }
#                             ]
#                         }
#                     }

# %%
context  = {
    "MEASURE": [
                {"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                #{"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  #{"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               {"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               {"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               {"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
         {"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
#                         {"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
#                         {"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                         {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "in corporate share of phone and binder basis discount"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "discount": [
#                                 {
#                                     "ENTITY": "Discount",
#                                     "MEASURE CONSTRAINT": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "Phone": [
#                                 {
#                                     "ENTITY": "Phone",
#                                     "RANK": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ],
#                             "Binder": [
#                                 {
#                                     "ENTITY": "Binder",
#                                     "RANK": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": [
#                             {
#                                 "ENTITY": "Phone",
#                                 "PARENT": "Sub-Category",
#                                 "EXCLUDE": ""
#                             },
#                             {
#                                 "ENTITY": "Binder",
#                                 "PARENT": "Sub-Category",
#                                 "EXCLUDE": ""
#                             },
#                             {
#                                 "ENTITY": "Corporate",
#                                 "PARENT": "Segment",
#                                 "EXCLUDE": ""
#                             }
#                         ],
#                         "DERIVED MEASURE": {
#                             "Ratio": [
#                                 {
#                                     "ENTITY": "Ratio",
#                                     "RATIO FILTER": [
#                                         {
#                                             "Binder": "Binder"
#                                         },
#                                         {
#                                             "Phone": "Phone"
#                                         }
#                                     ],
#                                     "APPLIED MEASURE": [
#                                         {
#                                             "Discount": "Discount"
#                                         }
#                                     ],
#                                     "DERIVED MEASURE CONSTRAINT": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DATE VARIABLE": [
#                             {
#                                 "asked time element": [
#                                     {
#                                         "ENTITY": "Order Date",
#                                         "DATE RANGE

# %%
context  = {
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  #{"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
         #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
#                         {"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
#                         {"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                         {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "sales in q123 vs pp"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "sales": [
#                                 {
#                                     "ENTITY": "Sales",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": "vs"
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": [],
#                         "FILTER": [],
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": {
#                             "asked time element": [
#                                 {
#                                     "ENTITY": "Order Date",
#                                     "DATE RANGE": "date range",
#                                     "CONVERTED TIME ELEMENT": "date range"
#                                 }
#                             ]
#                         }
#                     }

# %%
context  = {
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  {"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
         #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
#                         {"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
#                         {"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                         {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "top most selling segments in 2020 vs 2021"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "sales": [
#                                 {
#                                     "ENTITY": "Sales",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "segment": [
#                                 {
#                                     "ENTITY": "Segment",
#                                     "RANK": [
#                                         {
#                                             "RANK ADJECTIVE": "top",
#                                             "RANK VALUE": "1"
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": [],
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": [
#                             {
#                                 "asked time element": [
#                                     {
#                                         "ENTITY": "Order Date",
#                                         "DATE RANGE": "01/01/2020 - 31/12/2020",
#                                         "CONVERTED TIME ELEMENT": "2020"
#                                     },
#                                     {
#                                         "ENTITY": "Order Date",
#                                         "DATE RANGE": "01/01/2021 - 31/12/2021",
#                                         "CONVERTED TIME ELEMENT": "2021"
#                                     }
#                                 ]
#                             }
#                         ]
#                     }

# %%
context  = {
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  #{"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
         #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
#                         {"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
#                         {"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                         {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "sales from 2021 to 2023"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "sales": [
#                                 {
#                                     "ENTITY": "Sales",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "2021",
#                                             "COMPARSION OPERATOR": ">"
#                                         },
#                                         {
#                                             "COMPARISON VALUE": "2023",
#                                             "COMPARSION OPERATOR": "<"
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": [],
#                         "FILTER": [],
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": {
#                             "asked time element": [
#                                 {
#                                     "ENTITY": "Order Date",
#                                     "DATE RANGE": "2021-01-01 to 2023-12-31",
#                                     "CONVERTED TIME ELEMENT": "2021-01-01 to 2023-12-31"
#                                 }
#                             ]
#                         }
#                     }

# %%
context  = {
    "MEASURE": [
                {"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                #{"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        {"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  #{"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        {"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               {"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
         {"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
#                         {"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
#                         {"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                         {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "binder share of discount by consumer"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "discount": [
#                                 {
#                                     "ENTITY": "Discount",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "Sub-Category": [
#                                 {
#                                     "ENTITY": "Sub-Category",
#                                     "RANK": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": {
#                             "Consumer": [
#                                 {
#                                     "ENTITY": "Consumer",
#                                     "PARENT": "Segment",
#                                     "EXCLUDE": ""
#                                 }
#                             ],
#                             "Binder": [
#                                 {
#                                     "ENTITY": "Binder",
#                                     "PARENT": "Sub-Category",
#                                     "EXCLUDE": ""
#                                 }
#                             ]
#                         },
#                         "DERIVED MEASURE": {
#                             "Ratio": [
#                                 {
#                                     "ENTITY": "Ratio",
#                                     "RATIO FILTER": [
#                                         {
#                                             "Binder": "Binder"
#                                         }
#                                     ],
#                                     "APPLIED MEASURE": [
#                                         {
#                                             "Discount": "Discount"
#                                         }
#                                     ],
#                                     "DERIVED MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DATE VARIABLE": {
#                             "Order Date": [
#                                 {
#                                     "ENTITY": "Order Date",
#                                     "DATE RANGE": "date range",
#                                     "CONVERTED TIME ELEMENT": "date range"
#                                 }

# %%
context  = {
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        {"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  {"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               {"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               {"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               {"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
         {"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
#                         {"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
#                         {"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                         {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "binder and phone share basis sales for corporate"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "sales": [
#                                 {
#                                     "ENTITY": "Sales",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "sub-category": [
#                                 {
#                                     "ENTITY": "Sub-Category",
#                                     "RANK": [
#                                         {
#                                             "RANK ADJECTIVE": "",
#                                             "RANK VALUE": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ],
#                             "segment": [
#                                 {
#                                     "ENTITY": "Segment",
#                                     "RANK": [
#                                         {
#                                             "RANK ADJECTIVE": "",
#                                             "RANK VALUE": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": [
#                             {
#                                 "ENTITY": "Phone",
#                                 "PARENT": "Sub-Category",
#                                 "EXCLUDE": ""
#                             },
#                             {
#                                 "ENTITY": "Binder",
#                                  "PARENT": "Sub-Category",
#                                 "EXCLUDE": ""
#                             },
#                             {
#                                 "ENTITY": "Corporate",
#                                 "PARENT": "Segment",
#                                 "EXCLUDE": ""
#                             }
#                         ],
#                         "DERIVED MEASURE": {
#                             "Ratio": [
#                                 {
#                                     "ENTITY": "Ratio",
#                                     "RATIO FILTER": [
#                                         {
#                                             "Binder": "Binder"
#                                         },

# %%
context  = {
    "MEASURE": [
                {"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                #{"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        {"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  {"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               {"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               {"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               {"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
         {"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
#                         {"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
#                         {"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                         {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "in corporate, share of phone and binder basis discount"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "discount": [
#                                 {
#                                     "ENTITY": "Discount",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "Sub-Category": [
#                                 {
#                                     "ENTITY": "Sub-Category",
#                                     "RANK": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ],
#                             "Segment": [
#                                 {
#                                     "ENTITY": "Segment",
#                                     "RANK": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": {
#                             "Phone": [
#                                 {
#                                     "ENTITY": "Phone",
#                                     "PARENT": "Sub-Category",
#                                     "EXCLUDE": ""
#                                 }
#                             ],
#                             "Binder": [
#                                 {
#                                     "ENTITY": "Binder",
#                                     "PARENT": "Sub-Category",
#                                     "EXCLUDE": ""
#                                 }
#                             ],
#                             "Corporate": [
#                                 {
#                                     "ENTITY": "Corporate",
#                                     "PARENT": "Segment",
#                                     "EXCLUDE": ""
#                                 }
#                             ]
#                         },
#                         "DERIVED MEASURE": {
#                             "Ratio": [
#                                 {
#                                     "ENTITY": "Ratio",
#                                     "RATIO FILTER": [
#                                         {
#                                             "Binder": "Binder"
#                                         },
#                                         {
#                                             "Phone": "Phone"
#                                         }

# %%
context  = {
    "MEASURE": [
                {"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                #{"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  #{"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               {"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               {"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               {"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
         {"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
#                         {"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
#                         {"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                         {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "phone to binder ratio of discount in corporate"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "discount": [
#                                 {
#                                     "ENTITY": "Discount",
#                                     "MEASURE CONSTRAINT": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "Phone": [
#                                 {
#                                     "ENTITY": "Phone",
#                                     "RANK": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ],
#                             "Binder": [
#                                 {
#                                     "ENTITY": "Binder",
#                                     "RANK": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ],
#                             "Corporate": [
#                                 {
#                                     "ENTITY": "Corporate",
#                                     "RANK": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": [
#                             {
#                                 "ENTITY": "Phone",
#                                 "PARENT": "Sub-Category",
#                                 "EXCLUDE": ""
#                             },
#                             {
#                                 "ENTITY": "Binder",
#                                 "PARENT": "Sub-Category",
#                                 "EXCLUDE": ""
#                             },
#                             {
#                                 "ENTITY": "Corporate",
#                                 "PARENT": "Segment",
#                                 "EXCLUDE": ""
#                             }
#                         ],
#                         "DERIVED MEASURE": {
#                             "Ratio": [
#                                 {
#                                     "ENTITY": "Ratio",
#                                     "RATIO FILTER": [
#                                         {
#                                             "Binder": "Binder"
#                                         }
#                                     ],
#                                     "APPLIED MEASURE": [
#                                         {
#                                             "Discount": "Discount"
#                                         }
#                                     ],
#                                     "DERIVED MEASURE CONSTRAINT": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DATE VARIABLE

# %%
context  = {
    "MEASURE": [
                {"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                #{"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  {"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
         #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
#                         {"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
#                         {"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                         {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "segments with discount rate greater than 100k"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "discount": [
#                                 {
#                                     "ENTITY": "Discount",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "100k",
#                                             "COMPARISON OPERATOR": ">"
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "segment": [
#                                 {
#                                     "ENTITY": "Segment",
#                                     "RANK": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": [],
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": [
#                             {
#                                 "asked time element": [
#                                     {
#                                         "ENTITY": "Order Date",
#                                         "DATE RANGE": "01/01/2020 - 15/09/2023",
#                                         "CONVERTED TIME ELEMENT": "Order Date"
#                                     }
#                                 ]
#                             }
#                         ]
#                     }

# %%
context  = {
    "MEASURE": [
                {"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                {"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                #{"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        {"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  #{"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
         #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
#                         {"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
#                         {"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                         {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "category with discount rate greater than 10k and quantity less than 2k"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "discount": [
#                                 {
#                                     "ENTITY": "Discount",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "10k",
#                                             "COMPARSION OPERATOR": ">"
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ],
#                             "quantity": [
#                                 {
#                                     "ENTITY": "Quantity",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "2k",
#                                             "COMPARSION OPERATOR": "<"
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "Sub-Category": [
#                                 {
#                                     "ENTITY": "Sub-Category",
#                                     "RANK": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": [],
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": [
#                             {
#                                 "asked time element": [
#                                     {
#                                         "ENTITY": "Order Date",
#                                         "DATE RANGE": "date range",
#                                         "CONVERTED TIME ELEMENT": "date range"
#                                     }
#                                 ]
#                             }
#                         ]
#                     }

# %%
context  = {
    "MEASURE": [
                {"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                #{"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  #{"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               {"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
         #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
                         {"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
#                         {"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                         {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "why did discount of phones drop"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "discount": [
#                                 {
#                                     "ENTITY": "Discount",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "Phone": [
#                                 {
#                                     "ENTITY": "Phone",
#                                     "RANK": [
#                                         {
#                                             "RANK ADJECTIVE": "",
#                                             "RANK VALUE": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": {
#                             "Phone": [
#                                 {
#                                     "ENTITY": "Phone",
#                                     "PARENT": "Sub-Category",
#                                     "EXCLUDE": ""
#                                 }
#                             ]
#                         },
#                         "DERIVED MEASURE": {
#                             "Why": [
#                                 {
#                                     "ENTITY": "Why",
#                                     "RATIO FILTER": [],
#                                     "APPLIED MEASURE": [
#                                         {
#                                             "ENTITY": "Discount",
#                                             "other names": [
#                                                 "discount",
#                                                 "discount rate",
#                                                 "discount value",
#                                                 "deduction"
#                                             ]
#                                         }
#                                     ],
#                                     "DERIVED MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DATE VARIABLE": {
#                             "Order Date": [
#                                 {
#                                     "ENTITY": "Order Date",
#                                     "DATE RANGE": "date range",
#                                     "CONVERTED TIME ELEMENT": "date range"
#                                 }
#                             ]
#                         }
#                     }

# %%
context  = {
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                {"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  #{"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               {"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
         #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
                         #{"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
#                         {"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
                         {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
                                         "correlated",
                                         "correlation", "correlations", "relate", "related", "relation", "relations",
                                         "relationship",
                                         "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "correlation of sales and purchase for phone"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "purchase": [
#                                 {
#                                     "ENTITY": "Purchase Vol",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ],
#                             "sales": [
#                                 {
#                                     "ENTITY": "Sales",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": [],
#                         "FILTER": [
#                             {
#                                 "ENTITY": "Phone",
#                                 "PARENT": "Sub-Category",
#                                 "EXCLUDE": ""
#                             }
#                         ],
#                         "DERIVED MEASURE": [
#                             {
#                                 "ENTITY": "correlation",
#                                 "RATIO FILTER": [],
#                                 "APPLIED MEASURE": [
#                                     {
#                                         "ENTITY": "Purchase Vol",
#                                         "other names": [
#                                             "purchase",
#                                             "purchase value",
#                                             "purchase model"
#                                         ]
#                                     },
#                                     {
#                                         "ENTITY": "Sales",
#                                         "other names": [
#                                             "sales",
#                                             "sale"
#                                         ]
#                                     }
#                                 ],
#                                 "DERIVED MEASURE CONSTRAINT": [
#                                     {
#                                         "COMPARISON VALUE": "",
#                                         "COMPARSION OPERATOR": ""
#                                     }
#                                 ],
#                                 "ADJECTIVE": [],
#                                 "TONE": ""
#                             }
#                         ],
#                         "DATE VARIABLE": [
#                             {
#                                 "asked time element": [
#                                     {
#                                         "ENTITY": "Order Date",
#                                         "

# %%
context  = {
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  #{"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
         #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
                         #{"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
#                         {"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                          {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "what will be the sales in q1 21"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "sales": [
#                                 {
#                                     "ENTITY": "Sales",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": [],
#                         "FILTER": [],
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": {
#                             "asked time element": [
#                                 {
#                                     "ENTITY": "Order Date",
#                                     "DATE RANGE": "01/01/2021 - 31/03/2021",
#                                     "CONVERTED TIME ELEMENT": "quarterly"
#                                 }
#                             ]
#                         }
#                     }

# %%
context  = {
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  #{"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
         #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
                         #{"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
#                         {"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                          {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "sales in q1 and q2 2021"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "sales": [
#                                 {
#                                     "ENTITY": "Sales",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {},
#                         "FILTER": {},
#                         "DERIVED MEASURE": {},
#                         "DATE VARIABLE": {
#                             "asked time element": [
#                                 {
#                                     "ENTITY": "Order Date",
#                                     "DATE RANGE": "01/01/2021 - 31/03/2021, 01/04/2021 - 30/06/2021",
#                                     "CONVERTED TIME ELEMENT": "quarterly"
#                                 }
#                             ]
#                         }
#                     }

# %%
context  = {
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  {"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
         #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
                         #{"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
                         {"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                          {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "how many segments contributing to growth of sales in p3m vs pp"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "sales": [
#                                 {
#                                     "ENTITY": "Sales",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "pp",
#                                             "COMPARSION OPERATOR": ">"
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "segment": [
#                                 {
#                                     "ENTITY": "Segment",
#                                     "RANK": [
#                                         {
#                                             "RANK ADJECTIVE": "top",
#                                             "RANK VALUE": "1"
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": [],
#                         "DERIVED MEASURE": {
#                             "contribution_to_growth": [
#                                 {
#                                     "ENTITY": "contribution_to_growth",
#                                     "RATIO FILTER": [],
#                                     "APPLIED MEASURE": [
#                                         {
#                                             "ENTITY": "Sales",
#                                             "other names": ["sales", "sale"]
#                                         }
#                                     ],
#                                     "DERIVED MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "p3m",
#                                             "COMPARSION OPERATOR": ">"
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DATE VARIABLE": {
#                             "Order Date": [
#                                 {
#                                     "ENTITY": "Order Date",
#                                     "DATE RANGE": "date range",
#                                     "CONVERTED TIME ELEMENT": "date range"
#                                 }
#                             ]
#                         }
#                     }

# %%
context  = {
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  #{"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
         #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
                         #{"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
                         #{"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                          {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "how has sales trended in first week of 2021"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "sales": [
#                                 {
#                                     "ENTITY": "Sales",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": [],
#                         "FILTER": [],
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": {
#                             "asked time element": [
#                                 {
#                                     "ENTITY": "Order Date",
#                                     "DATE RANGE": "01/01/2021 - 07/01/2021",
#                                     "CONVERTED TIME ELEMENT": "01/01/2021 - 07/01/2021"
#                                 }
#                             ]
#                         }
#                     }

# %%
context  = {
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  #{"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
         #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
                         #{"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
                         #{"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                          {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "what will be sales in 1st 5 days of 2023"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "sales": [
#                                 {
#                                     "ENTITY": "Sales",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": [],
#                         "FILTER": [],
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": {
#                             "asked time element": [
#                                 {
#                                     "ENTITY": "Order Date",
#                                     "DATE RANGE": "01/01/2023 - 05/01/2023",
#                                     "CONVERTED TIME ELEMENT": "01/01/2023 - 05/01/2023"
#                                 }
#                             ]
#                         }
#                     }

# %%
context  = {
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                {"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  #{"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
         #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
                         #{"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
                         #{"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                          {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "sales and purchase across yoy"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "purchase": [
#                                 {
#                                     "ENTITY": "Purchase Vol",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ],
#                             "sales": [
#                                 {
#                                     "ENTITY": "Sales",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": [],
#                         "FILTER": [],
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": [
#                             {
#                                 "asked time element": [
#                                     {
#                                         "ENTITY": "Order Date",
#                                         "DATE RANGE": "date range",
#                                         "CONVERTED TIME ELEMENT": "date range"
#                                     }
#                                 ]
#                             }
#                         ]
#                     }

# %%
context  = {
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                #{"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  {"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
         #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
                         #{"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
                         #{"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                          {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "list of under performing segments"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "under performing": [
#                                 {
#                                     "ENTITY": "under performing",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "least",
#                                             "COMPARSION OPERATOR": "<"
#                                         }
#                                     ],
#                                     "ADJECTIVE": [
#                                         "under performing"
#                                     ],
#                                     "TONE": "negative"
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "Segment": [
#                                 {
#                                     "ENTITY": "Segment",
#                                     "RANK": [
#                                         {
#                                             "RANK ADJECTIVE": "least",
#                                             "RANK VALUE": "1"
#                                         }
#                                     ],
#                                     "ADJECTIVE": [
#                                         "least"
#                                     ],
#                                     "TONE": "negative"
#                                 }
#                             ]
#                         },
#                         "FILTER": [],
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": {
#                             "Order Date": [
#                                 {
#                                     "ENTITY": "Order Date",
#                                     "DATE RANGE": "01/01/2020 - 15/09/2023",
#                                     "CONVERTED TIME ELEMENT": "01/01/2020 - 15/09/2023"
#                                 }
#                             ]
#                         }
#                     }

# %%
context  = {
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  {"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
         #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
                         #{"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
                         #{"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                          {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "when was the first time sales of segments was 0"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "sales": [
#                                 {
#                                     "ENTITY": "Sales",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "0",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "segment": [
#                                 {
#                                     "ENTITY": "Segment",
#                                     "RANK": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": [],
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": [
#                             {
#                                 "asked time element": [
#                                     {
#                                         "ENTITY": "Order Date",
#                                         "DATE RANGE": "date range",
#                                         "CONVERTED TIME ELEMENT": "date range"
#                                     }
#                                 ]
#                             }
#                         ]
#                     }

# %%
context  = {
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  {"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
         #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
                         #{"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
                         #{"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                          {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "sales of segments from beginning"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "sales": [
#                                 {
#                                     "ENTITY": "Sales",
#                                     "MEASURE CONSTRAINT": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "segment": [
#                                 {
#                                     "ENTITY": "Segment",
#                                     "RANK": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": [],
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": {
#                             "asked time element": [
#                                 {
#                                     "ENTITY": "Order Date",
#                                     "DATE RANGE": "01/01/2020 - 15/09/2023",
#                                     "CONVERTED TIME ELEMENT": "Order Date"
#                                 }
#                             ]
#                         }
#                     }

# %%
context  = {
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  #{"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
         #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
                         #{"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
                         #{"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                          {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "sales in 20/01/2020"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "sales": [
#                                 {
#                                     "ENTITY": "Sales",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "20/01/2020",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": [],
#                         "FILTER": [],
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": {
#                             "asked time element": [
#                                 {
#                                     "ENTITY": "Order Date",
#                                     "DATE RANGE": "20/01/2020 - 20/01/2020",
#                                     "CONVERTED TIME ELEMENT": "20/01/2020"
#                                 }
#                             ]
#                         }
#                     }

# %%
context  = {
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  #{"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
         #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
                         #{"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
                         #{"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                          {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "sales in last one and half years"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "sales": [
#                                 {
#                                     "ENTITY": "Sales",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": [],
#                         "FILTER": [],
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": {
#                             "asked time element": [
#                                 {
#                                     "ENTITY": "Order Date",
#                                     "DATE RANGE": "01/01/2020 - 07/01/2021",
#                                     "CONVERTED TIME ELEMENT": "last one and half years"
#                                 }
#                             ]
#                         }
#                     }

# %%
context  = {
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  #{"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               {"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
         #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
                         #{"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
                         #{"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                          {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "trend of sales in dubai now"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "sales": [
#                                 {
#                                     "ENTITY": "Sales",
#                                     "MEASURE CONSTRAINT": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": [],
#                         "FILTER": {
#                             "dubai": [
#                                 {
#                                     "ENTITY": "Dubai",
#                                     "PARENT": "Country",
#                                     "EXCLUDE": ""
#                                 }
#                             ]
#                         },
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": {
#                             "asked time element": [
#                                 {
#                                     "ENTITY": "Order Date",
#                                     "DATE RANGE": "01/01/2020 - 15/09/2023",
#                                     "CONVERTED TIME ELEMENT": "01/01/2020 - 15/09/2023"
#                                 }
#                             ]
#                         }
#                     }

# %%
context  = {
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  #{"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
         #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
                         #{"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
                         #{"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                          {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "sales in the week of 01 March 2022"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "sales": [
#                                 {
#                                     "ENTITY": "Sales",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "",
#                                             "COMPARSION OPERATOR": ""
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {},
#                         "FILTER": {},
#                         "DERIVED MEASURE": {},
#                         "DATE VARIABLE": {
#                             "asked time element": [
#                                 {
#                                     "ENTITY": "Order Date",
#                                     "DATE RANGE": "01/03/2022 - 07/03/2022",
#                                     "CONVERTED TIME ELEMENT": "01/03/2022 - 07/03/2022"
#                                 }
#                             ]
#                         }
#                     }

# %%
context  = {
    "MEASURE": [
                #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}
               ],
    "DIMENSION": [
        #{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  #{"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  #{"ENTITY": "Country", "other names": ["country", "countries"]}
    ],
    "FILTER": [
        #{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               #{"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
    ],
    "DERIVED MEASURE": [
         #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
                         #{"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
                         #{"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         {"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
#                          {"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
#                                          "correlated",
#                                          "correlation", "correlations", "relate", "related", "relation", "relations",
#                                          "relationship",
#                                          "relationships"]}
                        ],
    "DATE VARIABLE": [
        {"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}
        ]
        }

question = "sales from 100 to 200"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "sales": [
#                                 {
#                                     "ENTITY": "Sales",
#                                     "MEASURE CONSTRAINT": [
#                                         {
#                                             "COMPARISON VALUE": "200",
#                                             "COMPARSION OPERATOR": ">"
#                                         },
#                                         {
#                                             "COMPARISON VALUE": "100",
#                                             "COMPARSION OPERATOR": "<"
#                                         }
#                                     ],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": [],
#                         "FILTER": [],
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": [
#                             {
#                                 "asked time element": [
#                                     {
#                                         "ENTITY": "Order Date",
#                                         "DATE RANGE": "date range",
#                                         "CONVERTED TIME ELEMENT": "date range"
#                                     }
#                                 ]
#                             }
#                         ]
#                     }

# %%
# Out:
# {'MEASURE': [{'ENTITY': 'Sales',
#    'other names': ['sales'],
#    'dataset_id': '65113e0de69a671c98f59929_1'}],
#  'DIMENSION': [{'ENTITY': 'Segment',
#    'other names': ['segment'],
#    'dataset_id': '65113e0de69a671c98f59929_1'}],
#  'FILTER': [{'ENTITY': 'Phones',
#    'other names': ['phone'],
#    'dataset_id': '65113e0de69a671c98f59929_1',
#    'parent': 'Sub-Category'},
#   {'ENTITY': 'Consumer',
#    'other names': ['consumer'],
#    'dataset_id': '65113e0de69a671c98f59929_1',
#    'parent': 'Segment'}],
#  'DERIVED MEASURE': [{'ENTITY': 'why',
#    'other names': ['reason for'],
#    'dataset_id': 'non_data_metrics'}],
#  'DATE VARIABLE': [{'ENTITY': 'Order Date',
#    'other names': ['when',
#     'trend',
#     'mom',
#     'date',
#     'time',
#     'yoy',
#     'order date'],
#    'dataset_id': '65113e0de69a671c98f59929_1'}]}

# %%
context = {
  'MEASURE': [
    {
      'ENTITY': 'Sales',
      'other names': [
        'sales'
      ],
      'dataset_id': '65113e0de69a671c98f59929_1'
    }
  ],
  'DIMENSION': [
    {
      'ENTITY': 'Segment',
      'other names': [
        'segment'
      ],
      'dataset_id': '65113e0de69a671c98f59929_1'
    }
  ],
  'FILTER': [
    {
      'ENTITY': 'Phones',
      'other names': [
        'phone'
      ],
      'dataset_id': '65113e0de69a671c98f59929_1',
      'parent': 'Sub-Category'
    },
    {
      'ENTITY': 'Consumer',
      'other names': [
        'consumer'
      ],
      'dataset_id': '65113e0de69a671c98f59929_1',
      'parent': 'Segment'
    }
  ],
  'DERIVED MEASURE': [
    {
      'ENTITY': 'why',
      'other names': [
        'reason for'
      ],
      'dataset_id': 'non_data_metrics'
    }
  ],
  'DATE VARIABLE': [
    {
      'ENTITY': 'Order Date',
      'other names': [
        'when',
        'trend',
        'mom',
        'date',
        'time',
        'yoy',
        'order date'
      ],
      'dataset_id': '65113e0de69a671c98f59929_1'
    }
  ]
}

# %%
# context  ={
#     "MEASURE": [
#                 #{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
#                 #{"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
#                 #{"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
#                 {"ENTITY": "Sales", "other names": ["sales", "sale"]}
#                ],
#     "DIMENSION": [
#         {"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
#                   {"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
#                   #{"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
#                   #{"ENTITY": "Country", "other names": ["country", "countries"]}
#     ],
#     "FILTER": [
#         {"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
#                {"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
#                #{"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
#                #{"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
#                #{"ENTITY": "India", "other names": ["india"], "parent": "Country"},
#                #{"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}
#     ],
#     "DERIVED MEASURE": [
#         #{"ENTITY": "Ratio", "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
#                         #{"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
#                         #{"ENTITY": "contribution_to_growth","other names": ["contribution to growth", "growth", "grown"]},
#                         #{"ENTITY": "kda_transactional","other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
#                         #{"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
# #                         #{"ENTITY": "correlation","other names": ["associate", "associated", "association", "associations", "correlate",
# #                                          "correlated",
# #                                          "correlation", "correlations", "relate", "related", "relation", "relations",
# #                                          "relationship",
# #                                          "relationships"]}
#                         ]
#     #"DATE VARIABLE": [
#         #{"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}]
# }

question = "maximum sales of phone for consumer segment"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "sales": [
#                                 {
#                                     "ENTITY": "Sales",
#                                     "MEASURE CONSTRAINT": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "segment": [
#                                 {
#                                     "ENTITY": "Segment",
#                                     "RANK": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": [
#                             {
#                                 "ENTITY": "Phones",
#                                 "PARENT": "Segment",
#                                 "EXCLUDE": ""
#                             },
#                             {
#                                 "ENTITY": "Consumer",
#                                 "PARENT": "Segment",
#                                 "EXCLUDE": ""
#                             }
#                         ],
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": {
#                             "Order Date": [
#                                 {
#                                     "ENTITY": "Order Date",
#                                     "DATE RANGE": "01/01/2020 - 15/09/2023",
#                                     "CONVERTED TIME ELEMENT": "01/01/2020 - 15/09/2023"
#                                 }
#                             ]
#                         }
#                     }

# %%
context = "{\'MEASURE\': [{\'ENTITY\': \'Sales\', \'other names\': [\'sales\'], \'dataset_id\': \'65113e0de69a671c98f59929_1\'}], \'DIMENSION\': [{\'ENTITY\': \'Segment\', \'other names\': [\'segment\'], \'dataset_id\': \'65113e0de69a671c98f59929_1\'}], \'FILTER\': [{\'ENTITY\': \'Phones\', \'other names\': [\'phone\'], \'dataset_id\': \'65113e0de69a671c98f59929_1\', \'parent\': \'Sub-Category\'}, {\'ENTITY\': \'Consumer\', \'other names\': [\'consumer\'], \'dataset_id\': \'65113e0de69a671c98f59929_1\', \'parent\': \'Segment\'}], \'DERIVED MEASURE\': [{\'ENTITY\': \'why\', \'other names\': [\'reason for\'], \'dataset_id\': \'non_data_metrics\'}], \'DATE VARIABLE\': [{\'ENTITY\': \'Order Date\', \'other names\': [\'when\', \'trend\', \'mom\', \'date\', \'time\', \'yoy\', \'order date\'], \'dataset_id\': \'65113e0de69a671c98f59929_1\'}]}"

# %%
question = "maximum sales of phone for consumer segment"
res = Api_call(question,context=context)
print(res[0])
# Out:
#                     {
#                         "MEASURE": {
#                             "sales": [
#                                 {
#                                     "ENTITY": "Sales",
#                                     "MEASURE CONSTRAINT": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "DIMENSION": {
#                             "segment": [
#                                 {
#                                     "ENTITY": "Segment",
#                                     "RANK": [],
#                                     "ADJECTIVE": [],
#                                     "TONE": ""
#                                 }
#                             ]
#                         },
#                         "FILTER": [
#                             {
#                                 "ENTITY": "Phones",
#                                 "PARENT": "Segment",
#                                 "EXCLUDE": ""
#                             },
#                             {
#                                 "ENTITY": "Consumer",
#                                 "PARENT": "Segment",
#                                 "EXCLUDE": ""
#                             }
#                         ],
#                         "DERIVED MEASURE": [],
#                         "DATE VARIABLE": {
#                             "Order Date": [
#                                 {
#                                     "ENTITY": "Order Date",
#                                     "DATE RANGE": "01/01/2020 - 15/09/2023",
#                                     "CONVERTED TIME ELEMENT": "01/01/2020 - 15/09/2023"
#                                 }
#                             ]
#                         }
#                     }

# %%
context = {\'MEASURE\': [{\'ENTITY\': \'WD Out-Stock%\', \'other names\': [\'wd out-stock%\']}, {\'ENTITY\': \'Total Stock (Units (000))\', \'other names\': [\'total stock\']}, {\'ENTITY\': \'ND Out-Stock%\', \'other names\': [\'nd out stock\', \'nd out-stock%\']}], \'DIMENSION\': [], \'FILTER\': [{\'ENTITY\': \'HORLICKS\', \'other names\': [\'horlicks\'], \'parent\': \'Brand\'}], \'DERIVED MEASURE\': [{\'ENTITY\': \'ratio\', \'other names\': [\'percent\']}, {\'ENTITY\': \'why\', \'other names\': [\'reason for\']}], \'DATE VARIABLE\': [{\'ENTITY\': \'month\', \'other names\': [\'when\', \'mom\', \'trend\', \'date\', \'yoy\', \'month\', \'months\', \'time\']}]}
# Out:
#   Cell In[6], line 1
#     context = {\'MEASURE\': [{\'ENTITY\': \'WD Out-Stock%\', \'other names\': [\'wd out-stock%\']}, {\'ENTITY\': \'Total Stock (Units (000))\', \'other names\': [\'total stock\']}, {\'ENTITY\': \'ND Out-Stock%\', \'other names\': [\'nd out stock\', \'nd out-stock%\']}], \'DIMENSION\': [], \'FILTER\': [{\'ENTITY\': \'HORLICKS\', \'other names\': [\'horlicks\'], \'parent\': \'Brand\'}], \'DERIVED MEASURE\': [{\'ENTITY\': \'ratio\', \'other names\': [\'percent\']}, {\'ENTITY\': \'why\', \'other names\': [\'reason for\']}], \'DATE VARIABLE\': [{\'ENTITY\': \'month\', \'other names\': [\'when\', \'mom\', \'trend\', \'date\', \'yoy\', \'month\', \'months\', \'time\']}]}
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ^
# SyntaxError: unexpected character after line continuation character
