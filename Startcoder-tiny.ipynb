# %%
# !sudo huggingface-cli login --token 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
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

checkpoint = "bigcode/tiny_starcoder_py"
device = "cpu" # for GPU usage or "cpu" for CPU usage

tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForCausalLM.from_pretrained(checkpoint).to(device)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
# Out:
# Using pad_token, but it is not set yet.

# %%
inputs = tokenizer.encode("Generate SAS program to read file into abcd", return_tensors="pt").to(device)

outputs = model.generate(inputs, pad_token_id=tokenizer.pad_token_id, max_new_tokens=100)
#outputs = model.generate(inputs)
print(tokenizer.decode(outputs[0]))
# Out:
# Generate SAS program to read file into abcd.
#
# Usage:
#     python3 read_sas.py <file>
#
# Options:
#     -h --help     Show this screen.
#     -f --file     Read file from file.
#     -d --delimiter  Delimiter to use.
#     -s --start     Start reading from file.
#     -e --end     End reading from file.
#     -i --input     Input file.
#     -o --output     Output file.
# """
#
# import sys

# %%
# !pip install auto_gptq bitsandbytes
# Out:
# WARNING: The directory '/home/mosaic-ai/.cache/pip/http' or its parent directory is not owned by the current user and the cache has been disabled. Please check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# WARNING: The directory '/home/mosaic-ai/.cache/pip' or its parent directory is not owned by the current user and caching wheels has been disabled. check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Collecting auto_gptq
#   Downloading https://files.pythonhosted.org/packages/1f/dd/59b8e40a29af6367bc17bb8c3edb74f40d87724ffe5f812d55938daa39ff/auto_gptq-0.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8MB)
#      |████████████████████████████████| 1.8MB 7.0MB/s eta 0:00:01
# Collecting bitsandbytes
#   Downloading https://files.pythonhosted.org/packages/1e/2c/af22cd797fc368a9f098ed03015730e6568b884fe67f9940793d944a4b7b/bitsandbytes-0.41.1-py3-none-any.whl (92.6MB)
#      |████████████████████████████████| 92.6MB 194.0MB/s eta 0:00:01
# Collecting accelerate>=0.19.0
#   Downloading https://files.pythonhosted.org/packages/d9/92/2d3aecf9f4a192968035880be3e2fc8b48d541c7128f7c936f430d6f96da/accelerate-0.23.0-py3-none-any.whl (258kB)
#      |████████████████████████████████| 266kB 125.4MB/s eta 0:00:01
# Collecting peft
#   Downloading https://files.pythonhosted.org/packages/37/1a/8d20e8704da9fa070eb909265584b960da57be1d833d550c59f50906dc5c/peft-0.5.0-py3-none-any.whl (85kB)
#      |████████████████████████████████| 92kB 116.5MB/s eta 0:00:01
# Collecting rouge
#   Downloading https://files.pythonhosted.org/packages/32/7c/650ae86f92460e9e8ef969cc5008b24798dcf56a9a8947d04c78f550b3f5/rouge-1.0.1-py3-none-any.whl
# Collecting safetensors
#   Downloading https://files.pythonhosted.org/packages/7d/cb/878e746f52e3c55312c34d89a3a80f1b2db59f5293457a75cbc99c82a27a/safetensors-0.4.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3MB)
#      |████████████████████████████████| 1.4MB 75.2MB/s eta 0:00:01
# Collecting numpy
#   Downloading https://files.pythonhosted.org/packages/98/5d/5738903efe0ecb73e51eb44feafba32bdba2081263d40c5043568ff60faf/numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3MB)
#      |████████████████████████████████| 17.3MB 113.6MB/s eta 0:00:01
# Collecting torch>=1.13.0
#   Downloading https://files.pythonhosted.org/packages/e1/24/f7fe3fe82583e6891cc3fceeb390f192f6c7f1d87e5a99a949ed33c96167/torch-2.1.0-cp38-cp38-manylinux1_x86_64.whl (670.2MB)
#      |██████████████▎                 | 299.1MB 183.9MB/s eta 0:00:03
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#      |██████████████████████████████  | 628.6MB 195.6MB/s eta 0:00:01
#      |██████████████████████████████▌ | 638.4MB 195.6MB/s eta 0:00:01
#      |███████████████████████████████ | 647.7MB 195.6MB/s eta 0:00:01
#      |███████████████████████████████▍| 657.4MB 195.6MB/s eta 0:00:01
#      |███████████████████████████████▉| 667.0MB 195.6MB/s eta 0:00:01
#      |████████████████████████████████| 670.2MB 195.6MB/s
# Collecting datasets
#   Downloading https://files.pythonhosted.org/packages
#      |█████████████████████████████▋  | 677.4MB 4.9MB/s eta 0:00:11
#      |██████████████████████████████  | 686.8MB 4.9MB/s eta 0:00:10
#      |██████████████████████████████▌ | 696.6MB 4.9MB/s eta 0:00:08
#      |██████████████████████████████▉ | 706.3MB 4.9MB/s eta 0:00:06
#      |███████████████████████████████▎| 716.0MB 4.9MB/s eta 0:00:04
#      |███████████████████████████████▊| 725.7MB 4.9MB/s eta 0:00:02
#      |████████████████████████████████| 731.7MB 199.6MB/s
# Collecting nvidia-cublas-cu12==12.1.3.1; platform_system == "Linux" and platform_machine == "x86_64"
#   Downloading https://files.pythonhosted.org/packages/37/6d/121efd7382d5b0284239f4ab1fc1590d86d34ed4a4a2fdb13b30ca8e5740/nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6MB)
#      |███████████████████████▏        | 297.1MB 149.6MB/s eta 0:00:01
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
from transformers import AutoTokenizer, pipeline, logging
from auto_gptq import AutoGPTQForCausalLM, BaseQuantizeConfig
import argparse

model_name_or_path = "TheBloke/Redmond-Hermes-Coder-GPTQ"
model_basename = "model"

use_triton = False

tokenizer = AutoTokenizer.from_pretrained(model_name_or_path, use_fast=True)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
import os
import torch
from datasets import load_dataset
from datasets import Dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    TrainingArguments,
    pipeline,
    logging,
)

# Activate 4-bit precision base model loading
use_4bit = True

# Compute dtype for 4-bit base models
bnb_4bit_compute_dtype = "float16"

# Quantization type (fp4 or nf4)
bnb_4bit_quant_type = "nf4"

# Activate nested quantization for 4-bit base models (double quantization)
use_nested_quant = True

compute_dtype = getattr(torch, bnb_4bit_compute_dtype)

bnb_config = BitsAndBytesConfig(
    load_in_4bit=use_4bit,
    bnb_4bit_quant_type=bnb_4bit_quant_type,
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=use_nested_quant,
)
# Out:
# ---------------------------------------------------------------------------
# PackageNotFoundError                      Traceback (most recent call last)
# Cell In[2], line 29
#      25 use_nested_quant = True
#      27 compute_dtype = getattr(torch, bnb_4bit_compute_dtype)
# ---> 29 bnb_config = BitsAndBytesConfig(
#      30     load_in_4bit=use_4bit,
#      31     bnb_4bit_quant_type=bnb_4bit_quant_type,
#      32     bnb_4bit_compute_dtype=compute_dtype,
#      33     bnb_4bit_use_double_quant=use_nested_quant,
#      34 )
#
# File /tmp/pip_packages/transformers/utils/quantization_config.py:212, in BitsAndBytesConfig.__init__(self, load_in_8bit, load_in_4bit, llm_int8_threshold, llm_int8_skip_modules, llm_int8_enable_fp32_cpu_offload, llm_int8_has_fp16_weight, bnb_4bit_compute_dtype, bnb_4bit_quant_type, bnb_4bit_use_double_quant, **kwargs)
#     209 else:
#     210     raise ValueError("bnb_4bit_compute_dtype must be a string or a torch.dtype")
# --> 212 self.post_init()
#
# File /tmp/pip_packages/transformers/utils/quantization_config.py:238, in BitsAndBytesConfig.post_init(self)
#     235 if not isinstance(self.bnb_4bit_use_double_quant, bool):
#     236     raise ValueError("bnb_4bit_use_double_quant must be a boolean")
# --> 238 if self.load_in_4bit and not version.parse(importlib.metadata.version("bitsandbytes")) >= version.parse(
#     239     "0.39.0"
#     240 ):
#     241     raise ValueError(
#     242         "4 bit quantization requires bitsandbytes>=0.39.0 - please upgrade your bitsandbytes version"
#     243     )
#
# File /opt/conda/lib/python3.8/importlib/metadata.py:530, in version(distribution_name)
#     523 def version(distribution_name):
#     524     """Get the version string for the named package.
#     525
#     526     :param distribution_name: The name of the distribution package to query.
#     527     :return: The version string for the package as defined in the package's
#     528         "Version" metadata key.
#     529     """
# --> 530     return distribution(distribution_name).version
#
# File /opt/conda/lib/python3.8/importlib/metadata.py:503, in distribution(distribution_name)
#     497 def distribution(distribution_name):
#     498     """Get the ``Distribution`` instance for the named package.
#     499
#     500     :param distribution_name: The name of the distribution package as a string.
#     501     :return: A ``Distribution`` instance (or subclass thereof).
#     502     """
# --> 503     return Distribution.from_name(distribution_name)
#
# File /opt/conda/lib/python3.8/importlib/metadata.py:177, in Distribution.from_name(cls, name)
#     175         return dist
#     176 else:
# --> 177     raise PackageNotFoundError(name)
#
# PackageNotFoundError: bitsandbytes

# %%
model = AutoGPTQForCausalLM.from_quantized(model_name_or_path,
        model_basename=model_basename,
        use_safetensors=True,
        trust_remote_code=False,
        device="cpu",
        quantize_config=None)
# Out:
# GPTBigCodeGPTQForCausalLM hasn't fused attention module yet, will skip inject fused attention.
# GPTBigCodeGPTQForCausalLM hasn't fused mlp module yet, will skip inject fused mlp.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model = AutoGPTQForCausalLM.from_quantized(model_name_or_path,
#       2         model_basename=model_basename,
#       3         use_safetensors=True,
#       4         trust_remote_code=False,
#       5         device="cpu",
#       6         quantize_config=None)
#
# File /tmp/pip_packages/auto_gptq/modeling/auto.py:108, in AutoGPTQForCausalLM.from_quantized(cls, model_name_or_path, device_map, max_memory, device, low_cpu_mem_usage, use_triton, inject_fused_attention, inject_fused_mlp, use_cuda_fp16, quantize_config, model_basename, use_safetensors, trust_remote_code, warmup_triton, trainable, disable_exllama, **kwargs)
#     102 # TODO: do we need this filtering of kwargs? @PanQiWei is there a reason we can't just pass all kwargs?
#     103 keywords = {
#     104     key: kwargs[key]
#     105     for key in list(signature(quant_func).parameters.keys()) + huggingface_kwargs
#     106     if key in kwargs
#     107 }
# --> 108 return quant_func(
#     109     model_name_or_path=model_name_or_path,
#     110     device_map=device_map,
#     111     max_memory=max_memory,
#     112     device=device,
#     113     low_cpu_mem_usage=low_cpu_mem_usage,
#     114     use_triton=use_triton,
#     115     inject_fused_attention=inject_fused_attention,
#     116     inject_fused_mlp=inject_fused_mlp,
#     117     use_cuda_fp16=use_cuda_fp16,
#     118     quantize_config=quantize_config,
#     119     model_basename=model_basename,
#     120     use_safetensors=use_safetensors,
#     121     trust_remote_code=trust_remote_code,
#     122     warmup_triton=warmup_triton,
#     123     trainable=trainable,
#     124     disable_exllama=disable_exllama,
#     125     **keywords
#     126 )
#
# File /tmp/pip_packages/auto_gptq/modeling/_base.py:923, in BaseGPTQForCausalLM.from_quantized(cls, model_name_or_path, device_map, max_memory, device, low_cpu_mem_usage, use_triton, torch_dtype, inject_fused_attention, inject_fused_mlp, use_cuda_fp16, quantize_config, model_basename, use_safetensors, trust_remote_code, warmup_triton, trainable, disable_exllama, **kwargs)
#     917         cls.fused_mlp_module_type.inject_to_model(
#     918             model,
#     919             use_triton=use_triton
#     920         )
#     922 # Any post-initialization that require device information, for example buffers initialization on device.
# --> 923 model = autogptq_post_init(model, use_act_order=quantize_config.desc_act)
#     925 model.eval()
#     926 # == step6: (optional) warmup triton == #
#
# File /tmp/pip_packages/auto_gptq/modeling/_utils.py:258, in autogptq_post_init(model, use_act_order, max_input_length)
#     255 model.device_to_buffers = device_to_buffers
#     257 for device, buffers in model.device_to_buffers.items():
# --> 258     prepare_buffers(device, buffers["temp_state"], buffers["temp_dq"])
#     260 # Using the default from exllama repo here.
#     261 matmul_recons_thd = 8
#
# RuntimeError: no device index

# %%
prompt = "Tell me about AI"
prompt_template=f'''Below is an instruction that describes a task. Write a response that appropriately completes the request.

### Instruction: PROMPT

### Response:

'''

print("\n\n*** Generate:")

input_ids = tokenizer(prompt_template, return_tensors='pt').input_ids
output = model.generate(inputs=input_ids, temperature=0.7, max_new_tokens=512)
print(tokenizer.decode(output[0]))

# Inference can also be done using transformers' pipeline

# Prevent printing spurious transformers error when using pipeline with AutoGPTQ
logging.set_verbosity(logging.CRITICAL)

print("*** Pipeline:")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_new_tokens=512,
    temperature=0.7,
    top_p=0.95,
    repetition_penalty=1.15
)

print(pipe(prompt_template)[0]['generated_text'])
