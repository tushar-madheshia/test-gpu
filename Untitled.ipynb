# %%
! sudo pip3 install torch torchvision torchaudio
# Out:
# ...
#      |████████████████▌               | 319.0MB 15.6MB/s eta 0:00:20
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#      |███████████████████████████████ | 599.3MB 147.3MB/s eta 0:00:01
#      |███████████████████████████████▎| 607.0MB 147.3MB/s eta 0:00:01
#      |███████████████████████████████▊| 615.1MB 147.3MB/s eta 0:00:01
#      |████████████████████████████████| 619.9MB 147.3MB/s eta 0:00:01
#      |████████████████████████████████| 619.9MB 26kB/s
# ...
#      |████████████████████████████████| 6.0MB 98.6MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 4.4MB 100.0MB/s eta 0:00:01
# ...
#      |███████████████████████████▏    | 268.9MB 174.2MB/s eta 0:00:01
# IOPub data rate exceeded.
# ...

# %%
pip install datasets transformers
# Out:
# ...
#      |████████████████████████████████| 501kB 10.0MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 7.4MB 119.0MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 143kB 126.7MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 51kB 37.2MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 81kB 56.3MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 747kB 123.2MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 276kB 123.1MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 17.7MB 121.2MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 194kB 114.7MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.1MB 274kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 39.0MB 109.6MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 163kB 119.9MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 71kB 53.7MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 122kB 128.8MB/s eta 0:00:01
# ...

# %% [markdown]
# ## Check GPU availability
# Import torch and check if GPU is available and other details around it

# %%
import torch
is_available = torch.cuda.is_available()
count_gpu =  torch.cuda.device_count()

print(f"GPU available in this notebook : {is_available}")
print(f"Total no. of GPUs available    : {count_gpu}")
# Out:
# GPU available in this notebook : True
# Total no. of GPUs available    : 1

# %%
# !nvidia-smi
# Out:
# Mon Jul 31 05:00:29 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.73.08    Driver Version: 510.73.08    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A10-4Q       On   | 00000002:00:00.0 Off |                    0 |
# | N/A   N/A    P8    N/A /  N/A |      0MiB /  4096MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ## Fine-Tune ViT for Image Classification with 🤗 Transformers

# %%
from datasets import load_dataset

ds = load_dataset('beans')
ds
# Out:
# ...
# Generating test split:   0%|          | 0/128 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['image_file_path', 'image', 'labels'],
#         num_rows: 1034
#     })
#     validation: Dataset({
#         features: ['image_file_path', 'image', 'labels'],
#         num_rows: 133
#     })
#     test: Dataset({
#         features: ['image_file_path', 'image', 'labels'],
#         num_rows: 128
#     })
# })

# %% [markdown]
# ### Check one Random datapoint

# %%
ex = ds['train'][400]
ex
# Out:
# {'image_file_path': '/home/mosaic-ai/.cache/huggingface/datasets/downloads/extracted/8d969391b22d6b6baa6dfdce63e6e4d1c9544855a993467c1b7b812d05cac2ae/train/bean_rust/bean_rust_train.148.jpg',
#  'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500>,
#  'labels': 1}

# %% [markdown]
# Display the image in above random datapoint

# %%
image = ex['image']

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500>

# %%
# feature definition of labels
labels = ds['train'].features['labels']
labels
# Out:
# ClassLabel(names=['angular_leaf_spot', 'bean_rust', 'healthy'], id=None)
