# %% [markdown]
# ### Distill step by step finetuning approach - trying enhanced rationale with specific reasoning for date conversion

# %%
# !sudo pip install -q transformers --upgrade

# %%
import transformers
transformers.__version__
# Out:
# '4.34.1'

# %%
#!sudo pip install -q accelerate peft==0.4.0 bitsandbytes trl==0.4.7

# %%
import os
import torch
from datasets import load_dataset
from datasets import Dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    TrainingArguments,
    pipeline,
    logging,
)
from peft import LoraConfig, PeftModel
from trl import SFTTrainer
import pandas as pd
import torch

# %%
df = pd.read_csv('/data/mistral/query-to-mql/exp-8/training-data.csv')

# %%
df.columns
# Out:
# Index(['Query', 'MQL', 'Rationale'], dtype='object')

# %%
df.shape
# Out:
# (65, 3)

# %%
# The model that you want to train from the Hugging Face hub
model_name = "mistralai/Mistral-7B-Instruct-v0.1"

# The instruction dataset to use
#dataset_name = ""

# Fine-tuned model name
#new_model = "mistral-ft-peft-on-template_and_user_query-data"

# %%
################################################################################
# QLoRA parameters
################################################################################

# LoRA attention dimension
lora_r = 64

# Alpha parameter for LoRA scaling
lora_alpha = 16

# Dropout probability for LoRA layers
lora_dropout = 0.1

# %%
################################################################################
# bitsandbytes parameters
################################################################################

# Activate 4-bit precision base model loading
use_4bit = True

# Compute dtype for 4-bit base models
bnb_4bit_compute_dtype = "float16"

# Quantization type (fp4 or nf4)
bnb_4bit_quant_type = "nf4"

# Activate nested quantization for 4-bit base models (double quantization)
use_nested_quant = True

# %%
################################################################################
# TrainingArguments parameters
################################################################################

# Output directory where the model predictions and checkpoints will be stored
output_dir = "/data/mistral/query-to-mql/exp-8/oct-30"

# Number of training epochs
num_train_epochs = 15

# Enable fp16/bf16 training (set bf16 to True with an A100)
# fp16 = False
fp16 = True # not using quantisation
bf16 = False

# Batch size per GPU for training
per_device_train_batch_size = 1

# Batch size per GPU for evaluation
per_device_eval_batch_size = 1

# Number of update steps to accumulate the gradients for
gradient_accumulation_steps = 1

# Enable gradient checkpointing
gradient_checkpointing = True


# Maximum gradient normal (gradient clipping)
max_grad_norm = 0.3

# Initial learning rate (AdamW optimizer)
learning_rate = 2e-4

# Weight decay to apply to all layers except bias/LayerNorm weights
weight_decay = 0.001

# Optimizer to use
optim = "paged_adamw_32bit"

# Learning rate schedule (constant a bit better than cosine)
lr_scheduler_type = "constant"

# Number of training steps (overrides num_train_epochs)
max_steps = 200

# Ratio of steps for a linear warmup (from 0 to learning rate)
warmup_ratio = 0.03

# Group sequences into batches with same length
# Saves memory and speeds up training considerably
group_by_length = True

# Save checkpoint every X updates steps
save_steps = 40

# Log every X updates steps
logging_steps = 40

# %%
################################################################################
# SFT parameters
################################################################################

# Maximum sequence length to use
max_seq_length = None

# Pack multiple short examples in the same input sequence to increase efficiency
packing = False

# Load the entire model on the GPU 0
device_map = {"": 0}

# %%
promt_template = """Given the context : {context} and date reference: {date_input}, the query: {user_query}, is converted into below shown structured output.
[MQL]
{mql}
[/MQL]
the steps and rationale used to achieve above structured output is as below.
{rationale}
"""

# %%
df.columns
# Out:
# Index(['Query', 'MQL', 'Rationale'], dtype='object')

# %%
context = """{
    "MEASURE": [{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                {"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                {"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}],
    "DIMENSION": [{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  {"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  {"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  {"ENTITY": "Country", "other names": ["country", "countries"]}],
    "FILTER": [{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               {"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               {"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               {"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               {"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               {"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}],
    "DERIVED MEASURE": [{"ENTITY": "Ratio",
             "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
            {"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
            {"ENTITY": "contribution_to_growth", "other names": ["contribution to growth", "growth", "grown"]},
            {"ENTITY": "kda_transactional", "other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
            {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
            {"ENTITY": "correlation",
             "other names": ["associate", "associated", "association", "associations", "correlate", "correlated",
                             "correlation", "correlations", "relate", "related", "relation", "relations",
                             "relationship",
                             "relationships"]}
            ],
    "DATE VARIABLE": [{"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}]
    }"""

# %%
date_input = {
    "start_date": "01/01/2020",
    "end_date": "15/09/2023"
}

# %%
def create_fine_tuning_dataset(row):
    mql = row['MQL']
    user_query = row['Query']
    rationale = row['Rationale']
    formated = promt_template.format(context=context,
                                             date_input=date_input,
                                             user_query=user_query,
                                             mql=mql,
                                             rationale=rationale)
    return formated

# %%
df['fine_tuning_dataset']=df.apply(create_fine_tuning_dataset, axis=1)

# %%
df.drop(columns=['Query', 'MQL', 'Rationale'], inplace=True)
df.shape
# Out:
# (65, 1)

# %%
train_dataset = Dataset.from_pandas(df)

# %%
train_dataset
# Out:
# Dataset({
#     features: ['fine_tuning_dataset'],
#     num_rows: 65
# })

# %%
train_dataset['fine_tuning_dataset'][0]
# Out:
# 'Given the context : {\n    "MEASURE": [{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},\n                {"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},\n                {"ENTITY": "Quantity", "other names": ["quantity", "volume"]},\n                {"ENTITY": "Sales", "other names": ["sales", "sale"]}],\n    "DIMENSION": [{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},\n                  {"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},\n                  {"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},\n                  {"ENTITY": "Country", "other names": ["country", "countries"]}],\n    "FILTER": [{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},\n               {"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},\n               {"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},\n               {"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},\n               {"ENTITY": "India", "other names": ["india"], "parent": "Country"},\n               {"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}],\n    "DERIVED MEASURE": [{"ENTITY": "Ratio",\n             "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},\n            {"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},\n            {"ENTITY": "contribution_to_growth", "other names": ["contribution to growth", "growth", "grown"]},\n            {"ENTITY": "kda_transactional", "other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},\n            {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},\n            {"ENTITY": "correlation",\n             "other names": ["associate", "associated", "association", "associations", "correlate", "correlated",\n                             "correlation", "correlations", "relate", "related", "relation", "relations",\n                             "relationship",\n                             "relationships"]}\n            ],\n    "DATE VARIABLE": [{"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}]\n    } and date reference: {\'start_date\': \'01/01/2020\', \'end_date\': \'15/09/2023\'}, the query: what is purchase across segments, is converted into below shown structured output.\n[MQL]\n{\n    "DIMENSION": {\n        "segments": [\n            {\n                "ENTITY": "Segment",\n                "RANK": [\n                    {\n                        "RANK ADJECTIVE": "",\n                        "RANK VALUE": ""\n                    }\n                ]\n            }\n        ]\n    },\n    "MEASURE": {\n        "purchase": [\n            {\n                "ENTITY": "Purchase Vol",\n                "MEASURE CONSTRAINT": [\n                    {\n                        "COMPARISON VALUE": "",\n                        "COMPARSION OPERATOR": ""\n                    }\n                ]\n            }\n        ]\n    }\n}\n[/MQL]\nthe steps and rationale used to achieve above structured output is as below.\nStep 1: Identify the components in the query\n- The query asks for "purchase" which can be matched to the context as "Purchase Vol".\n- The query mentions "across segments" which can be matched to the context as "Segment".\n\nStep 2: Match the components to the context\n- "Purchase Vol" is a measure in the context, so it will be placed under the "MEASURE" section in the structured output.\n- "Segment" is a dimension in the context, so it will be placed under the "DIMENSION" section in the structured output.\n\nStep 3: Convert the components into structured output format\n- For "Pur ...

# %%
# Load tokenizer and model with QLoRA configuration
compute_dtype = getattr(torch, bnb_4bit_compute_dtype)

bnb_config = BitsAndBytesConfig(
    load_in_4bit=use_4bit,
    bnb_4bit_quant_type=bnb_4bit_quant_type,
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=use_nested_quant,
)

# %%
bnb_4bit_quant_type
# Out:
# 'nf4'

# %%
compute_dtype
# Out:
# torch.float16

# %%
# Check GPU compatibility with bfloat16
if compute_dtype == torch.float16 and use_4bit:
    major, _ = torch.cuda.get_device_capability()
    if major >= 8:
        print("=" * 80)
        print("Your GPU supports bfloat16: accelerate training with bf16=True")
        print("=" * 80)

# %%
model_name = "mistralai/Mistral-7B-Instruct-v0.1"

# %%
# !sudo pip install -q pynvml

# %%
from pynvml.smi import nvidia_smi
nvsmi = nvidia_smi.getInstance()
nvsmi.DeviceQuery('memory.free, memory.total')
# Out:
# {'gpu': [{'fb_memory_usage': {'total': 16384.0,
#     'free': 15972.9375,
#     'unit': 'MiB'}}]}

# %%
#!df -H

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# del model
# torch.cuda.empty_cache()

# %%
# Load base model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
#     torch_dtype=torch.bfloat16,
    device_map="auto"
)
model.config.use_cache = False
model.config.pretraining_tp = 1
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# Load LLaMA tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True,
                                          # add_eos_token=True,
                                          use_fast=False)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

# %%
max([len(tokenizer.encode(df['fine_tuning_dataset'][i])) for i in range(df.shape[0])])
# Out:
# 1709

# %%
# LoRA configuration
peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    target_modules = ["q_proj", "v_proj"],
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM",
)

# %%
# Set training parameters
training_arguments = TrainingArguments(
    output_dir=output_dir,
    num_train_epochs=num_train_epochs,
    per_device_train_batch_size=per_device_train_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    optim=optim,
    save_steps=save_steps,
#     eval_steps=50, # requires when eval_dataset is defined
#     per_device_eval_batch_size=1, # Batch size for evaluation
#     evaluation_strategy="steps", # requires when eval_dataset is defined
    logging_strategy="steps",
    logging_steps=5,
    learning_rate=learning_rate,
    weight_decay=weight_decay,
    fp16=fp16,
    bf16=bf16,
    max_grad_norm=max_grad_norm,
    max_steps=2000,
    warmup_ratio=warmup_ratio,
    group_by_length=group_by_length,
    lr_scheduler_type=lr_scheduler_type,
    report_to="tensorboard",
#     load_best_model_at_end=True,
#     save_total_limit=1,
#     metric_for_best_model="eval_loss",
#     greater_is_better=False
)

# %%
## Getting FLOPs of model

model_flops = (
  model.floating_point_ops(
    {
       "input_ids": torch.zeros(
           (1, 2048)
      )
    }
  )
  * training_arguments.gradient_accumulation_steps
)

#print(model)
print("Memory footprint", model.get_memory_footprint() / 1e9, "GB")
print("Flops", model_flops / 1e9, "GFLOPs")
# Out:
# Memory footprint 5.185232896 GB
# Flops 87710.798708736 GFLOPs

# %%
train_dataset
# Out:
# Dataset({
#     features: ['fine_tuning_dataset'],
#     num_rows: 65
# })

# %%
#print(torch.cuda.memory_summary(device=None, abbreviated=False))

# %%
# Set supervised fine-tuning parameters
trainer = SFTTrainer(
    model=model,
    train_dataset=train_dataset,
#     eval_dataset=val_dataset,
    peft_config=peft_config,
    dataset_text_field="fine_tuning_dataset",
    max_seq_length=2048,
    tokenizer=tokenizer,
    args=training_arguments,
    packing=packing,
)
# Out:
# Map:   0%|          | 0/65 [00:00<?, ? examples/s]

# %%
# Train model
trainer.train()
# Out:
#     <div>
#
#       <progress value='250' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 250/2000 31:17 < 3:40:51, 0.13 it/s, Epoch 3.83/31]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>0.860600</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.743100</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.542200</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.283000</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.184300</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.140500</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.161600</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.129100</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.145400</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.183200</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.130600</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.150600</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.107100</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.086300</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.094900</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.103500</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.098800</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.069400</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.084900</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.096300</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.082100</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.124100</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.103500</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.095900</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.081400</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.074600</td>
#     </tr>
#     <tr>
#       <td>135</td>
#       <td>0.063400</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.050900</td>
#     </tr>
#     <tr>
#       <td>145</td>
#       <td>0.056300</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.061600</td>
#     </tr>
#     <tr>
#       <td>155</td>
#       <td>0.070800</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.071700</td>
#     </tr>
#     <tr>
#       <td>165</td>
#       <td>0.075200</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.057000</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>0.064900</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.056000</td>
#     </tr>
#     <tr>
#       <td>185</td>
#       <td>0.052500</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.060100</td>
#     </tr>
#     <tr>
#       <td>195</td>
#       <td>0.053100</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.037000</td>
#     </tr>
#     <tr>
#       <td>205</td>
#       <td>0.038900</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.036800</td>
#     </tr>
#     <tr>
#       <td>215</td>
#       <td>0.038500</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.041400</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.046800</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.039800</td>
#     </tr>
#     <tr>
#       <td>235</td>
#       <td>0.044700</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.041900</td>
#     </tr>
#     <tr>
#       <td>245</td>
#       <td>0.047300</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# Fine-tuned model name
#new_model_name = "mistral-ft-peft-v1-lr-64-with-more-data"

# %%
# Save trained model
trainer.model.save_pretrained(new_model)

# %%
trainer.model
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): MistralForCausalLM(
#       (model): MistralModel(
#         (embed_tokens): Embedding(32000, 4096)
#         (layers): ModuleList(
#           (0-31): 32 x MistralDecoderLayer(
#             (self_attn): MistralAttention(
#               (q_proj): Linear4bit(
#                 in_features=4096, out_features=4096, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=64, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=64, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#               (v_proj): Linear4bit(
#                 in_features=4096, out_features=1024, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=64, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=64, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#               (rotary_emb): MistralRotaryEmbedding()
#             )
#             (mlp): MistralMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (act_fn): SiLUActivation()
#             )
#             (input_layernorm): MistralRMSNorm()
#             (post_attention_layernorm): MistralRMSNorm()
#           )
#         )
#         (norm): MistralRMSNorm()
#       )
#       (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
#     )
#   )
# )

# %%
from peft import PeftModel, PeftConfig

# %%
new_model_name = "/data/mistral/query-to-mql/exp-8/oct-30/checkpoint-2000"

# %%
#del model
# del trainer
torch.cuda.empty_cache()

# %%
nvsmi = nvidia_smi.getInstance()
nvsmi.DeviceQuery('memory.free, memory.total')
# Out:
# {'gpu': [{'fb_memory_usage': {'total': 16384.0,
#     'free': 15972.9375,
#     'unit': 'MiB'}}]}

# %%
# del model
torch.cuda.empty_cache()

from peft import AutoPeftModelForCausalLM

model = AutoPeftModelForCausalLM.from_pretrained(new_model_name, device_map="auto", torch_dtype=torch.bfloat16)
model = model.merge_and_unload()
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
query_template_v1 = """Given the context : {context} and date reference: {date_input}, the query: {user_query}, is converted into below shown structured output.
[MQL]
"""

# %%
#model.to('cuda')

# %%
def predict_template_query_v1(user_query):
    inp = query_template_v1.format(context=context,
                                   user_query=user_query,
                                  date_input=date_input)
    _inputs = tokenizer.encode(inp, return_tensors="pt")
    outputs = model.generate(input_ids=_inputs.to('cuda'), max_length= 1700, pad_token_id=tokenizer.eos_token_id)
    output = tokenizer.decode(outputs[0])
    output_new = output.split('[MQL]\n')[1]
    return output_new.split('\n[/MQL]')[0], output
#     return output

# %%
# %%time
user_query = 'show me the bottom 10 segments basis sales'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  show me the bottom 10 segments basis sales
# ----------------------------------------------------------------------------------------------------
# /opt/conda/lib/python3.8/site-packages/transformers/generation/utils.py:2507: UserWarning: Specified kernel cache directory could not be created! This disables kernel caching. Specified directory is /home/mosaic-ai/.cache/torch/kernels. This warning will appear only once per process. (Triggered internally at ../aten/src/ATen/native/cuda/jit_utils.cpp:1442.)
#   next_tokens.tile(eos_token_id_tensor.shape[0], 1).ne(eos_token_id_tensor.unsqueeze(1)).prod(dim=0)
# {'DIMENSION': {'segments': [{'ENTITY': 'Segment', 'RANK': [{'RANK ADJECTIVE': 'bottom', 'RANK VALUE': '10'}]}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - "bottom 10 segments": Dimension (segments) with a ranking adjective "bottom" and a rank value "10"
# - "basis sales": Measure (sales)
#
# Step 2: Match the components to the context
# - "segments" matches the "Segment" entity in the context, which has other names like "segments", "units", and "divisions".
# - "sales" matches the "Sales" entity in the context, which has other names like "sales" and "sale".
#
# Step 3: Convert the components into structured output
# - For the dimension "segments", we create a "DIMENSION" object with the "Segment" entity and add a "RANK" object with the ranking adjective "bottom" and the rank value "10".
# - For the measure "sales", we create a "MEASURE" object with the "Sales" entity.
#
# Step 4: Combine the structured output components
# - We combine the "DIMENSION" and "MEASURE" objects into a single structured output.
#
# Step 5: Check for date components and date reference utilization
# - The query does not have any date components, so the date reference is not utilized in this case.
#
# Rationale:
# - The query asks for the bottom 10 segments based on sales, so we need to identify the relevant dimension and measure from the context and create structured output for them.
# - The context provides the necessary information to match the components in the query to the appropriate entities and create the structured output.
# - Since there are no date components in the query, the date reference is not utilized.
#
# Note: The date reference is utilized when the query involves date-related components like "today", "yesterday", "this week", etc. The date reference provided in the context should be used to generate the structured output for those date-related components.
#
# MQL is the Marshmallow Query Language, which is a language used to convert SQL queries into structured output. It is used in data processing and analysis tasks to extract specific information from large datasets. The structured output is a representation of the data in a format that can be easily processed and analyzed by various applications and systems.</s>
# CPU times: user 42.6 s, sys: 1 s, total: 43.6 s
# Wall time: 43.6 s

# %%
# %%time
user_query = 'top 2 and bottom 3 segments by sales'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  top 2 and bottom 3 segments by sales
# ----------------------------------------------------------------------------------------------------
# {'DIMENSION': {'segments': [{'ENTITY': 'Segment', 'RANK': [{'RANK ADJECTIVE': 'top', 'RANK VALUE': '2'}, {'RANK ADJECTIVE': 'bottom', 'RANK VALUE': '3'}]}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - "top 2": Rank adjective and rank value
# - "bottom 3": Rank adjective and rank value
# - "segments": Dimension (matches with 'Segment' in the context)
# - "by sales": Measure (matches with 'Sales' in the context)
#
# Step 2: Match the components to the context
# - "segments" matches with 'Segment' in the context under 'DIMENSION'
# - "sales" matches with 'Sales' in the context under 'MEASURE'
#
# Step 3: Convert the query into structured output
# - Create a 'DIMENSION' key and add 'segments' as an array with 'Segment' as the ENTITY and the rank adjectives and values as RANK objects.
# - Create a 'MEASURE' key and add 'sales' as an array with 'Sales' as the ENTITY.
#
# Step 4: Check for date components
# - The query does not have any date components, so the date reference is not utilized in this case.
#
# Rationale:
# The query asks for the top 2 and bottom 3 segments by sales. We identified the components in the query and matched them to the context. Then, we created the structured output with the 'DIMENSION' and 'MEASURE' keys, including the rank adjectives and values for the segments. Since there are no date components in the query, the date reference is not used.
#
# Note: The date reference is utilized when the query has date components, such as "today", "yesterday", or a specific date range. In this case, the query does not have any date components, so the date reference is not needed.</s>
# CPU times: user 38.9 s, sys: 944 ms, total: 39.9 s
# Wall time: 39.9 s

# %%
# %%time
user_query = 'top 2 segments and bottom 3 sub-category basis quantity'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  top 2 segments and bottom 3 sub-category basis quantity
# ----------------------------------------------------------------------------------------------------
# {'DIMENSION': {'segments': [{'ENTITY': 'Segment', 'RANK': [{'RANK ADJECTIVE': 'top', 'RANK VALUE': '2'}]}], 'sub-category': [{'ENTITY': 'Sub-Category', 'RANK': [{'RANK ADJECTIVE': 'bottom', 'RANK VALUE': '3'}]}]}, 'MEASURE': {'quantity': [{'ENTITY': 'Quantity'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - "top 2 segments": Rank adjective "top", rank value "2", and entity "segments"
# - "bottom 3 sub-category": Rank adjective "bottom", rank value "3", and entity "sub-category"
# - "basis quantity": Measure "quantity"
#
# Step 2: Match the components to the context
# - "segments" matches the entity "Segment" in the context with other names ['segment', 'segments', 'units', 'divisions'].
# - "sub-category" matches the entity "Sub-Category" in the context with other names ['sub-category', 'sub category', 'categories', 'section'].
# - "quantity" matches the entity "Quantity" in the context with other names ['quantity', 'volume'].
#
# Step 3: Convert the components into structured output
# - For "top 2 segments", create a "DIMENSION" object with "segments" and add a "RANK" object with rank adjective "top" and rank value "2".
# - For "bottom 3 sub-category", create a "DIMENSION" object with "sub-category" and add a "RANK" object with rank adjective "bottom" and rank value "3".
# - For "basis quantity", create a "MEASURE" object with "quantity".
#
# Step 4: Handle date components
# - In this query, there are no date components mentioned, so the date reference {'start_date': '01/01/2020', 'end_date': '15/09/2023'} is not utilized here.
#
# Rationale: The query asks for the top 2 segments and bottom 3 sub-categories based on the quantity. The structured output captures this information by creating "DIMENSION" objects for "segments" and "sub-category" with their respective rank adjectives and rank values, and a "MEASURE" object for "quantity". The date reference is not used in this case as there are no date components in the query.
#
# Note: The structured output is created based on the context and the query components identified in steps 1-3. The date reference is only utilized when there are date components in the query.</s>
# CPU times: user 49.5 s, sys: 1.05 s, total: 50.6 s
# Wall time: 50.6 s

# %%
# %%time
user_query = 'quantity across segments except consumer and corporate in dubai'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  quantity across segments except consumer and corporate in dubai
# ----------------------------------------------------------------------------------------------------
# {'DIMENSION': {'segments': [{'ENTITY': 'Segment'}]}, 'FILTER': {'consumer': [{'ENTITY': 'Consumer', 'EXCLUDE': 'True', 'PARENT': 'Segment'}], 'corporate': [{'ENTITY': 'Corporate', 'EXCLUDE': 'True', 'PARENT': 'Segment'}], 'dubai': [{'ENTITY': 'Dubai', 'PARENT': 'Country'}]}, 'MEASURE': {'quantity': [{'ENTITY': 'Quantity'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - Quantity: Measure
# - Segments: Dimension
# - Consumer: Filter (to be excluded)
# - Corporate: Filter (to be excluded)
# - Dubai: Filter
#
# Step 2: Match the components to the context
# - Quantity: Matches with 'Quantity' in the context
# - Segments: Matches with 'Segment' in the context
# - Consumer: Matches with 'Consumer' in the context (parent: Segment)
# - Corporate: Matches with 'Corporate' in the context (parent: Segment)
# - Dubai: Matches with 'Dubai' in the context (parent: Country)
#
# Step 3: Convert the query into structured output
# - DIMENSION: Add 'Segment' as the dimension
# - FILTER: Add 'Consumer' and 'Corporate' as filters with "EXCLUDE": "True" and their respective parents. Add 'Dubai' as a filter with its parent.
# - MEASURE: Add 'Quantity' as the measure
#
# Step 4: Check for date components
# - The query does not have any date components, so the date reference is not utilized in this case.
#
# Rationale:
# The query asks for the quantity across segments except consumer and corporate in dubai. We identified the components in the query and matched them to the context. Then, we converted the query into a structured output by adding the dimension, filters, and measure. Since there are no date components in the query, the date reference is not utilized.
#
# Note: The date reference is only utilized when the query has date components that need to be converted into a structured output. In this case, the query does not have any date components, so the date reference is not utilized.</s>
# CPU times: user 43.8 s, sys: 972 ms, total: 44.7 s
# Wall time: 44.7 s

# %%
# %%time
user_query = 'in corporate share of phone and binder basis discount'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  in corporate share of phone and binder basis discount
# ----------------------------------------------------------------------------------------------------
# {'DERIVED MEASURE': {'share': [{'APPLIED MEASURE': [{'discount': 'Discount'}], 'ENTITY': 'Ratio', 'RATIO FILTER': ['Phone', 'Binder']}]}, 'FILTER': {'binder': [{'ENTITY': 'Binder', 'PARENT': 'Sub-Category'}], 'corporate': [{'ENTITY': 'Corporate', 'PARENT': 'Segment'}], 'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'discount': [{'ENTITY': 'Discount'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - Corporate: Segment
# - Share: Derived Measure (Ratio)
# - Phone and Binder: Sub-Category
# - Discount: Measure
#
# Step 2: Match the components to the context
# - Corporate: {'ENTITY': 'Corporate', 'other names': ['corporates', 'corporate'], 'parent': 'Segment'}
# - Share: {'ENTITY': 'Ratio', 'other names': ['ratio', 'share', 'contribution', 'percentage', 'proportion', 'contributing']}
# - Phone: {'ENTITY': 'Phone', 'other names': ['phone', 'phones', 'mobile phones'], 'parent': 'Sub-Category'}
# - Binder: {'ENTITY': 'Binder', 'other names': ['binders', 'binder'], 'parent': 'Sub-Category'}
# - Discount: {'ENTITY': 'Discount', 'other names': ['discount', 'discount rate', 'discount value', 'deduction']}
#
# Step 3: Convert the query into a structured output
# - Add the "Corporate" filter to the FILTER section
# - Add the "Phone" and "Binder" filters to the RATIO FILTER section under the "share" derived measure
# - Add the "Discount" measure to the APPLIED MEASURE section under the "share" derived measure
#
# Step 4: Check for date components and utilize the date reference
# - The query does not mention any specific date component, so the date reference is not utilized in this case.
#
# Rationale:
# The query asks for the share of Phone and Binder in the Corporate segment based on the discount. We first identify the components in the query and match them to the context. Then, we structure the output by adding the filters and derived measures accordingly. Since there is no specific date component mentioned in the query, the date reference is not utilized.
#
# Note: The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}. If the query had a specific date component, it would have been utilized in the structured output.</s>
# CPU times: user 53.4 s, sys: 1.05 s, total: 54.4 s
# Wall time: 54.4 s

# %%
# %%time
user_query = 'list of under performing segments'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  list of under performing segments
# ----------------------------------------------------------------------------------------------------
# {'DIMENSION': {'segments': [{'ADJECTIVE': ['under performing'], 'ENTITY': 'Segment', 'RANK': [{'RANK ADJECTIVE': 'bottom', 'RANK VALUE': '1'}], 'TONE': 'negative'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the main components of the query
# - The query asks for a "list of under performing segments."
#
# Step 2: Match the components to the context
# - In the context, we have a 'DIMENSION' with an 'ENTITY' called 'Segment' and its other names as ['segment', 'segments', 'units', 'divisions'].
#
# Step 3: Identify the adjectives and tone
# - The query has an adjective "under performing" which indicates a negative tone.
#
# Step 4: Identify the ranking
# - The query asks for a list, which implies a ranking. Since it's asking for under performing segments, we can assume it's looking for the bottom segments.
#
# Step 5: Convert the query into a structured output
# - Based on the identified components, we can create a structured output with 'DIMENSION', 'ENTITY', 'ADJECTIVE', 'RANK', and 'TONE'.
#
# Step 6: Date components
# - The query does not mention any specific date or time period, so the date reference is not utilized in this case.
#
# Rationale:
# - The query is asking for a list of under performing segments, which indicates a ranking of segments based on their performance. The adjective "under performing" and the negative tone help us understand that we are looking for the bottom segments in terms of performance. Since there is no mention of a specific date or time period in the query, the date reference is not utilized. The structured output is created based on the identified components and their matching context.
#
# Note:
# - The query could have been more specific if it mentioned a specific time period or date range. In that case, the date reference would have been utilized to generate the structured output.
#
# [MQL]
# {
#     "DATE VARIABLE": {
#         "order date": [
#             {
#                 "ENTITY": "Order Date",
#                 "TIME PERIOD": "start_date to end_date"
#             }
#         ]
#     }
# }
# [/MQL]
# the date reference is utilized here as the query mentions a specific time period "start_date to end_date", so the date reference is used to generate the structured output. The date reference is converted into a "TIME PERIOD" in the structured output.</s>
# CPU times: user 44.1 s, sys: 1.02 s, total: 45.1 s
# Wall time: 45.1 s

# %%
# %%time
user_query = 'when was the first time sales of segments was 0'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  when was the first time sales of segments was 0
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'when': [{'CONVERTED TIME ELEMENT': 'when', 'ENTITY': 'Order Date'}]}, 'DIMENSION': {'segments': [{'ENTITY': 'Segment'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales', 'MEASURE CONSTRAINT': [{'COMPARISON VALUE': '0', 'COMPARSION OPERATOR': '='}]}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query asks for "when" which indicates a date variable.
# - The query mentions "sales" which is a measure.
# - The query mentions "segments" which is a dimension.
# - The query specifies a condition for sales to be "0".
#
# Step 2: Match the components to the context
# - "when" can be matched to the "Order Date" entity in the DATE VARIABLE context.
# - "sales" can be matched to the "Sales" entity in the MEASURE context.
# - "segments" can be matched to the "Segment" entity in the DIMENSION context.
#
# Step 3: Convert the date component
# - The query asks for "when" which is matched to the "Order Date" entity in the DATE VARIABLE context.
# - The date reference provided has a start_date and end_date, but they are not needed in this case as the query does not specify any date range. Therefore, the date reference is not utilized here.
#
# Step 4: Convert the measure component
# - The query mentions "sales" which is matched to the "Sales" entity in the MEASURE context.
# - The query specifies a condition for sales to be "0". This is added as a MEASURE CONSTRAINT with a COMPARISON VALUE of "0" and a COMPARISON OPERATOR of "=".
#
# Step 5: Convert the dimension component
# - The query mentions "segments" which is matched to the "Segment" entity in the DIMENSION context.
#
# The structured output is created by combining the converted components from steps 3, 4, and 5.
#
# Rationale:
# - The query asks for the first time sales of segments were 0, so we need to find the order date when sales of segments were 0.
# - The query specifies a condition for sales to be "0", which is added as a MEASURE CONSTRAINT in the structured output.
# - The query mentions "segments" as a dimension, so it is included in the structured output as well.
# - The date reference is not utilized in this case as the query does not specify any date range.
#
# Overall, the structured output captures the essential information from the query and allows for easy analysis and processing.</s>
# CPU times: user 49.3 s, sys: 1.1 s, total: 50.3 s
# Wall time: 50.3 s

# %%
# %%time
user_query = 'sales of segments from beginning'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  sales of segments from beginning
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'beginning': [{'CONVERTED TIME ELEMENT': 'beginning', 'DATE RANGE': '01/01/2020 - 15/09/2023', 'ENTITY': 'Order Date'}]}, 'DIMENSION': {'segments': [{'ENTITY': 'Segment'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query mentions "sales" which can be matched to the "Sales" entity in the MEASURE context.
# - The query mentions "segments" which can be matched to the "Segment" entity in the DIMENSION context.
# - The query mentions "from beginning" which indicates a date range starting from the earliest date available.
#
# Step 2: Match the components to the context
# - "sales" is matched to the "Sales" entity in the MEASURE context.
# - "segments" is matched to the "Segment" entity in the DIMENSION context.
#
# Step 3: Convert the date component
# - The query mentions "from beginning" which indicates a date range starting from the earliest date available. In this case, the start_date in the date reference is '01/01/2020', and the end_date is '15/09/2023'.
# - Since the query asks for data "from beginning", we can use the start_date '01/01/2020' as the beginning of the date range and the end_date '15/09/2023' as the end of the date range.
#
# Step 4: Create the structured output
# - The "DATE VARIABLE" section includes the "Order Date" entity with the date range "01/01/2020 - 15/09/2023" as the converted time element.
# - The "DIMENSION" section includes the "Segment" entity.
# - The "MEASURE" section includes the "Sales" entity.
#
# Rationale:
# - The query asks for sales data of segments from the beginning, so we need to include the "Sales" entity in the MEASURE section and the "Segment" entity in the DIMENSION section.
# - The date component "from beginning" is converted using the date reference provided, resulting in a date range of "01/01/2020 - 15/09/2023" for the "Order Date" entity in the DATE VARIABLE section.
# - The "Order Date" entity is used in the query to specify the date range, so it is included in the structured output with the converted date range.
#
# The structured output captures the essential information from the query, including the MEASURE, DIMENSION, and DATE VARIABLE components. The date component is converted using the date reference provided, ensuring that the query is answered accurately.</s>
# CPU times: user 51.6 s, sys: 1.04 s, total: 52.6 s
# Wall time: 52.6 s

# %%
# %%time
user_query = 'sales in 20/01/2020'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  sales in 20/01/2020
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'20/01/2020': [{'CONVERTED TIME ELEMENT': '2020-01-20', 'DATE RANGE': '2020/01/20 - 2020/01/20', 'ENTITY': 'Order Date'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query mentions "sales" which is a measure.
# - The query also mentions "20/01/2020" which is a date component.
#
# Step 2: Match the components to the context
# - In the context, "sales" can be matched to the "Sales" entity under the "MEASURE" category.
# - The date component "20/01/2020" needs to be converted to a date format.
#
# Step 3: Convert the date component
# - The date component "20/01/2020" can be converted to "2020-01-20" using the date reference provided.
# - The date reference specifies a start date of "01/01/2020" and an end date of "15/09/2023". However, in this case, we only need the start date, so "01/01/2020" is used.
#
# Step 4: Create the structured output
# - The structured output should include the identified components and their corresponding categories from the context.
# - For the measure "sales", the output should include the "Sales" entity under the "MEASURE" category.
# - For the date component "20/01/2020", the output should include the "Order Date" entity under the "DATE VARIABLE" category with the converted date "2020-01-20".
#
# Rationale:
# - The query asks for sales in a specific date, so the structured output should include both the measure "sales" and the date component "20/01/2020" converted to a date format.
# - The date reference is used to convert the date component to a date format.
# - The context is used to identify the components in the query and their corresponding categories.
#
# Overall, the structured output provides the required information in a structured format that can be easily processed by a data analysis system.</s>
# CPU times: user 42.6 s, sys: 1.02 s, total: 43.6 s
# Wall time: 43.6 s

# %%
# %%time
user_query = 'sales in last one and half years'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  sales in last one and half years
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'last one and half years': [{'CONVERTED TIME ELEMENT': 'last one and half years', 'DATE RANGE': '2022/03/15 - 2023/09/15', 'ENTITY': 'Order Date'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query mentions "sales" which is a measure.
# - The query also mentions "last one and half years" which is a date variable.
#
# Step 2: Match the components to the context
# - "sales" can be matched to the "Sales" entity in the context under MEASURE.
# - "last one and half years" can be matched to the "Order Date" entity in the context under DATE VARIABLE.
#
# Step 3: Convert the date component
# - The date component "last one and half years" needs to be converted into a date range.
# - To do this, we need to calculate the start date and end date for the range.
# - The end date is given in the date reference as '15/09/2023'.
# - To find the start date, we need to go back one and a half years from the end date.
# - One and a half years is equivalent to 18 months.
# - Subtracting 18 months from the end date (15/09/2023) gives us the start date (15/03/2022).
#
# Step 4: Create the structured output
# - The structured output should include the identified components and their corresponding entities from the context.
# - For the measure "sales", the output should include the "Sales" entity.
# - For the date component "last one and half years", the output should include the "Order Date" entity and the calculated date range (2022/03/15 - 2023/09/15).
#
# Rationale:
# - The query asks for sales in the last one and half years, so we need to identify the measure "sales" and the date component "last one and half years" from the query.
# - We then match these components to the context to find the corresponding entities.
# - The date component needs to be converted into a date range using the date reference provided.
# - Finally, we create the structured output using the identified components and their corresponding entities from the context.
#
# The structured output provides a clear and organized representation of the query, making it easier to process and analyze the data.</s>
# CPU times: user 44.1 s, sys: 988 ms, total: 45.1 s
# Wall time: 45.1 s

# %%
# %%time
user_query = 'trend of sales in dubai now'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  trend of sales in dubai now
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'trend': [{'CONVERTED TIME ELEMENT': 'now', 'DATE RANGE': '2023/09/15 - 2023/09/15', 'ENTITY': 'Order Date'}]}, 'FILTER': {'dubai': [{'ENTITY': 'Dubai', 'PARENT': 'Country'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query mentions "trend of sales" which refers to the measure 'Sales' and the date variable 'Order Date'.
# - The query also mentions "in Dubai" which refers to the filter 'Dubai'.
#
# Step 2: Match components to the context
# - 'Sales' can be matched to the measure 'Sales' in the context.
# - 'Order Date' can be matched to the date variable 'Order Date' in the context.
# - 'Dubai' can be matched to the filter 'Dubai' in the context.
#
# Step 3: Convert date components
# - The query mentions "now" which refers to the current date. Since the end_date in the date reference is '15/09/2023', we can assume that "now" refers to this date.
# - The date range for the trend will be a single day, i.e., '2023/09/15 - 2023/09/15'.
#
# Step 4: Create structured output
# - For the measure 'Sales', add the entity 'Sales' to the structured output.
# - For the filter 'Dubai', add the entity 'Dubai' with its parent 'Country' to the structured output.
# - For the date variable 'Order Date', add the converted time element 'now', the date range '2023/09/15 - 2023/09/15', and the entity 'Order Date' to the structured output.
#
# Note: The date reference 'start_date' is not utilized in this conversion as the query only asks for the trend of sales "now", which corresponds to the 'end_date'.
#
# Rationale:
# - The query asks for the trend of sales in Dubai, so we need to identify the measure 'Sales', the filter 'Dubai', and the date variable 'Order Date' from the context.
# - We then convert the date component 'now' to a single day date range '2023/09/15 - 2023/09/15' based on the date reference 'end_date'.
# - Finally, we create the structured output with the identified components and their corresponding entities from the context.
#
# The structured output provides a clear and organized representation of the query, making it easier for downstream processing and analysis.</s>
# CPU times: user 49.8 s, sys: 988 ms, total: 50.7 s
# Wall time: 50.8 s

# %%
# %%time
user_query = 'sales in the week of 01 March 2022'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  sales in the week of 01 March 2022
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'week of 01 March 2022': [{'CONVERTED TIME ELEMENT': 'week of 1 March 2022', 'DATE RANGE': '2022/02/28 - 2022/03/06', 'ENTITY': 'Order Date'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query mentions "sales" which is a measure.
# - The query also mentions "week of 01 March 2022" which is a date component.
#
# Step 2: Match components to the context
# - In the context, "sales" can be matched to the "Sales" entity under the "MEASURE" category.
# - The date component "week of 01 March 2022" needs to be converted to a date range.
#
# Step 3: Convert date component
# - The date component "week of 01 March 2022" refers to the week starting from 1st March 2022.
# - To find the date range for this week, we need to identify the start and end dates of the week.
# - 1st March 2022 is a Tuesday, so the week starts on the previous Monday, which is 28th February 2022.
# - The week ends on the following Sunday, which is 6th March 2022.
# - Therefore, the date range for the week of 01 March 2022 is "2022/02/28 - 2022/03/06".
#
# Step 4: Check date reference
# - The date range "2022/02/28 - 2022/03/06" falls within the date reference provided, which is from "01/01/2020" to "15/09/2023".
# - Since the date range is within the date reference, no further adjustments are needed.
#
# Step 5: Create structured output
# - The structured output is created by combining the matched components and the converted date component.
# - The "MEASURE" component is represented by the "Sales" entity.
# - The "DATE VARIABLE" component is represented by the "Order Date" entity and the converted date range "2022/02/28 - 2022/03/06".
#
# The structured output is generated based on the identified components and their corresponding matches in the context, as well as the converted date component. The date reference is checked to ensure the date range falls within the specified limits.
#
# Rationale:
# - The query asks for sales in the week of 01 March 2022.
# - The context provides the necessary components to create a structured output, including the "Sales" entity for the measure and the "Order Date" entity for the date variable.
# - The date component is converted to a date range by identifying the start and end dates of the week.
# - The date reference is checked to ensure the date range falls within the specified limits.
# - The structured output is created by combining the matched components and the converted date component.
#
# Overall, the structured output is generated by identifying the relevant components in the query and context, and converting the date component to a date range that falls within the date reference. This allows for a structured representation of the query that can be easily analyzed and processed.</s>
# CPU times: user 58.2 s, sys: 892 ms, total: 59.1 s
# Wall time: 59.1 s

# %%
# %%time
user_query = 'top most selling segments in 2020 vs 2021'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  top most selling segments in 2020 vs 2021
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'2020 vs 2021': [{'CONVERTED TIME ELEMENT': '2020 vs 2021', 'DATE RANGE': '2020/01/01 - 2020/12/31, 2021/01/01 - 2021/12/31', 'ENTITY': 'Order Date'}]}, 'DIMENSION': {'segments': [{'ENTITY': 'Segment', 'RANK': [{'RANK ADJECTIVE': 'top', 'RANK VALUE': '1'}]}]}, 'MEASURE': {'selling': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - "top most selling": Rank adjective "top" and Measure "Sales"
# - "segments": Dimension "Segment"
# - "2020 vs 2021": Date Variable "Order Date" with a comparison between two time periods
#
# Step 2: Match the components to the context
# - "top most selling" matches with the Measure "Sales"
# - "segments" matches with the Dimension "Segment"
# - "2020 vs 2021" matches with the Date Variable "Order Date"
#
# Step 3: Convert the date component
# - "2020 vs 2021" is a comparison between two time periods, so we need to create two date ranges for each year.
# - The date reference is not utilized here as the query specifically mentions the years 2020 and 2021.
#
# Step 4: Create the structured output
# - For the Measure, we include "Sales" as the ENTITY.
# - For the Dimension, we include "Segment" as the ENTITY and specify the rank adjective "top" and rank value "1".
# - For the Date Variable, we include "Order Date" as the ENTITY and create two date ranges for 2020 and 2021.
#
# The structured output is created based on the identified components and their matches in the context.
#
# Note: The date reference is not utilized here as the query specifically mentions the years 2020 and 2021.
#
# Rationale:
# - The query asks for the top selling segments in 2020 vs 2021, so we need to include the Dimension "Segment" and the Measure "Sales" in the structured output.
# - The date component "2020 vs 2021" is matched with the Date Variable "Order Date" in the context.
# - Since the date reference is not utilized here, we create two date ranges for 2020 and 2021 based on the query specifications.
#
# The structured output is created by combining the identified components and their matches in the context. The date reference is not utilized as the query specifically mentions the years 2020 and 2021.</s>
# CPU times: user 53.8 s, sys: 984 ms, total: 54.7 s
# Wall time: 54.8 s

# %%
# %%time
user_query = 'sales from 100 to 200'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  sales from 100 to 200
# ----------------------------------------------------------------------------------------------------
# {'MEASURE': {'sales': [{'ENTITY': 'Sales', 'MEASURE CONSTRAINT': [{'COMPARISON VALUE': '100', 'COMPARSION OPERATOR': '>='}, {'COMPARISON VALUE': '200', 'COMPARSION OPERATOR': '<='}]}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query mentions "sales" which is a measure.
# - The query also mentions a range "from 100 to 200" which is a constraint on the sales measure.
#
# Step 2: Match the components to the context
# - In the context, we can find the "Sales" entity under the 'MEASURE' category with other names like 'sales' and 'sale'.
# - There is no date component mentioned in the query, so the date reference is not utilized here.
#
# Step 3: Convert the query into a structured output
# - Since the query is about sales, we can use the "Sales" entity from the context.
# - The range "from 100 to 200" is a constraint on the sales measure. We can represent this constraint using two comparison operators: ">=" for the lower bound (100) and "<=" for the upper bound (200).
#
# Rationale:
# - The query is asking for sales data within a specific range (100 to 200). To represent this in a structured output, we need to identify the measure (Sales) and apply the constraints on it using comparison operators.
# - The date reference is not utilized in this case as there is no date component mentioned in the query.
#
# Overall, the structured output represents the query by identifying the measure (Sales) and applying the constraints on it using comparison operators.
#
# [MQL]
# {
#     "MEASURE": {
#         "sales": [
#             {
#                 "ENTITY": "Sales",
#                 "MEASURE CONSTRAINT": [
#                     {
#                         "COMPARISON VALUE": "100",
#                         "COMPARSION OPERATOR": ">="
#                     },
#                     {
#                         "COMPARISON VALUE": "200",
#                         "COMPARSION OPERATOR": "<="
#                     }
#                 ]
#             }
#         ]
#     }
# }
# [/MQL]
# the date reference is not utilized here as there is no date component mentioned in the query.</s>
# CPU times: user 43.8 s, sys: 1.05 s, total: 44.9 s
# Wall time: 44.9 s

# %%
# %%time
user_query = 'sales from 2021 to 2023'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  sales from 2021 to 2023
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'from': '2021/01/01', 'to': '2023/09/15'}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query mentions "sales" which is a measure.
# - The query also mentions "from 2021 to 2023" which is a date range.
#
# Step 2: Match the components to the context
# - In the context, "sales" can be matched to the "Sales" entity under the "MEASURE" category.
# - The date range "from 2021 to 2023" needs to be converted into a date format that can be utilized by the date reference.
#
# Step 3: Convert the date range
# - The date range "from 2021 to 2023" can be converted into "2021/01/01" to "2023/09/15" using the date reference provided.
# - The start date "2021/01/01" is chosen as the beginning of the date range, and the end date "2023/09/15" is chosen as the end of the date range.
#
# Step 4: Create the structured output
# - The structured output should include the "MEASURE" and "DATE VARIABLE" categories.
# - Under the "MEASURE" category, the "sales" entity is included as a list with the "Sales" entity.
# - Under the "DATE VARIABLE" category, the "from" and "to" keys are included with their respective date values.
#
# Rationale:
# - The query asks for sales data within the date range "from 2021 to 2023".
# - The context provides information about the measure "sales" and its different entities.
# - The date reference is utilized to convert the date range into a date format that can be utilized by the structured output.
# - The structured output is created by including the "MEASURE" and "DATE VARIABLE" categories with their respective components.
#
# The structured output is created by including the "MEASURE" and "DATE VARIABLE" categories with their respective components. The date range "from 2021 to 2023" is converted into a date format that can be utilized by the date reference provided. The query asks for sales data within the date range "from 2021 to 2023", and the context provides information about the measure "sales" and its different entities.
#
# The structured output is created by including the "MEASURE" and "DATE VARIABLE" categories with their respective components. The date reference is utilized to convert the date range into a date format that can be utilized by the structured output. The rationale used to achieve the structured output is based on the components in the query and their corresponding matches in the context, as well as the date reference provided.</s>
# CPU times: user 49.7 s, sys: 1.04 s, total: 50.8 s
# Wall time: 50.8 s

# %%
# %%time
user_query = 'what is purchase across segments'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  what is purchase across segments
# ----------------------------------------------------------------------------------------------------
# {'DIMENSION': {'segments': [{'ENTITY': 'Segment', 'RANK': [{'RANK ADJECTIVE': '', 'RANK VALUE': ''}]}]}, 'MEASURE': {'purchase': [{'ENTITY': 'Purchase Vol', 'MEASURE CONSTRAINT': [{'COMPARISON VALUE': '', 'COMPARSION OPERATOR': ''}]}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query asks for "purchase" which can be matched to the context as "Purchase Vol".
# - The query mentions "across segments" which can be matched to the context as "Segment".
#
# Step 2: Match the components to the context
# - "Purchase Vol" is a measure in the context, so it will be placed under the "MEASURE" section in the structured output.
# - "Segment" is a dimension in the context, so it will be placed under the "DIMENSION" section in the structured output.
#
# Step 3: Convert the components into structured output format
# - For "Purchase Vol", we create an entry under "MEASURE" with the ENTITY as "Purchase Vol" and no constraints since the query doesn't specify any comparison value or operator.
# - For "Segment", we create an entry under "DIMENSION" with the ENTITY as "Segment" and no rank value or rank adjective since the query doesn't ask for any ranking.
#
# Step 4: Handling date components
# - The query does not mention any specific date or time period, so the date reference is not utilized in this case.
#
# Rationale:
# - The query asks for the purchase value across segments, so we need to include "Purchase Vol" as a measure and "Segment" as a dimension in the structured output.
# - There is no specific date or time period mentioned in the query, so the date reference is not utilized.
#
# Overall, the structured output is created based on the identified components in the query and their corresponding matches in the context, without considering the date reference.
#
# Note: The date reference is only utilized when the query specifically mentions a date or time period. In this case, the query does not mention any date or time period, so the date reference is not utilized.</s>
# CPU times: user 41.2 s, sys: 1.02 s, total: 42.2 s
# Wall time: 42.2 s

# %%
# %%time
user_query = 'discount rate of phone and binders'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  discount rate of phone and binders
# ----------------------------------------------------------------------------------------------------
# {'FILTER': {'binders': [{'ENTITY': 'Binder', 'PARENT': 'Sub-Category'}], 'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'discount rate': [{'ENTITY': 'Discount', 'MEASURE CONSTRAINT': [{'COMPARISON VALUE': '', 'COMPARSION OPERATOR': ''}]}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query mentions "discount rate", which is a measure.
# - The query also mentions "phone" and "binders", which are filters.
#
# Step 2: Match components to the context
# - "discount rate" can be matched to the "Discount" entity in the context.
# - "phone" can be matched to the "Phone" entity in the context, which has a parent "Sub-Category".
# - "binders" can be matched to the "Binder" entity in the context, which also has a parent "Sub-Category".
#
# Step 3: Convert components into structured output
# - For the measure "discount rate", we add the "Discount" entity to the MEASURE section of the structured output.
# - For the filter "phone", we add the "Phone" entity with its parent "Sub-Category" to the FILTER section of the structured output.
# - For the filter "binders", we add the "Binder" entity with its parent "Sub-Category" to the FILTER section of the structured output.
#
# Step 4: Check for date components
# - The query does not mention any date components, so we do not need to utilize the date reference in this case.
#
# Rationale:
# - The query asks for the discount rate of phone and binders, which can be achieved by identifying the relevant measure and filters from the context and adding them to the structured output.
# - The context provides the necessary information to match the components in the query to their corresponding entities and parents.
# - Since the query does not mention any date components, the date reference is not utilized in the structured output.
#
# Note:
# - The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}.
# - The query asks for the discount rate of phone and binders, which do not have any date components mentioned, so the date reference is not utilized in the structured output.
# - The structured output is created based on the identified components in the query and their corresponding entities and parents in the context.
# - The measure "discount rate" is added to the MEASURE section of the structured output, while the filters "phone" and "binders" are added to the FILTER section with their respective parent entities.
# - The date reference is not utilized in this case as the query does not mention any date components.</s>
# CPU times: user 50.1 s, sys: 1.07 s, total: 51.1 s
# Wall time: 51.1 s

# %%
# %%time
user_query = 'discount rate of overall sub-category in corporate'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  discount rate of overall sub-category in corporate
# ----------------------------------------------------------------------------------------------------
# {'DIMENSION': {'sub-category': [{'ENTITY': 'Sub-Category', 'RANK': [{'RANK ADJECTIVE': '', 'RANK VALUE': ''}]}]}, 'FILTER': {'corporate': [{'ENTITY': 'Corporate', 'PARENT': 'Segment'}]}, 'MEASURE': {'discount rate': [{'ENTITY': 'Discount', 'MEASURE CONSTRAINT': [{'COMPARISON VALUE': '', 'COMPARSION OPERATOR': ''}]}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query mentions "discount rate", which is a measure.
# - It also mentions "overall sub-category", which is a dimension.
# - The query specifies "corporate", which is a filter.
#
# Step 2: Match the components to the context
# - "discount rate" can be matched to the "Discount" entity in the context.
# - "overall sub-category" can be matched to the "Sub-Category" entity in the context.
# - "corporate" can be matched to the "Corporate" entity in the context, which has a parent "Segment".
#
# Step 3: Convert the components into structured output
# - For the dimension, we have "Sub-Category" with no rank specified.
# - For the filter, we have "Corporate" with a parent "Segment".
# - For the measure, we have "Discount" with no comparison value or operator specified.
#
# Step 4: Consider the date reference
# - The date reference provided is not utilized in this query, as there is no mention of any date-related component in the query.
#
# Rationale:
# The query asks for the discount rate of overall sub-category in the corporate segment. We identified the components in the query and matched them to the context. Then, we converted these components into a structured output format. The date reference was not utilized in this case, as the query did not mention any date-related component.
#
# Note: The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}. It is a uni-directional date reference, meaning it only has a start date and no end date specified. In this query, there is no mention of any date-related component, so the date reference is not utilized.</s>
# CPU times: user 44.8 s, sys: 1.08 s, total: 45.9 s
# Wall time: 45.9 s

# %%
# %%time
user_query = 'maximum sales of phone for consumer segment'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  maximum sales of phone for consumer segment
# ----------------------------------------------------------------------------------------------------
# {'DIMENSION': {'segment': [{'ENTITY': 'Segment', 'RANK': [{'RANK ADJECTIVE': '', 'RANK VALUE': ''}]}]}, 'FILTER': {'consumer': [{'ENTITY': 'Consumer', 'PARENT': 'Segment'}], 'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'sales': [{'ADJECTIVE': ['maximum'], 'ENTITY': 'Sales', 'MEASURE CONSTRAINT': [{'COMPARISON VALUE': '', 'COMPARSION OPERATOR': ''}], 'TONE': 'positive'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - "maximum sales": Measure (Sales) with an adjective "maximum"
# - "phone": Filter (Phone)
# - "consumer segment": Filter (Consumer)
#
# Step 2: Match the components to the context
# - "maximum sales": Matched to "Sales" in the context with the adjective "maximum"
# - "phone": Matched to "Phone" in the context, which is a child of "Sub-Category"
# - "consumer segment": Matched to "Consumer" in the context, which is a child of "Segment"
#
# Step 3: Convert the components into structured output
# - "maximum sales": Add "Sales" as a measure with the adjective "maximum" and a positive tone
# - "phone": Add "Phone" as a filter with its parent "Sub-Category"
# - "consumer segment": Add "Consumer" as a filter with its parent "Segment"
#
# Step 4: Check for date components
# - The query does not have any date components, so the date reference is not utilized in this case.
#
# Rationale:
# - The query asks for the maximum sales of phones for the consumer segment. This requires identifying the measure (Sales) with an adjective (maximum), and applying filters for the phone sub-category and the consumer segment.
# - The context provides the necessary information to match the components in the query to their corresponding entities and parents.
# - Since there are no date components in the query, the date reference is not utilized in the structured output.
#
# Overall, the structured output captures the essential information from the query by identifying the measure, filters, and their respective parents based on the context.</s>
# CPU times: user 46.6 s, sys: 1.08 s, total: 47.7 s
# Wall time: 47.7 s

# %%
# %%time
user_query = 'forecast of sales'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# {'MEASURE': {'sales': [{'ENTITY': 'Sales', 'MEASURE CONSTRAINT': [{'COMPARISON VALUE': '', 'COMPARSION OPERATOR': ''}]}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query is "forecast of sales". The main component here is "sales".
#
# Step 2: Match the components to the context
# - In the context, we can find "Sales" under the "MEASURE" category with other names such as "sales" and "sale". So, we can match the "sales" component in the query to the "Sales" entity in the context.
#
# Step 3: Identify the date component in the query
# - The query does not have any explicit date component mentioned. However, since it is a forecast, we can assume that the forecast is for the future period after the end_date mentioned in the date reference.
#
# Step 4: Utilize the date reference
# - The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}. Since the query is about forecasting sales, we can assume that the forecast is for the period after the end_date. However, the exact future period is not specified in the query, so we cannot include a specific date range in the structured output. Therefore, the date reference is not utilized in the structured output.
#
# Step 5: Convert the query into a structured output
# - Based on the identified components and their matching in the context, we can create the structured output. The main component is "Sales", which is a measure. We can create a "MEASURE" dictionary with "sales" as the key and an array containing the "Sales" entity as the value. Since there are no specific constraints or comparisons mentioned in the query, we can leave the "MEASURE CONSTRAINT" array empty.
#
# Rationale:
# - The query is asking for a forecast of sales, which is a measure in the context. We have identified the "Sales" entity in the context and created a structured output with the "MEASURE" dictionary containing the "sales" key and the "Sales" entity as the value. The date reference is not utilized in the structured output as the query does not specify an exact future period for the forecast.
#
# The structured output is created based on the identified components in the query and their matching in the context. The date reference is not utilized as the query does not specify an exact future period for the forecast.</s>
# CPU times: user 43 s, sys: 1.06 s, total: 44 s
# Wall time: 44 s

# %%
# %%time
user_query = 'quantity across segments except consumer'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  quantity across segments except consumer
# ----------------------------------------------------------------------------------------------------

# %%
# %%time
user_query = 'which segment has highest purchase'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  which segment has highest purchase
# ----------------------------------------------------------------------------------------------------
# {'DIMENSION': {'segment': [{'ENTITY': 'Segment', 'RANK': [{'RANK ADJECTIVE': 'top', 'RANK VALUE': '1'}]}]}, 'MEASURE': {'purchase': [{'ADJECTIVE': ['highest'], 'ENTITY': 'Purchase Vol', 'MEASURE CONSTRAINT': [{'COMPARISON VALUE': '', 'COMPARSION OPERATOR': ''}], 'TONE': 'positive'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query asks for the segment with the highest purchase.
# - Components: segment, highest, purchase
#
# Step 2: Match the components to the context
# - Segment: Found in the context under 'DIMENSION' with the ENTITY 'Segment'
# - Purchase: Found in the context under 'MEASURE' with the ENTITY 'Purchase Vol'
# - Highest: This is an adjective that indicates a ranking or comparison.
#
# Step 3: Convert the query into structured output
# - Since the query is asking for the segment with the highest purchase, we need to include the 'Segment' dimension in the output.
# - The 'Purchase Vol' measure is the main focus of the query, so it should be included in the output as well.
# - The adjective 'highest' indicates a ranking, so we need to include a RANK component in the output. In this case, we are looking for the top 1 segment.
#
# Step 4: Handle the date components
# - The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}.
# - However, the query does not mention any specific date or time period, so the date reference is not utilized in the structured output.
#
# Rationale:
# - The query is asking for the segment with the highest purchase, which is a ranking based on the measure of purchase volume.
# - We have identified the relevant components from the query and matched them to the context.
# - The structured output is created based on the identified components, including the dimension and measure.
# - The date reference is not utilized in this case as the query does not mention any specific date or time period.
#
# Overall, the structured output is created by identifying the relevant components in the query, matching them to the context, and including the dimension and measure in the output. The date reference is not utilized in this case.
#
# Note: The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}. However, the query does not mention any specific date or time period, so the date reference is not utilized in the structured output.</s>
# CPU times: user 50 s, sys: 1.02 s, total: 51 s
# Wall time: 51 s

# %%
# %%time
user_query = 'top 2 segments basis discount'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  top 2 segments basis discount
# ----------------------------------------------------------------------------------------------------
# {'DIMENSION': {'segments': [{'ENTITY': 'Segment', 'RANK': [{'RANK ADJECTIVE': 'top', 'RANK VALUE': '2'}]}]}, 'MEASURE': {'discount': [{'ENTITY': 'Discount'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query mentions "top 2 segments" which indicates a ranking and a dimension.
# - The query also mentions "basis discount" which indicates a measure.
#
# Step 2: Match the components to the context
# - In the context, "segments" can be matched to the "Segment" entity under the "DIMENSION" category.
# - "discount" can be matched to the "Discount" entity under the "MEASURE" category.
#
# Step 3: Convert the query components into structured output
# - For the dimension "segments", we need to include the "ENTITY" as "Segment" and the ranking information as "RANK" with "RANK ADJECTIVE" as "top" and "RANK VALUE" as "2".
# - For the measure "discount", we need to include the "ENTITY" as "Discount".
#
# Step 4: Check for date components and utilize date reference if needed
# - The query does not mention any date components, so the date reference is not utilized in this case.
#
# Rationale:
# - The query asks for the top 2 segments based on the discount. To answer this, we need to identify the relevant dimension and measure from the context and include them in the structured output.
# - The dimension "segments" is matched to the "Segment" entity, and the measure "discount" is matched to the "Discount" entity.
# - Since the query does not mention any date components, the date reference is not utilized in the structured output.
#
# Overall, the structured output is created by identifying the relevant components in the query and matching them to the context, then converting them into the required format.
#
# Note: The context and date reference provided are for demonstration purposes only and may not be accurate or complete for all scenarios.
#
# [MQL]
# {
#     "DIMENSION": {
#         "segments": [
#             {
#                 "ENTITY": "Segment",
#                 "RANK": [
#                     {
#                         "RANK ADJECTIVE": "top",
#                         "RANK VALUE": "2"
#                     }
#                 ]
#             }
#         ]
#     },
#     "MEASURE": {
#         "discount": [
#             {
#                 "ENTITY": "Discount"
#             }
#         ]
#     }
# }
# [/MQL]</s>
# CPU times: user 46.8 s, sys: 1 s, total: 47.8 s
# Wall time: 47.8 s

# %%
# %%time
user_query = 'binder share of discount by consumer'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# {'DERIVED MEASURE': {'share': [{'APPLIED MEASURE': [{'discount': 'Discount'}], 'DERIVED MEASURE CONSTRAINT': [{'COMPARISON VALUE': '', 'COMPARSION OPERATOR': ''}], 'ENTITY': 'Ratio', 'RATIO FILTER': ['binder']}]}, 'FILTER': {'binder': [{'ENTITY': 'Binder', 'PARENT': 'Sub-Category'}], 'consumer': [{'ENTITY': 'Consumer', 'PARENT': 'Segment'}]}, 'MEASURE': {'discount': [{'ENTITY': 'Discount', 'MEASURE CONSTRAINT': [{'COMPARISON VALUE': '', 'COMPARSION OPERATOR': ''}]}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - Binder: Sub-Category
# - Share: Derived Measure (Ratio)
# - Discount: Measure
# - Consumer: Segment (Filter)
#
# Step 2: Match the components to the context
# - Binder: Matches with "Binder" in the context under FILTER with parent "Sub-Category"
# - Share: Matches with "Ratio" in the context under DERIVED MEASURE
# - Discount: Matches with "Discount" in the context under MEASURE
# - Consumer: Matches with "Consumer" in the context under FILTER with parent "Segment"
#
# Step 3: Convert the query into structured output
# - Add "Binder" as a filter with its ENTITY and PARENT details from the context
# - Add "Consumer" as a filter with its ENTITY and PARENT details from the context
# - Add "Discount" as a measure with its ENTITY details from the context
# - Add "Ratio" as a derived measure with its ENTITY details from the context, and specify that it is applied to the "Discount" measure. Also, add "Binder" as a ratio filter.
#
# Step 4: Convert the date components
# - In this query, there is no mention of any date component or time period. Therefore, the date reference {'start_date': '01/01/2020', 'end_date': '15/09/2023'} is not utilized in the structured output.
#
# Rationale:
# The query asks for the share of binder in terms of discount by consumer. To answer this, we need to identify the relevant components in the query and match them to the context. Then, we can convert these components into a structured output format. Since there is no date component mentioned in the query, the date reference is not utilized.
#
# The structured output shows the derived measure "Ratio" with its applied measure "Discount" and the filter "Binder" and "Consumer". This helps in understanding the relationship between the share, discount, binder, and consumer segments.
#
# Overall, the structured output provides a clear and organized representation of the query, making it easier to analyze and interpret the data.</s>
# CPU times: user 57 s, sys: 1.01 s, total: 58 s
# Wall time: 58 s

# %%
# %%time
user_query = 'binder and phone share basis sales for corporate'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  binder and phone share basis sales for corporate
# ----------------------------------------------------------------------------------------------------
# {'DERIVED MEASURE': {'share': [{'APPLIED MEASURE': [{'sales': 'Sales'}], 'DERIVED MEASURE CONSTRAINT': [{'COMPARISON VALUE': '', 'COMPARSION OPERATOR': ''}], 'ENTITY': 'Ratio', 'RATIO FILTER': ['Binder', 'Phone']}]}, 'FILTER': {'binder': [{'ENTITY': 'Binder', 'PARENT': 'Sub-Category'}], 'corporate': [{'ENTITY': 'Corporate', 'PARENT': 'Segment'}], 'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - Binder
# - Phone
# - Share
# - Sales
# - Corporate
#
# Step 2: Match the components to the context
# - Binder: Sub-Category (Filter)
# - Phone: Sub-Category (Filter)
# - Share: Ratio (Derived Measure)
# - Sales: Sales (Measure)
# - Corporate: Segment (Filter)
#
# Step 3: Convert the query into structured output
# - Since the query is asking for the share of binder and phone sales for the corporate segment, we need to calculate the ratio of sales for these sub-categories within the corporate segment.
# - To do this, we first apply the filters for Binder, Phone, and Corporate to the data.
# - Next, we calculate the share (Ratio) using the Sales measure for the filtered data.
# - The structured output will have the Derived Measure (Ratio) with the Applied Measure (Sales) and the Ratio Filter (Binder, Phone), along with the Filter entities (Binder, Phone, Corporate).
#
# Step 4: Utilize the date reference
# - In this case, the query does not mention any specific date or time period, so the date reference ('start_date': '01/01/2020', 'end_date': '15/09/2023') is not utilized in the structured output.
#
# Rationale:
# - The query is asking for the share of binder and phone sales within the corporate segment. We need to calculate the ratio of sales for these sub-categories within the corporate segment.
# - To do this, we apply the filters for Binder, Phone, and Corporate to the data.
# - The structured output will have the Derived Measure (Ratio) with the Applied Measure (Sales) and the Ratio Filter (Binder, Phone), along with the Filter entities (Binder, Phone, Corporate).
# - The date reference is not utilized in this case as the query does not mention any specific date or time period.
#
# Note: The above structured output is just an example and may not be the actual output for a specific data set. The conversion process may vary depending on the specific data and query.</s>
# CPU times: user 53.8 s, sys: 1.02 s, total: 54.8 s
# Wall time: 54.8 s

# %%
# %%time
user_query = 'in corporate, share of phone and binder basis discount'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  in corporate, share of phone and binder basis discount
# ----------------------------------------------------------------------------------------------------
# {'DERIVED MEASURE': {'share': [{'APPLIED MEASURE': [{'discount': 'Discount'}], 'DERIVED MEASURE CONSTRAINT': [{'COMPARISON VALUE': '', 'COMPARSION OPERATOR': ''}], 'ENTITY': 'Ratio', 'RATIO FILTER': ['Phone', 'Binder']}]}, 'FILTER': {'binder': [{'ENTITY': 'Binder', 'PARENT': 'Sub-Category'}], 'corporate': [{'ENTITY': 'Corporate', 'PARENT': 'Segment'}], 'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'discount': [{'ENTITY': 'Discount', 'MEASURE CONSTRAINT': [{'COMPARISON VALUE': '', 'COMPARSION OPERATOR': ''}]}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - Corporate: Segment
# - Share: Derived Measure (Ratio)
# - Phone and Binder: Sub-Category
# - Discount: Measure
#
# Step 2: Match the components to the context
# - Corporate: {'ENTITY': 'Corporate', 'other names': ['corporates', 'corporate'], 'parent': 'Segment'}
# - Share: {'ENTITY': 'Ratio', 'other names': ['ratio', 'share', 'contribution', 'percentage', 'proportion', 'contributing']}
# - Phone: {'ENTITY': 'Phone', 'other names': ['phone', 'phones', 'mobile phones'], 'parent': 'Sub-Category'}
# - Binder: {'ENTITY': 'Binder', 'other names': ['binders', 'binder'], 'parent': 'Sub-Category'}
# - Discount: {'ENTITY': 'Discount', 'other names': ['discount', 'discount rate', 'discount value', 'deduction']}
#
# Step 3: Convert the query components into structured output format
# - For the derived measure "share", we need to specify the applied measure "discount" and the ratio filter "Phone" and "Binder".
# - For the filter, we need to include "corporate", "phone", and "binder" with their respective parent entities.
# - For the measure, we need to include "discount" with no constraints.
#
# Step 4: Analyze the date component and date reference
# - The query does not mention any specific date or time period.
# - The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}.
# - Since the query does not mention any date component, the date reference is not utilized in the structured output.
#
# Rationale:
# - The query asks for the share of phone and binder based on the discount in the corporate segment.
# - We identified the relevant components from the query and matched them to the context.
# - We then converted these components into the structured output format, specifying the derived measure, filter, and measure.
# - The date reference was not utilized as the
# CPU times: user 1min, sys: 972 ms, total: 1min 1s
# Wall time: 1min 1s

# %%
# %%time
user_query = 'phone to binder ratio of discount in corporate'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  phone to binder ratio of discount in corporate
# ----------------------------------------------------------------------------------------------------
# {'DATE': {'': []}, 'DERIVED MEASURE': {'ratio': [{'APPLIED MEASURE': [{'discount': 'Discount'}], 'DERIVED MEASURE CONSTRAINT': [{'COMPARISON VALUE': '', 'COMPARSION OPERATOR': ''}], 'ENTITY': 'Ratio', 'RATIO FILTER': ['Phone', 'Binder']}]}, 'DIMENSION': {'corporate': [{'ENTITY': 'Corporate', 'RANK': [{'RANK ADJECTIVE': '', 'RANK VALUE': ''}]}]}, 'FILTER': {'binder': [{'ENTITY': 'Binder', 'PARENT': 'Sub-Category'}], 'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'discount': [{'ENTITY': 'Discount', 'MEASURE CONSTRAINT': [{'COMPARISON VALUE': '', 'COMPARSION OPERATOR': ''}]}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - Phone
# - Binder
# - Ratio
# - Discount
# - Corporate
#
# Step 2: Match the components to the context
# - Phone: Sub-Category (Filter)
# - Binder: Sub-Category (Filter)
# - Ratio: Derived Measure
# - Discount: Measure
# - Corporate: Segment (Dimension)
#
# Step 3: Convert the query into structured output
# - Since the query is asking for the ratio of discount, we need to use the Derived Measure "Ratio" and apply it to the Measure "Discount".
# - The ratio is between Phone and Binder, so we add them as "RATIO FILTER" under the "Ratio" Derived Measure.
# - The query is specifically asking for the ratio in the Corporate segment, so we add "Corporate" as a Dimension with no rank constraints.
#
# Step 4: Convert the date component
# - The query does not mention any specific date or time period, so we do not need to utilize the date reference in this case. The structured output does not include any date-related information.
#
# Rationale:
# - The query is asking for the ratio of discount between Phone and Binder in the Corporate segment. We identified the components in the query and matched them to the context.
# - We then utilized the Derived Measure "Ratio" and applied it to the Measure "Discount" while considering the RATIO FILTER of "Phone" and "Binder".
# - Since the query does not mention any specific date or time period, we did not utilize the date reference in the structured output.
#
# Note:
# - The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}. However, the query does not mention any specific date or time period, so the date reference is not utilized in the structured output.
# - The context includes various entities such as Me
# CPU times: user 1min, sys: 1.03 s, total: 1min 1s
# Wall time: 1min 1s

# %%
# %%time
user_query = 'segments with discount rate greater than 100k'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  segments with discount rate greater than 100k
# ----------------------------------------------------------------------------------------------------
# {'DIMENSION': {'segments': [{'ENTITY': 'Segment'}]}, 'MEASURE': {'discount rate': [{'ENTITY': 'Discount', 'MEASURE CONSTRAINT': [{'COMPARISON VALUE': '100k', 'COMPARSION OPERATOR': '>'}]}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query mentions "segments" which can be matched to the "Segment" entity in the context under DIMENSION.
# - The query also mentions "discount rate" which can be matched to the "Discount" entity in the context under MEASURE.
# - The query specifies a condition "greater than 100k" which is a comparison constraint.
#
# Step 2: Match the components to the context
# - "segments" is matched to the "Segment" entity in the context under DIMENSION.
# - "discount rate" is matched to the "Discount" entity in the context under MEASURE.
#
# Step 3: Convert the query into a structured output
# - Add the "Segment" entity to the DIMENSION section of the structured output.
# - Add the "Discount" entity to the MEASURE section of the structured output.
# - Add the comparison constraint "greater than 100k" to the "Discount" entity in the MEASURE section of the structured output.
#
# Step 4: Utilize the date reference
# - In this query, there is no mention of any date or time-related component. Therefore, the date reference is not utilized in the structured output.
#
# Rationale:
# The query asks for segments with a discount rate greater than 100k. The structured output captures this information by including the "Segment" entity in the DIMENSION section and the "Discount" entity in the MEASURE section with the comparison constraint "greater than 100k". Since there is no date-related component in the query, the date reference is not utilized in the structured output.
#
# Note: The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}. It is utilized in other queries where there is a date-related component.
#
# [MQL]
# {
#     "DATE VARIABLE": {
#         "order date": [
#             {
#                 "ENTITY": "Order Date",
#                 "DATE CONSTRAINT": [
#                     {
#                         "COMPARISON VALUE": "01/01/2020",
#                         "COMPARSION OPERATOR": "="
#                     },
#                     {
#                         "COMPARISON VALUE": "15/09/2023",
#                         "COMPARSION OPERATOR": "="
#                     }
#                 ]
#             }
#         ]
#     }
# }
# [/MQL]
# the date reference is utilized here as the query asks for sales in the time period of 01/01/2020 to 15/09/2023. The structured output captures this information by including the "Order Date" entity in the DATE VARIABLE section with the date constraints "01/01/2020" and "15/09/2023".</s>
# CPU times: user 57 s, sys: 1.06 s, total: 58.1 s
# Wall time: 58.1 s

# %%
# %%time
user_query = 'category with discount rate greater than 10k and quantity less than 2k'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  category with discount rate greater than 10k and quantity less than 2k
# ----------------------------------------------------------------------------------------------------
# {'DIMENSION': {'category': [{'ENTITY': 'Sub-Category'}]}, 'MEASURE': {'discount rate': [{'ENTITY': 'Discount', 'MEASURE CONSTRAINT': [{'COMPARISON VALUE': '10k', 'COMPARSION OPERATOR': '>'}]}], 'quantity': [{'ENTITY': 'Quantity', 'MEASURE CONSTRAINT': [{'COMPARISON VALUE': '2k', 'COMPARSION OPERATOR': '<'}]}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - "category" is a dimension component
# - "discount rate" is a measure component
# - "greater than 10k" is a measure constraint
# - "quantity" is a measure component
# - "less than 2k" is a measure constraint
#
# Step 2: Match the components to the context
# - "category" matches with "Sub-Category" in the context
# - "discount rate" matches with "Discount" in the context
# - "quantity" matches with "Quantity" in the context
#
# Step 3: Convert the components into structured output format
# - "category" is added under "DIMENSION" with the ENTITY "Sub-Category"
# - "discount rate" is added under "MEASURE" with the ENTITY "Discount" and the measure constraint "greater than 10k" is added as "COMPARISON VALUE": "10k" and "COMPARSION OPERATOR": ">"
# - "quantity" is added under "MEASURE" with the ENTITY "Quantity" and the measure constraint "less than 2k" is added as "COMPARISON VALUE": "2k" and "COMPARSION OPERATOR": "<"
#
# Step 4: Check for date components and reference
# - There are no date components in the query, so the date reference is not utilized in this case.
#
# Rationale:
# The query asks for categories with a discount rate greater than 10k and quantity less than 2k. By identifying the components in the query and matching them to the context, we can create a structured output that represents the query in a format that can be easily processed by a data analysis system. The date reference is not utilized in this case as there are no date components in the query.
#
# The structured output includes the dimension "category" with the ENTITY "Sub-Category" and the measures "discount rate" and "quantity" with their respective ENTITIES and measure constraints. The measure constraint for "discount rate" is "greater than 10k" and the measure constraint for "quantity" is "less than 2k".
#
# Overall, the structured output provides a clear and organized representation of the query that can be easily understood by a data analysis system.</s>
# CPU times: user 51.1 s, sys: 992 ms, total: 52.1 s
# Wall time: 52.1 s

# %%
# %%time
user_query = 'why did discount of phones drop'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  why did discount of phones drop
# ----------------------------------------------------------------------------------------------------
# {'DERIVED MEASURE': {'why': [{'ENTITY': 'Why'}]}, 'FILTER': {'phones': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'discount': [{'ADJECTIVE': ['dropped'], 'ENTITY': 'Discount', 'TONE': 'negative'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query asks "why did discount of phones drop". The components in the query are "discount", "phones", and "drop".
#
# Step 2: Match the components to the context
# - "discount" can be matched to the "Discount" entity in the MEASURE context.
# - "phones" can be matched to the "Phone" entity in the FILTER context.
# - "drop" indicates a negative tone and can be associated with the "Discount" entity.
#
# Step 3: Identify the derived measure
# - The query asks "why", which can be matched to the "Why" entity in the DERIVED MEASURE context.
#
# Step 4: Create the structured output
# - The structured output should include the identified components and their respective context categories. In this case, the output should include the "Discount" entity in the MEASURE category, the "Phone" entity in the FILTER category, and the "Why" entity in the DERIVED MEASURE category.
#
# Step 5: Add the tone and adjective to the structured output
# - Since the query mentions "drop", which indicates a negative tone, the "Discount" entity in the MEASURE category should have a "TONE" attribute set to "negative". Additionally, the "ADJECTIVE" attribute should be set to "dropped".
#
# Step 6: Consider the date reference
# - The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}. However, the query does not mention any specific date or time period. Therefore, the date reference is not utilized in this case.
#
# Rationale:
# - The query asks for the reason behind the drop in the discount of phones. By identifying the components in the query and matching them to the context, we can create a structured output that includes the relevant entities and their respective categories. The output also takes into account the negative tone and adjective associated with the "Discount" entity. Since the query does not mention any specific date or time period, the date reference is not utilized.
#
# The structured output provides a clear and organized representation of the query, making it easier to understand and analyze the data. This helps in identifying the root cause of the drop in the discount of phones and taking appropriate action.</s>
# CPU times: user 47.7 s, sys: 980 ms, total: 48.7 s
# Wall time: 48.7 s

# %%
# %%time
user_query = 'correlation of sales and purchase for phone'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  correlation of sales and purchase for phone
# ----------------------------------------------------------------------------------------------------
# {'DERIVED MEASURE': {'correlation': [{'APPLIED MEASURE': [{'sales': 'Sales'}, {'purchase': 'Purchase Vol'}], 'ENTITY': 'correlation'}]}, 'FILTER': {'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query mentions "correlation", which is a derived measure.
# - It also mentions "sales" and "purchase", which are measures.
# - The term "phone" is mentioned, which is a filter.
#
# Step 2: Match the components to the context
# - "correlation" can be matched to the derived measure "correlation" in the context.
# - "sales" can be matched to the measure "Sales" in the context.
# - "purchase" can be matched to the measure "Purchase Vol" in the context.
# - "phone" can be matched to the filter "Phone" in the context, which has a parent "Sub-Category".
#
# Step 3: Convert the query into a structured output
# - The derived measure "correlation" is applied to the measures "Sales" and "Purchase Vol", which are added as "APPLIED MEASURE" in the structured output.
# - The filter "Phone" is added to the structured output with its parent "Sub-Category".
#
# Step 4: Check for date components and date reference
# - The query does not mention any date components, so the date reference is not utilized in this case.
#
# Rationale:
# The query asks for the correlation between sales and purchase for the phone sub-category. We identified the components in the query and matched them to the context. Then, we converted the query into a structured output by applying the derived measure to the measures and adding the filter with its parent. Since there are no date components in the query, the date reference is not utilized.
#
# Note: The date reference is utilized when the query contains date components or when analyzing time-series data. In this case, the query does not mention any date components, so the date reference is not needed.</s>
# CPU times: user 38.8 s, sys: 1.03 s, total: 39.8 s
# Wall time: 39.8 s

# %%
# %%time
user_query = 'what will be the sales in q1 24'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  what will be the sales in q1 24
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'q1 24': [{'CONVERTED TIME ELEMENT': 'quarter 1 2024', 'DATE RANGE': '2024/01/01 - 2024/03/31', 'ENTITY': 'Order Date'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query asks for "sales" in "q1 24".
#
# Step 2: Match the components to the context
# - "sales" can be matched to the "Sales" entity in the MEASURE context.
# - "q1 24" is a date component that needs to be converted.
#
# Step 3: Convert the date component
# - "q1 24" can be interpreted as "quarter 1 2024".
# - The date range for quarter 1 2024 is "2024/01/01 - 2024/03/31".
#
# Step 4: Check if the date reference is needed
# - The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}.
# - Since the query asks for sales in quarter 1 2024, the date reference is not needed in this case, as the requested date range is outside the date reference provided.
#
# Step 5: Create the structured output
# - The structured output should include the "Sales" entity from the MEASURE context and the converted date component "quarter 1 2024" with its date range "2024/01/01 - 2024/03/31" associated with the "Order Date" entity from the DATE VARIABLE context.
#
# Rationale:
# - The query asks for sales in a specific date range (quarter 1 2024), so the structured output should include the "Sales" entity from the MEASURE context and the converted date component "quarter 1 2024" with its date range associated with the "Order Date" entity from the DATE VARIABLE context.
# - The date reference is not needed in this case, as the requested date range is outside the date reference provided.
# - The date component is converted using standard date conventions (quarter 1 2024 = January 1, 2024 - March 31, 2024).
# - The MEASURE and DATE VARIABLE contexts are utilized to identify the relevant entities and their associated date ranges.
# - The structured output follows the MQL format and includes the identified entities and their associated date ranges.</s>
# CPU times: user 47.4 s, sys: 1.03 s, total: 48.5 s
# Wall time: 48.5 s

# %%
# %%time
user_query = 'sales in q1 and q2 2021'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  sales in q1 and q2 2021
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'q1 and q2 2021': [{'CONVERTED TIME ELEMENT': 'quarter 1 and quarter 2 2021', 'DATE RANGE': '2021/01/01 - 2021/03/31, 2021/04/01 - 2021/06/30', 'ENTITY': 'Order Date'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query mentions "sales" which is a measure.
# - The query also mentions "q1 and q2 2021" which is a date component.
#
# Step 2: Match the components to the context
# - In the context, "sales" can be matched to the "Sales" entity under the 'MEASURE' category.
# - For the date component "q1 and q2 2021", we need to convert it into a proper date range.
#
# Step 3: Convert the date component
# - "q1 and q2 2021" refers to the first two quarters of the year 2021.
# - Quarter 1 (Q1) of 2021 ranges from 2021/01/01 to 2021/03/31.
# - Quarter 2 (Q2) of 2021 ranges from 2021/04/01 to 2021/06/30.
# - Combine these two date ranges as "2021/01/01 - 2021/03/31, 2021/04/01 - 2021/06/30".
#
# Step 4: Check if the date reference is needed
# - In this case, the date reference is not needed as the query already specifies the exact date range (Q1 and Q2 2021) for which the sales data is required.
#
# Step 5: Create the structured output
# - Under "DATE VARIABLE", include the converted time element "quarter 1 and quarter 2 2021" along with the date range "2021/01/01 - 2021/03/31, 2021/04/01 - 2021/06/30" and the entity "Order Date".
# - Under "MEASURE", include the entity "Sales" as it matches the query component "sales".
#
# The structured output is now complete with the identified and matched components from the query and context.
#
# Rationale:
# - The query asks for sales data in Q1 and Q2 2021, so we need to create a structured output that includes the date range and the measure (sales).
# - The date reference is not needed in this case as the query already specifies the exact date range.
# - The context helps us identify and match the components in the query to the appropriate entities and date ranges.
# - The structured output should be clear, concise, and easy to understand, providing all the necessary information for the user to analyze the data.
#
# MQL tags:
# {
#     "DATE VARIABLE": [
#         {
#             "CONVERTED TIME ELEMENT": "quarter 1 and quarter 2 2021",
#             "DATE RANGE": "2021/01/01 - 2021/03/31, 2021/0
# CPU times: user 1min, sys: 992 ms, total: 1min 1s
# Wall time: 1min 1s

# %%
# %%time
user_query = 'how many segments contributing to growth of sales in p3m vs pp'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  how many segments contributing to growth of sales in p3m vs pp
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'p3m': [{'CONVERTED TIME ELEMENT': 'previous 3 months', 'DATE RANGE': '2023/06/15-2023/09/15', 'ENTITY': 'Order Date'}], 'pp': [{'CONVERTED TIME ELEMENT': 'previous period', 'DATE RANGE': '2023/06/01-2023/05/31', 'ENTITY': 'Order Date'}]}, 'DERIVED MEASURE': {'contributing to growth': [{'APPLIED MEASURE': [{'sales': 'Sales'}], 'ENTITY': 'contribution_to_growth'}]}, 'DIMENSION': {'segments': [{'ENTITY': 'Segment'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - "segments": Dimension
# - "contributing to growth": Derived Measure
# - "sales": Measure
# - "p3m": Date Variable
# - "pp": Date Variable
#
# Step 2: Match the components to the context
# - "segments" matches to "Segment" in the context under 'DIMENSION'
# - "contributing to growth" matches to "contribution_to_growth" in the context under 'DERIVED MEASURE'
# - "sales" matches to "Sales" in the context under 'MEASURE'
# - "p3m" matches to "previous 3 months" in the context under 'DATE VARIABLE'
# - "pp" matches to "previous period" in the context under 'DATE VARIABLE'
#
# Step 3: Convert the date components
# - "p3m" is converted to "previous 3 months"
# - "pp" is converted to "previous period"
#
# Step 4: Create the structured output
# - For "DIMENSION", include "segments" as an entity
# - For "DERIVED MEASURE", include "contributing to growth" as an entity and "sales" as a applied measure
# - For "DATE VARIABLE", include "p3m" and "pp" as entities with their converted time elements and date ranges
#
# Step 5: Check the date reference
# - The date range for "p3m" is "2023/06/15-2023/09/15", which falls within the date reference provided ("2020/01/01-2023/09/15").
# - The date range for "pp" is "2023/06/01-2023/05/31", which also falls within the date reference provided ("2020/01/01-2023/09/15").
#
# The structured output is created based on the identified components, their matches in the context, and the conversion of the date components. The date reference is checked to ensure the date ranges used are within the provided date range.
#
# Rationale:
# The query asks for the number of segments contributing to the growth of sales in the previous 3 months versus the previous period. To answer this, we need to identify the relevant dimensions, derived measures, and date components in the query and match them to the context. We then convert the date components and create the structured output using the context and date reference. The rationale behind
# CPU times: user 1min, sys: 991 ms, total: 1min 1s
# Wall time: 1min 1s

# %%
# %%time
user_query = 'how has sales trended in first week of 2021'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  how has sales trended in first week of 2021
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'first week of 2021': [{'CONVERTED TIME ELEMENT': 'first week of 2021', 'DATE RANGE': '2021/01/01 - 2021/01/07', 'ENTITY': 'Order Date'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query asks for the sales trend in the first week of 2021.
#
# Step 2: Match the components to the context
# - From the context, we can identify that "sales" is a measure and is represented by the entity "Sales".
# - The date component "first week of 2021" is not directly available in the context, but we can derive it using the date reference.
#
# Step 3: Convert the date component
# - The query asks for the sales trend in the first week of 2021. We can derive this date range by considering the start date of 2021 (01/01/2021) and adding 6 days to it, resulting in the date range "2021/01/01 - 2021/01/07".
# - The date reference is not utilized here as the query specifically asks for the first week of 2021, which is independent of the start_date and end_date provided in the date reference.
#
# Step 4: Create the structured output
# - Based on the identified components and their matching entities in the context, we can create the structured output with the "DATE VARIABLE" and "MEASURE" keys.
# - For the "DATE VARIABLE" key, we include the derived date range "2021/01/01 - 2021/01/07" and associate it with the "Order Date" entity.
# - For the "MEASURE" key, we include the "Sales" entity as it represents the sales trend in the query.
#
# Rationale:
# - The structured output is created by identifying the relevant components in the query, matching them to the context, and converting the date component to a specific date range.
# - The date reference is not utilized in this case as the query specifically asks for the first week of 2021, which is independent of the start_date and end_date provided in the date reference.
# - The context is utilized to identify the measure (Sales) and its corresponding entity.
#
# The structured output provides a clear and organized representation of the query, making it easier for downstream processing and analysis.</s>
# CPU times: user 45 s, sys: 1.02 s, total: 46 s
# Wall time: 46 s

# %%
# %%time
user_query = 'what will be sales in 1st 5 days of 2024'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  what will be sales in 1st 5 days of 2024
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'1st 5 days of 2024': [{'CONVERTED TIME ELEMENT': 'first 5 days of january 2024', 'DATE RANGE': '2024/01/01 - 2024/01/05', 'ENTITY': 'Order Date'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query asks for "sales" which can be matched to the "Sales" entity in the context under MEASURE.
# - The query specifies a time period "1st 5 days of 2024" which needs to be converted into a date range.
#
# Step 2: Match the components to the context
# - "sales" is matched to the "Sales" entity under MEASURE in the context.
#
# Step 3: Convert the date component
# - The date component "1st 5 days of 2024" can be converted into a date range "2024/01/01 - 2024/01/05" as it refers to the first 5 days of January 2024.
#
# Step 4: Check if the date reference is needed
# - In this case, the date reference is not utilized as the query specifically asks for sales in the first 5 days of 2024, which is outside the date range provided in the date reference.
#
# Step 5: Create the structured output
# - The structured output is created by combining the identified components and their corresponding context matches, along with the converted date range.
#
# Rationale:
# - The query asks for sales in a specific time period, so the structured output should include the "Sales" entity from the context and the converted date range.
# - The date reference is not utilized in this case as the query specifically asks for sales in the first 5 days of 2024, which is outside the date range provided in the date reference.
# - The structured output is created by combining the identified components and their corresponding context matches, along with the converted date range.
#
# Note: The date reference is utilized in cases where the query asks for sales or any other measure in a specific time period that falls within the date range provided in the date reference. The date reference can help in converting the date component into a valid date range if needed.</s>
# CPU times: user 41.6 s, sys: 1.06 s, total: 42.6 s
# Wall time: 42.6 s

# %%
# %%time
user_query = 'sales and purchase across yoy'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  sales and purchase across yoy
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'yoy': [{'CONVERTED TIME ELEMENT': 'year over year', 'DATE RANGE': '2022/09/15 - 2023/09/15', 'ENTITY': 'Order Date'}]}, 'MEASURE': {'purchase': [{'ENTITY': 'Purchase Vol'}], 'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query mentions "sales" and "purchase" which are measures.
# - The query also mentions "yoy" which is a date variable.
#
# Step 2: Match the components to the context
# - "sales" can be matched to the "Sales" entity in the context.
# - "purchase" can be matched to the "Purchase Vol" entity in the context.
# - "yoy" can be matched to the "Order Date" entity in the context with the "year over year" time element.
#
# Step 3: Convert the date component
# - The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}.
# - Since the query mentions "yoy", we need to calculate the year-over-year date range.
# - The end date in the date reference is '15/09/2023', so the year-over-year date range would be from '2022/09/15' to '2023/09/15'.
#
# Step 4: Create the structured output
# - The structured output should include the identified and matched components from the query and context.
# - For the "MEASURE" section, include the "Sales" and "Purchase Vol" entities.
# - For the "DATE VARIABLE" section, include the "Order Date" entity with the "year over year" time element and the calculated date range ('2022/09/15 - 2023/09/15').
#
# Rationale:
# - The query asks for sales and purchase data across a year-over-year time frame.
# - The context provides the necessary entities and date reference to create a structured output that captures the requested information.
# - The date reference is used to calculate the year-over-year date range based on the end date provided.
# - The structured output follows the MQL format and includes the identified and matched components from the query and context.
#
# Note: The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}. The query asks for sales and purchase data across a year-over-year time frame, so the date range used in the structured output is from '2022/09/15' to '2023/09/15'. This date range is calculated by taking the end date in the date reference ('15/09/2023') and subtracting one year to get '2022/09/15', then adding another year to get '2023/09/15'. This ensures that the year-over-year date range includes the end date in the date reference and captures the time frame requested in the query.</s>
# CPU times: user 56.6 s, sys: 1.01 s, total: 57.6 s
# Wall time: 57.6 s

# %%
# %%time
user_query = 'sales and purchase during last one year'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  sales and purchase during last one year
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'last one year': [{'CONVERTED TIME ELEMENT': 'last one year', 'DATE RANGE': '2022/09/15 - 2023/09/15', 'ENTITY': 'Order Date'}]}, 'MEASURE': {'purchase': [{'ENTITY': 'Purchase Vol'}], 'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query mentions "sales" and "purchase" which are measures.
# - The query also mentions "last one year" which is a date variable.
#
# Step 2: Match the components to the context
# - "sales" can be matched to the "Sales" entity in the context.
# - "purchase" can be matched to the "Purchase Vol" entity in the context.
# - "last one year" can be matched to the "Order Date" entity in the context with the date range "2022/09/15 - 2023/09/15" as it refers to the period from September 15, 2022 to September 15, 2023.
#
# Step 3: Convert the date component
# - The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}.
# - However, the query mentions "last one year" which is not aligned with the date reference provided.
# - Therefore, the date reference is not utilized in this case, and the structured output is created based on the identified components and their matching in the context.
#
# Step 4: Create the structured output
# - The structured output is created by combining the identified components and their matching in the context.
# - For the "MEASURE" section, "sales" and "purchase" are included as separate entities.
# - For the "DATE VARIABLE" section, "last one year" is included as the "Order Date" entity with the date range "2022/09/15 - 2023/09/15" as it refers to the period from September 15, 2022 to September 15, 2023.
#
# Rationale:
# - The query asks for sales and purchase during the last one year, so the structured output should include these measures and the date variable that refers to the period from September 15, 2022 to September 15, 2023.
# - The date reference provided is not utilized in this case as the query does not mention a specific date range or period that corresponds to the date reference.
# - The context is used to identify the components in the query and their matching entities.
# - The structured output is created by combining these identified components and their matching entities.
#
# Note: The date component "last one year" is converted based on the context's date reference as it does not mention a specific date range or period in the query. The date reference provided is not utilized in this case as the query does not mention a specific date range or period that corresponds to the date reference.</s>
# CPU times: user 53.7 s, sys: 1.1 s, total: 54.8 s
# Wall time: 54.8 s

# %%
# %%time
user_query = 'In q1 2023, what was sales'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  In q1 2023, what was sales
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'q1 2023': [{'CONVERTED TIME ELEMENT': 'quarter 1 2023', 'DATE RANGE': '2023/01/01 - 2023/03/31', 'ENTITY': 'Order Date'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query asks for "sales" in "q1 2023".
#
# Step 2: Match the components to the context
# - "sales" can be matched to the "Sales" entity in the MEASURE context.
# - "q1 2023" is a date component that needs to be converted.
#
# Step 3: Convert the date component
# - "q1 2023" can be converted to "quarter 1 2023".
# - The date range for quarter 1 2023 is "2023/01/01 - 2023/03/31".
#
# Step 4: Check if the date reference is needed
# - The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}.
# - Since the query asks for sales in q1 2023, the date reference is not needed in this case, as the requested date range is outside the date reference provided.
#
# Step 5: Create the structured output
# - The structured output should include the "Sales" entity from the MEASURE context and the converted date component "quarter 1 2023" with its date range "2023/01/01 - 2023/03/31" associated with the "Order Date" entity from the DATE VARIABLE context.
#
# Rationale:
# - The query asks for sales in a specific date range (q1 2023), which needs to be converted into a structured output.
# - The context provides the necessary information to identify the entities and their relationships, allowing us to create a structured output that accurately represents the query.
# - The date reference is not needed in this case, as the requested date range is outside the date reference provided.
#
# The structured output is created by combining the identified components and their corresponding context elements, ensuring a clear and accurate representation of the query.</s>
# CPU times: user 42.6 s, sys: 1.1 s, total: 43.7 s
# Wall time: 43.7 s

# %%
# %%time
user_query = 'What are drivers of sales growth'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  What are drivers of sales growth
# ----------------------------------------------------------------------------------------------------
# {'DERIVED MEASURE': {'driver': [{'APPLIED MEASURE': [{'sales': 'Sales'}], 'DERIVED MEASURE CONSTRAINT': [{'COMPARISON VALUE': '', 'COMPARSION OPERATOR': ''}], 'ENTITY': 'kda_transactional', 'RATIO FILTER': [{'FILTER': ['Phone'], 'RATIO FILTER CONSTRAINT': [{'COMPARISON VALUE': '', 'COMPARSION OPERATOR': ''}]}]}]}, 'DATE VARIABLE': {'end_date': [{'DATE RANGE': [{'END DATE': '15/09/2023', 'START DATE': '01/01/2020'}]}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales', 'MEASURE CONSTRAINT': [{'COMPARISON VALUE': '', 'COMPARSION OPERATOR': ''}]}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - Drivers of sales growth
#
# Step 2: Match the components to the context
# - Sales: Matches with 'Sales' in the context under MEASURE
# - Drivers: Not a direct match, but could be associated with 'kda_transactional' in the context under DERIVED MEASURE
# - Growth: Not a direct match, but could be associated with 'growth rate' in the context under DERIVED MEASURE
#
# Step 3: Convert the query into structured output
# - Add 'Sales' as a measured value under MEASURE
# - Add 'kda_transactional' as a derived measure with 'Sales' as its applied measure and 'Phone' as its ratio filter
# - Add 'growth rate' as a derived measure with 'Sales' as its applied measure and no specific filter mentioned in the query
# - Add the date reference '15/09/2023' as the end date and '01/01/2020' as the start date under DATE VARIABLE
#
# Rationale:
# - The query asks for the drivers of sales growth. We identified 'kda_transactional' in the context as a derived measure that could be associated with this query. 'kda_transactional' has 'Sales' as its applied measure and 'Phone' as its ratio filter.
# - Since the query does not specify any specific filter for the ratio, we added the date reference '15/09/2023' as the end date and '01/01/2020' as the start date under DATE VARIABLE.
# - The query also mentions sales growth rate, which is a derived measure in the context with 'growth rate' as its name. We added this as another derived measure with 'Sales' as its applied measure and no specific filter mentioned in the query.
#
# The structured output captures the identified components and their relationships in a format that can be easily processed by a data analysis system.</s>
# CPU times: user 59.6 s, sys: 991 ms, total: 1min
# Wall time: 1min

# %%
# %%time
user_query = 'why did discount of phones decrease'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  why did discount of phones decrease
# ----------------------------------------------------------------------------------------------------
# {'DERIVED MEASURE': {'why': [{'ENTITY': 'Why'}]}, 'FILTER': {'phones': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'discount': [{'ADJECTIVE': ['decrease'], 'ENTITY': 'Discount', 'TONE': 'negative'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query asks "why did discount of phones decrease". The components in the query are "discount", "phones", and "decrease".
#
# Step 2: Match the components to the context
# - "discount" can be matched to the "Discount" entity in the MEASURE context.
# - "phones" can be matched to the "Phone" entity in the FILTER context.
# - "decrease" can be associated with the "Discount" entity as it is a negative tone.
#
# Step 3: Identify the derived measure
# - The query asks "why", which can be matched to the "Why" entity in the DERIVED MEASURE context.
#
# Step 4: Create the structured output
# - The structured output should include the identified components and their respective context categories. In this case, the output should include the "Discount" entity in the MEASURE category, the "Phone" entity in the FILTER category, and the "Why" entity in the DERIVED MEASURE category.
#
# Step 5: Add the tone and adjective to the structured output
# - Since the query mentions "decrease", which is a negative tone, the "Discount" entity in the MEASURE category should have a "TONE" attribute set to "negative". Additionally, the "ADJECTIVE" attribute should be set to "decrease".
#
# Step 6: Consider the date reference
# - The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}. However, the query does not mention any specific date or time period. Therefore, the date reference is not utilized in this case.
#
# Rationale:
# - The query asks for the reason behind the decrease in the discount of phones. By identifying the components in the query and matching them to the context, we can create a structured output that includes the relevant entities and their respective categories. The output also takes into account the negative tone and adjective associated with the "Discount" entity. Since the query does not mention any specific date or time period, the date reference is not utilized.
#
# Note:
# - The structured output is created based on the context provided and the query components identified. The rationale is to provide a structured representation of the query that can be easily understood and analyzed by a system or human user.</s>
# CPU times: user 48.6 s, sys: 964 ms, total: 49.6 s
# Wall time: 49.6 s

# %%
# %%time
user_query = 'why did sales of phones drop'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  why did sales of phones drop
# ----------------------------------------------------------------------------------------------------
# {'DERIVED MEASURE': {'why': [{'ENTITY': 'Why'}]}, 'FILTER': {'phones': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'sales': [{'ADJECTIVE': ['dropped'], 'ENTITY': 'Sales', 'TONE': 'negative'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query asks "why did sales of phones drop". The components in the query are "sales", "phones", and "drop".
#
# Step 2: Match the components to the context
# - "sales" can be matched to the "Sales" entity in the MEASURE context.
# - "phones" can be matched to the "Phone" entity in the FILTER context.
# - "drop" indicates a negative tone and can be associated with the "Sales" entity in the MEASURE context.
#
# Step 3: Identify the derived measure
# - The query asks "why", which can be matched to the "Why" entity in the DERIVED MEASURE context.
#
# Step 4: Create the structured output
# - The structured output should include the identified components and their respective context categories. In this case, the output should include the "Sales" entity in the MEASURE category, the "Phone" entity in the FILTER category, and the "Why" entity in the DERIVED MEASURE category.
#
# Step 5: Add the tone and adjective to the structured output
# - Since the query mentions "drop", which indicates a negative tone, the "Sales" entity in the MEASURE category should have a "TONE" attribute set to "negative". Additionally, the "ADJECTIVE" attribute should be set to "dropped".
#
# Step 6: Consider the date reference
# - The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}. However, the query does not mention any specific date or time period. Therefore, the date reference is not utilized in this case.
#
# Rationale:
# - The query asks for the reason behind the drop in sales of phones. By identifying the components in the query and matching them to the context, we can create a structured output that includes the relevant entities and their respective categories. The output also takes into account the negative tone and adjective associated with the "Sales" entity. Since the query does not mention any specific date or time period, the date reference is not utilized.
#
# The structured output provides a clear and organized representation of the query, making it easier to analyze and understand the information being requested.</s>
# CPU times: user 46.8 s, sys: 1 s, total: 47.8 s
# Wall time: 47.8 s

# %%
# %%time
user_query = 'why did discount of phones drop'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  why did discount of phones drop
# ----------------------------------------------------------------------------------------------------
# {'DERIVED MEASURE': {'why': [{'ENTITY': 'Why'}]}, 'FILTER': {'phones': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'discount': [{'ADJECTIVE': ['dropped'], 'ENTITY': 'Discount', 'TONE': 'negative'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query asks "why did discount of phones drop". The components in the query are "discount", "phones", and "drop".
#
# Step 2: Match the components to the context
# - "discount" can be matched to the "Discount" entity in the MEASURE context.
# - "phones" can be matched to the "Phone" entity in the FILTER context.
# - "drop" indicates a negative tone and can be associated with the "Discount" entity.
#
# Step 3: Identify the derived measure
# - The query asks "why", which can be matched to the "Why" entity in the DERIVED MEASURE context.
#
# Step 4: Create the structured output
# - The structured output should include the identified components and their respective context categories. In this case, the output should include the "Discount" entity in the MEASURE category, the "Phone" entity in the FILTER category, and the "Why" entity in the DERIVED MEASURE category.
#
# Step 5: Add the tone and adjective to the structured output
# - Since the query mentions "drop", which indicates a negative tone, the "Discount" entity in the MEASURE category should have a "TONE" attribute set to "negative". Additionally, the "ADJECTIVE" attribute should be set to "dropped".
#
# Step 6: Consider the date reference
# - The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}. However, the query does not mention any specific date or time period. Therefore, the date reference is not utilized in this case.
#
# Rationale:
# - The query asks for the reason behind the drop in the discount of phones. By identifying the components in the query and matching them to the context, we can create a structured output that includes the relevant entities and their respective categories. The output also takes into account the negative tone and adjective associated with the "Discount" entity. Since the query does not mention any specific date or time period, the date reference is not utilized.
#
# The structured output provides a clear and organized representation of the query, making it easier to understand and analyze the data. This helps in identifying the root cause of the drop in the discount of phones and taking appropriate action.</s>
# CPU times: user 47.6 s, sys: 1.04 s, total: 48.6 s
# Wall time: 48.7 s

# %%
# %%time
user_query = 'why discount of phones dropped'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  why discount of phones dropped
# ----------------------------------------------------------------------------------------------------
# {'DERIVED MEASURE': {'why': [{'ENTITY': 'Why'}]}, 'FILTER': {'phones': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'discount': [{'ADJECTIVE': ['dropped'], 'ENTITY': 'Discount', 'TONE': 'negative'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query asks "why discount of phones dropped". The components in the query are "discount", "phones", and "dropped".
#
# Step 2: Match the components to the context
# - "discount" can be matched to the "Discount" entity in the MEASURE context.
# - "phones" can be matched to the "Phone" entity in the FILTER context.
# - "dropped" indicates a negative tone and can be associated with the "Discount" entity.
#
# Step 3: Identify the derived measure
# - The query asks "why", which can be matched to the "Why" entity in the DERIVED MEASURE context.
#
# Step 4: Create the structured output
# - The structured output should include the identified components and their respective context categories. In this case, the output should include the "Discount" entity in the MEASURE category, the "Phone" entity in the FILTER category, and the "Why" entity in the DERIVED MEASURE category.
#
# Step 5: Add the tone and adjective to the structured output
# - Since the query mentions "dropped", which indicates a negative tone, the "Discount" entity in the MEASURE category should have a "TONE" attribute set to "negative". Additionally, the "ADJECTIVE" attribute should be set to "dropped".
#
# Step 6: Consider the date reference
# - The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}. However, the query does not mention any specific date or time period. Therefore, the date reference is not utilized in this case.
#
# Rationale:
# - The query asks for the reason behind the drop in the discount of phones. By identifying the components in the query and matching them to the context, we can create a structured output that includes the relevant entities and their respective categories. The output also takes into account the negative tone and adjective associated with the "Discount" entity. Since the query does not mention any specific date or time period, the date reference is not utilized.
#
# The structured output provides a clear and organized representation of the query, making it easier to analyze and understand the information being requested.</s>
# CPU times: user 46.6 s, sys: 996 ms, total: 47.6 s
# Wall time: 47.6 s

# %%
# %%time
user_query = 'discount of phones dropped, why?'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  discount of phones dropped, why?
# ----------------------------------------------------------------------------------------------------
# {'DERIVED MEASURE': {'why': [{'ENTITY': 'Why'}]}, 'FILTER': {'phones': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'discount': [{'ADJECTIVE': ['dropped'], 'ENTITY': 'Discount', 'TONE': 'negative'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query mentions "discount" which is a measure.
# - The query mentions "phones" which is a filter.
# - The query mentions "dropped" which is an adjective.
# - The query mentions "why" which is a derived measure.
#
# Step 2: Match the components to the context
# - "discount" can be matched to the "Discount" entity in the context.
# - "phones" can be matched to the "Phone" entity in the context which has a parent "Sub-Category".
# - "dropped" can be an adjective for the "Discount" entity.
# - "why" can be matched to the "Why" entity in the context which is a derived measure.
#
# Step 3: Convert the query into a structured output
# - The "Discount" entity is the main measure in the query, so it should be the top-level entity in the structured output.
# - The "Phone" entity is a filter, so it should be added as a child of the "Discount" entity.
# - The "dropped" adjective should be added as an adjective for the "Discount" entity.
# - The "Why" entity is a derived measure, so it should be added as a child of the "Discount" entity.
#
# Step 4: Check for date components and utilize date reference if needed
# - The query does not mention any date components, so the date reference is not utilized in this case.
#
# Rationale:
# The query asks for the reason (why) of the drop in discount of phones. To answer this, we need to identify the main measure (discount) and the filter (phones), and then add the derived measure (why) as a child of the main measure. The date reference is not utilized in this case as the query does not mention any date components.
#
# The structured output shows the identified components and their relationships, making it easier to understand and analyze the query.</s>
# CPU times: user 42 s, sys: 1 s, total: 43 s
# Wall time: 43 s

# %%
# %%time
user_query = "What was phone sales in q1 '23'?"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  What was phone sales in q1 '23'?
# ----------------------------------------------------------------------------------------------------
#   File <string>:3
#     "q1 '23"": [
#                 ^
# SyntaxError: EOL while scanning string literal

# %%
# %%time
user_query = "Phones least sold in 2021"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  Phones least sold in 2021
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'2021': [{'CONVERTED TIME ELEMENT': '2021', 'DATE RANGE': '2021', 'ENTITY': 'Order Date'}]}, 'DERIVED MEASURE': {'least sold': [{'APPLIED MEASURE': [{'discount': 'Discount'}], 'ENTITY': 'Ratio', 'RATIO FILTER': [{'COMPARISON VALUE': '0', 'COMPARSION OPERATOR': '<'}], 'TONE': 'negative'}]}, 'FILTER': {'phones': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - Phones: Sub-Category
# - least sold: Derived Measure (Ratio)
# - in 2021: Date Variable
#
# Step 2: Match the components to the context
# - Phones: Matches with 'Phone' in the context under FILTER with parent 'Sub-Category'
# - least sold: Matches with 'Ratio' in the context under DERIVED MEASURE
# - in 2021: Matches with 'Order Date' in the context under DATE VARIABLE
#
# Step 3: Convert the date component
# - 2021: Converted Time Element "2021"
# - Date Range: "2021"
# - Trend: "2021"
# - Time: "2021"
# - When: "2021"
# - MOM: "2021"
# - YY: "2021"
#
# Step 4: Create the structured output
# - DATE VARIABLE: {
#     "2021": [
#         {
#             "CONVERTED TIME ELEMENT": "2021",
#             "DATE RANGE": "2021",
#             "ENTITY": "Order Date"
#         }
#     ]
# }
# - DERIVED MEASURE: {
#     "least sold": [
#         {
#             "APPLIED MEASURE": [
#                 {
#                     "discount": "Discount"
#                 }
#             ],
#             "ENTITY": "Ratio",
#             "RATIO FILTER": [
#                 {
#                     "COMPARISON VALUE": "0",
#                     "COMPARSION OPERATOR": "<"
#                 }
#             ],
#             "TONE": "negative"
#         }
#     ]
# }
# - FILTER: {
#     "phones": [
#         {
#             "ENTITY": "Phone",
#             "PARENT": "Sub-Category"
#         }
#     ]
# }
#
# Note: The date reference 'start_date' and 'end_date' are not utilized in this conversion as the query only mentions the year '2021'.
#
# Rationale:
# - The query asks for the least sold phones in 2021, so we need to identify the Sub-Category 'Phone' and the Derived Measure 'Ratio' (with a negative tone)
# - We also need to convert the date component 'in 2021' to '2021' as a Time Element, Date Range, Trend, and When.
# - Finally, we create the structured output with the identified
# CPU times: user 1min, sys: 1.06 s, total: 1min 1s
# Wall time: 1min 1s

# %%
# %%time
user_query = "Phones most sold in 2021"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  Phones most sold in 2021
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'2021': [{'CONVERTED TIME ELEMENT': '2021', 'DATE RANGE': '2021', 'ENTITY': 'Order Date'}]}, 'DERIVED MEASURE': {'most sold': [{'APPLIED MEASURE': [{'sales': 'Sales'}], 'ENTITY': 'Ratio', 'RATIO FILTER': [{'COMPARISON VALUE': '', 'COMPARSION OPERATOR': ''}], 'TONE': 'positive'}]}, 'FILTER': {'phones': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - Phones: Sub-Category
# - most sold: Derived Measure (Ratio)
# - in 2021: Date Variable
#
# Step 2: Match the components to the context
# - Phones: Matches with 'Phone' in the context under FILTER with parent 'Sub-Category'
# - most sold: Matches with 'Ratio' in the context under DERIVED MEASURE
# - in 2021: Matches with 'Order Date' in the context under DATE VARIABLE
#
# Step 3: Convert the date component
# - In 2021: Converted to "2021" as it is a single year date.
#
# Step 4: Create the structured output
# - DATE VARIABLE: { "2021": [ { "CONVERTED TIME ELEMENT": "2021", "DATE RANGE": "2021", "ENTITY": "Order Date" } ] }
# - DERIVED MEASURE: { "most sold": [ { "APPLIED MEASURE": [ { "sales": "Sales" } ], "ENTITY": "Ratio", "RATIO FILTER": [ { "COMPARISON VALUE": "", "COMPARSION OPERATOR": "" } ], "TONE": "positive" } ] }
# - FILTER: { "phones": [ { "ENTITY": "Phone", "PARENT": "Sub-Category" } ] }
#
# Note: The date reference 'start_date' is not utilized in this conversion as the query only asks for data in 2021, which is already within the date range 'start_date' to 'end_date'.
#
# Rationale:
# The query asks for the most sold phones in 2021, so we need to identify the Sub-Category 'Phone' and the Derived Measure 'Ratio' (most sold). The Date Variable 'Order Date' is used to convert the year '2021' into a time element. The FILTER 'Sub-Category' is used to specify the phone category. The structured output is created based on these components and their matches in the context.
#
# The date reference is not utilized in this conversion as the query only asks for data in 2021, which is already within the date range 'start_date' to 'end_date'. Using the date reference would have required adjusting the structured output to include the date range 'start_date' to 'end_date', even though the query only asks for data in 2021.
#
# The structured output is created by identifying the relevant components in the query and their matches in the context. The Derived Measure 'Ratio' (
# CPU times: user 1min, sys: 1.06 s, total: 1min 1s
# Wall time: 1min 1s

# %%
# %%time
user_query = "In 02/19, What was the sales of phone?"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  In 02/19, What was the sales of phone?
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'02/19': [{'CONVERTED TIME ELEMENT': '02/19', 'DATE RANGE': '2023/02/19 - 2023/02/28', 'ENTITY': 'Order Date'}]}, 'FILTER': {'Phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The date component is "02/19".
# - The measure component is "sales".
# - The filter component is "Phone".
#
# Step 2: Match the components to the context
# - The date component "02/19" can be matched to the "Order Date" entity in the DATE VARIABLE context.
# - The measure component "sales" can be matched to the "Sales" entity in the MEASURE context.
# - The filter component "Phone" can be matched to the "Phone" entity in the FILTER context with its parent "Sub-Category".
#
# Step 3: Convert the date component
# - The date component "02/19" is converted to "02/19 - 02/28" as it falls within the month of February in 2023.
#
# Step 4: Create the structured output
# - The DATE VARIABLE section includes the "Order Date" entity and the converted date range "02/19 - 02/28".
# - The FILTER section includes the "Phone" entity with its parent "Sub-Category".
# - The MEASURE section includes the "Sales" entity.
#
# Rationale:
# - The query asks for the sales of phones in a specific date. Therefore, we need to identify the date, measure, and filter components in the query and match them to the context.
# - The date component is converted to a date range using the date reference provided.
# - The structured output is created by including the DATE VARIABLE, FILTER, and MEASURE sections with their respective entities and parents.
#
# Note: The date reference used in this conversion is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}. The date component "02/19" is converted to "02/19 - 02/28" as it falls within the month of February in 2023.
#
# [MQL]
# {
#     "DATE VARIABLE": {
#         "02/19": [
#             {
#                 "CONVERTED TIME ELEMENT": "02/19",
#                 "DATE RANGE": "2023/02/19 - 2023/02/28",
#                 "ENTITY": "Order Date"
#             }
#         ]
#     },
#     "FILTER": {
#         "Phone": [
#             {
#                 "ENTITY": "Phone",
#                 "PARENT": "Sub-Category"
#             }
#         ]
#     },
#     "MEASURE": {
#         "sales": [
#             {
#                 "ENTITY": "Sales"
#             }
#         ]
#     }
# }
# [/MQL]
# the date reference is not utilized in this conversion as the date component "02/19" is converted based on the month and year provided in the query. The
# CPU times: user 1min, sys: 1.08 s, total: 1min 1s
# Wall time: 1min 1s

# %%
# %%time
user_query = "In Feb 2019, What was the sales of phone?"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  In Feb 2019, What was the sales of phone?
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'Feb 2019': [{'CONVERTED TIME ELEMENT': 'month', 'DATE RANGE': '2019/02/01 - 2019/02/28', 'ENTITY': 'Order Date'}]}, 'FILTER': {'Phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query mentions "Feb 2019" which is a date component.
# - The query mentions "sales" which is a measure component.
# - The query mentions "Phone" which is a filter component.
#
# Step 2: Match the components to the context
# - "Feb 2019" can be matched to the "Order Date" entity in the DATE VARIABLE context with a month time element.
# - "Phone" can be matched to the "Phone" entity in the FILTER context with a parent of "Sub-Category".
# - "sales" can be matched to the "Sales" entity in the MEASURE context.
#
# Step 3: Convert the date component
# - The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}.
# - Since the query mentions "Feb 2019", we need to convert this date component to a month range.
# - "Feb 2019" corresponds to the month of February in the year 2019.
# - Therefore, the DATE VARIABLE output should include the month "February" in the range "2019/02/01 - 2019/02/28".
#
# Step 4: Create the structured output
# - The structured output should include the identified components and their corresponding context matches.
# - For the DATE VARIABLE, we include the "Order Date" entity with a month time element.
# - For the FILTER, we include the "Phone" entity with a parent of "Sub-Category".
# - For the MEASURE, we include the "Sales" entity.
#
# Rationale:
# - The query asks for the sales of phones in February 2019.
# - We need to identify the date component, measure component, and filter component in the query.
# - We then match these components to the context to ensure we are using the correct entities and time elements.
# - Finally, we create the structured output using the identified components and their context matches.
#
# The date reference is used to convert the date component "Feb 2019" to a month range "2019/02/01 - 2019/02/28". This is necessary because the query asks for sales in February 2019, so we need to use the month of February in the year 2019. The date reference is not used in the structured output itself, as it is used to convert the date component.
#
# The rationale for creating the structured output in this way is to ensure that we are using the correct entities and time elements from the context. By identifying the components in the query and matching them to the context, we can create a structured output that accurately represents the information being requested. The date reference is used to convert the date component to a month range, which is necessary to answer the query.</s>
# CPU times: user 59.2 s, sys: 1.1 s, total: 1min
# Wall time: 1min

# %%
# %%time
user_query = "worst performing sub category in 2021"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  worst performing sub category in 2021
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'2021': [{'CONVERTED TIME ELEMENT': '2021', 'DATE RANGE': '2021', 'ENTITY': 'Order Date'}]}, 'DIMENSION': {'sub category': [{'ENTITY': 'Sub-Category'}]}, 'MEASURE': {'worst performing': [{'ADJECTIVE': ['worst'], 'ENTITY': 'Ratio', 'RANK': [{'RANK ADJECTIVE': 'top', 'RANK VALUE': '1'}], 'TONE': 'negative'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query mentions "worst performing" which is an adjective and a rank.
# - The query also mentions "sub category" which is a dimension.
# - The query mentions "in 2021" which is a date variable.
#
# Step 2: Match the components to the context
# - "worst performing" can be matched to the "Ratio" measure in the context.
# - "sub category" can be matched to the "Sub-Category" dimension in the context.
# - "in 2021" can be matched to the "Order Date" date variable in the context.
#
# Step 3: Convert the date component
# - The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}.
# - Since the query mentions "in 2021", we need to convert the date component "2021" to a date range.
# - A date range of "2021" would be "2021-01-01" to "2021-12-31".
#
# Step 4: Create the structured output
# - The structured output should include the identified components and their corresponding matches in the context.
# - For the "MEASURE" section, the adjective "worst" and the rank "1" are included.
# - For the "DIMENSION" section, the "sub category" entity is included.
# - For the "DATE VARIABLE" section, the "Order Date" entity and the date range "2021-01-01" to "2021-12-31" are included.
#
# Rationale:
# - The query asks for the worst performing sub category in 2021.
# - By identifying the components in the query and matching them to the context, we can create a structured output that includes the relevant information.
# - The date component is converted using the date reference provided, ensuring that the date range used is accurate and consistent with the query.
# - The structured output follows the format specified in the MQL language, which is used to represent data in a structured manner.
#
# Overall, the structured output provides a clear and organized representation of the data requested in the query, making it easy to analyze and interpret.</s>
# CPU times: user 52.9 s, sys: 1.05 s, total: 54 s
# Wall time: 54 s

# %%
# %%time
user_query = "What was phone sales in jun '20'?"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  What was phone sales in jun '20'?
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {"jun '20'": [{'CONVERTED TIME ELEMENT': 'june 2020', 'DATE RANGE': '2020/06/01 - 2020/06/30', 'ENTITY': 'Order Date'}]}, 'FILTER': {'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query asks for "phone sales" in "jun '20'".
#
# Step 2: Match components to context
# - "phone" matches the "Phone" entity in the FILTER context.
# - "sales" matches the "Sales" entity in the MEASURE context.
# - "jun '20'" needs to be converted into a date range.
#
# Step 3: Convert date component
# - "jun '20'" can be converted into "june 2020".
# - The date reference {'start_date': '01/01/2020', 'end_date': '15/09/2023'} is not utilized here as the query specifically asks for sales in June 2020, which is outside the date range provided in the date reference.
#
# Step 4: Create structured output
# - The structured output should include the identified components and their corresponding context entities.
# - For the FILTER context, include "Phone" as the parent "Sub-Category".
# - For the MEASURE context, include "Sales" as the entity.
# - For the DATE VARIABLE context, include "Order Date" as the entity and the date range "2020/06/01 - 2020/06/30" for the converted date "june 2020".
#
# Rationale:
# - The query asks for sales of a specific product (Phone) in a particular month (June 2020).
# - The context provides the necessary information to identify the relevant entities and create a structured output that captures this information.
# - The date reference is not utilized in this case as the query specifically asks for sales in June 2020, which is outside the date range provided in the date reference.
#
# MQL tags:
# {
#     "DATE VARIABLE": {
#         "jun '20'": [
#             {
#                 "CONVERTED TIME ELEMENT": "june 2020",
#                 "DATE RANGE": "2020/06/01 - 2020/06/30",
#                 "ENTITY": "Order Date"
#             }
#         ]
#     },
#     "FILTER": {
#         "phone": [
#             {
#                 "ENTITY": "Phone",
#                 "PARENT": "Sub-Category"
#             }
#         ]
#     },
#     "MEASURE": {
#         "sales": [
#             {
#                 "ENTITY": "Sales"
#             }
#         ]
#     }
# }
# [MQL]
# the MQL tags are generated based on the structured output created above. They represent the identified components and their corresponding context entities in a machine-readable format.</s>
# CPU times: user 57.4 s, sys: 1.05 s, total: 58.4 s
# Wall time: 58.5 s

# %%
# %%time
user_query = "Growth rate of sales share of phone"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  Growth rate of sales share of phone
# ----------------------------------------------------------------------------------------------------
# {'DERIVED MEASURE': {'growth rate': [{'APPLIED MEASURE': [{'sales': 'Sales'}], 'DERIVED MEASURE CONSTRAINT': [{'COMPARISON VALUE': '', 'COMPARSION OPERATOR': ''}], 'ENTITY': 'Growth Rate', 'RATIO FILTER': [{'FILTER': 'Phone', 'FILTER RANGE': ''}]}], 'sales share': [{'APPLIED MEASURE': [{'sales': 'Sales'}], 'DERIVED MEASURE CONSTRAINT': [{'COMPARISON VALUE': '', 'COMPARSION OPERATOR': ''}], 'ENTITY': 'Ratio', 'RATIO FILTER': [{'FILTER': 'Phone', 'FILTER RANGE': ''}]}]}, 'FILTER': {'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - Growth rate
# - Sales share
# - Phone
#
# Step 2: Match the components to the context
# - Growth rate: Derived Measure (Growth Rate)
# - Sales share: Derived Measure (Ratio)
# - Phone: Filter (Phone)
#
# Step 3: Convert the query into structured output
# - Growth rate:
#     - Applied Measure: Sales
#     - Derived Measure Constraint: None
#     - Entity: Growth Rate
#     - Ratio Filter: Phone
# - Sales share:
#     - Applied Measure: Sales
#     - Derived Measure Constraint: None
#     - Entity: Ratio
#     - Ratio Filter: Phone
# - Phone:
#     - Entity: Phone
#     - Parent: Sub-Category
#
# Step 4: Check for date components and utilize date reference if needed
# - The query does not have any date components, so the date reference is not utilized in this case.
#
# Rationale:
# - The query asks for the growth rate of sales share for the phone sub-category. To answer this, we need to identify the relevant derived measures and filters from the context and match them to the query.
# - The derived measures used are Growth Rate and Ratio, which require the Sales measure as their applied measure. The Ratio constraint specifies that the phone sub-category should be used as the ratio filter.
# - The filter used is Phone, which has a parent of Sub-Category.
# - Since the query does not have any date components, the date reference is not utilized in the structured output.
#
# Note: The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}. However, the query does not have any date components, so the date reference is not utilized in the structured output.
#
# [MQL]
# {
#     "DERIVED MEASURE": {
#         "growth rate": [
#             {
#                 "APPLIED MEASURE": [
#                     {
#                         "sales": "Sales"
#                     }
#                 ],
#
# CPU times: user 1min, sys: 1.01 s, total: 1min 1s
# Wall time: 1min 1s

# %%
# %%time
user_query = "which are the 5 top selling sub category by sales in 2023"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  which are the 5 top selling sub category by sales in 2023
# ----------------------------------------------------------------------------------------------------
# {'DIMENSION': {'sub category': [{'ENTITY': 'Sub-Category', 'RANK': [{'RANK ADJECTIVE': 'top', 'RANK VALUE': '5'}]}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}, 'DATE VARIABLE': {'2023': [{'ENTITY': 'Date Variable', 'DATE ADJECTIVE': 'in 2023', 'DATE VALUE': '2023'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - "5 top selling": Rank adjective "top" and rank value "5"
# - "sub category": Dimension "Sub-Category"
# - "sales": Measure "Sales"
# - "in 2023": Date variable "Date Variable" with date adjective "in" and date value "2023"
#
# Step 2: Match the components to the context
# - "top selling" matches with the dimension "Sub-Category" and the measure "Sales"
# - "sub category" matches with the dimension "Sub-Category"
# - "sales" matches with the measure "Sales"
# - "in 2023" matches with the date variable "Date Variable" and the date adjective "in" matches with the date reference 'start_date' as it is in the future, and the date value "2023" matches with the date reference 'end_date' as it is in the future.
#
# Step 3: Convert the query into a structured output
# - For the dimension "Sub-Category", add the rank adjective "top" and the rank value "5" as RANK.
# - For the dimension "Sub-Category", add the entity "Sub-Category" as ENTITY.
# - For the measure "Sales", add the entity "Sales" as ENTITY.
# - For the date variable "Date Variable", add the date adjective "in 2023" as DATE ADJECTIVE and the date value "2023" as DATE VALUE.
#
# Step 4: Check for any additional conversion
# - There are no additional conversions needed as the query is asking for the top selling sub-category by sales in 2023, which is already captured in the structured output.
#
# Rationale:
# The query asks for the top selling sub-category by sales in 2023. The context provides the necessary components to convert this query into a structured output. The date reference 'start_date' and 'end_date' are not utilized in this conversion as the query is asking for sales in the future, which is not within the date range provided in the date reference. The structured output captures the dimension "Sub-Category", the measure "Sales", and the date variable "Date Variable" with the date adjective "in" and the date value "2023".
#
# Note: The date reference 'start_date' and 'end_date' are not utilized in this conversion as the query is asking for sales in the future, which is not within the date range provided in the date reference. The structured output captures the dimension "Sub-Category", the measure "Sales", and the date variable "Date Variable" with the date adjective "in" and the date value "2023".</s>
# CPU times: user 57.8 s, sys: 1.06 s, total: 58.9 s
# Wall time: 58.9 s

# %%
# %%time
user_query = "how does the sales change for phone in the last year"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  how does the sales change for phone in the last year
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'last year': [{'CONVERTED TIME ELEMENT': 'last year', 'DATE RANGE': '2022/09/15 - 2023/09/15', 'ENTITY': 'Order Date'}]}, 'FILTER': {'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query asks for "sales" which can be matched to the "Sales" entity in the context under MEASURE.
# - The query mentions "phone" which can be matched to the "Phone" entity in the context under FILTER with parent "Sub-Category".
# - The query asks for "sales" to be considered in the "last year" time frame which can be matched to the "Order Date" entity in the context under DATE VARIABLE.
#
# Step 2: Match components to context
# - "Sales" is matched to the "Sales" entity in the context under MEASURE.
# - "Phone" is matched to the "Phone" entity in the context under FILTER with parent "Sub-Category".
# - "last year" is matched to the "Order Date" entity in the context under DATE VARIABLE.
#
# Step 3: Convert date component
# - The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}.
# - The query asks for "sales" in the "last year" time frame.
# - To convert the date component "last year", we need to consider the end date in the date reference ('15/09/2023') and calculate the date range for the previous year.
# - The end date in the date reference is '15/09/2023', so the previous year's date range would be from '2022/09/15' to '2023/09/15'.
#
# Step 4: Create structured output
# - The structured output is created by combining the matched components from the context and the converted date component.
# - The MEASURE section includes the "Sales" entity.
# - The FILTER section includes the "Phone" entity with parent "Sub-Category".
# - The DATE VARIABLE section includes the "Order Date" entity with the calculated date range "2022/09/15 - 2023/09/15".
#
# Rationale:
# - The query asks for sales data for the phone sub-category in the last year.
# - We identified the relevant components from the context and matched them to the query.
# - We converted the date component "last year" by calculating the date range for the previous year using the date reference provided.
# - We created the structured output by combining the matched components and the converted date component.
# - The date reference is used to calculate the date range for the previous year, ensuring that the query is answered accurately.
#
# Note: The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}. The query asks for sales data in the last year, so we calculate the date range for the previous year (2022/09/15 - 2023/09/15) using the start_date and end_date in the date reference.
#
# [
# CPU times: user 1min, sys: 1.03 s, total: 1min 1s
# Wall time: 1min 1s

# %%
# %%time
user_query = "what is sales of phone in q1 2023"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  what is sales of phone in q1 2023
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'q1 2023': [{'CONVERTED TIME ELEMENT': 'quarter 1 2023', 'DATE RANGE': '2023/01/01 - 2023/03/31', 'ENTITY': 'Order Date'}]}, 'FILTER': {'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query asks for "sales of phone" in "q1 2023".
#
# Step 2: Match components to the context
# - "sales" can be matched to the "Sales" entity in the MEASURE context.
# - "phone" can be matched to the "Phone" entity in the FILTER context with parent "Sub-Category".
# - "q1 2023" needs to be converted into a date range.
#
# Step 3: Convert date component
# - "q1 2023" refers to quarter 1 of the year 2023.
# - In the date reference, the start date is '01/01/2020' and the end date is '15/09/2023'.
# - Quarter 1 of 2023 falls between January 1, 2020 and March 31, 2023.
# - The date range for quarter 1 2023 is "2023/01/01 - 2023/03/31".
#
# Step 4: Create structured output
# - The structured output should include the identified components and their corresponding context entities.
# - For the MEASURE, include "Sales" as the entity.
# - For the FILTER, include "Phone" as the entity with its parent "Sub-Category".
# - For the DATE VARIABLE, include "Order Date" as the entity and the date range "2023/01/01 - 2023/03/31" for quarter 1 2023.
#
# Rationale:
# - The query asks for sales data of a specific phone model in a particular quarter of a given year.
# - The context provides the necessary entities and their relationships to create a structured output that captures the required information.
# - The date reference is used to convert the date component "q1 2023" into a date range that falls within the specified year.
# - The structured output follows the MQL format and includes the identified components and their corresponding context entities.
#
# Overall, the query is converted into a structured output by identifying the required components, matching them to the context, and converting the date component using the date reference. The structured output captures the sales data of the phone model in the specified quarter of the year.</s>
# CPU times: user 50.8 s, sys: 1.05 s, total: 51.9 s
# Wall time: 51.9 s

# %%
# %%time
user_query = "what is sales of phone in q3"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  what is sales of phone in q3
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'q3': [{'CONVERTED TIME ELEMENT': 'quarter 3', 'DATE RANGE': '2023/03/01 - 2023/06/30', 'ENTITY': 'Order Date'}]}, 'FILTER': {'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query asks for "sales of phone in q3".
# - Components: sales, phone, q3
#
# Step 2: Match components to the context
# - Sales: Found in the context under 'MEASURE' with the ENTITY 'Sales'
# - Phone: Found in the context under 'FILTER' with the ENTITY 'Phone' and parent 'Sub-Category'
# - Q3: Since the date reference is not utilized here, we need to convert it manually. Q3 stands for quarter 3, which means the time period is from January 1, 2023 to June 30, 2023.
#
# Step 3: Create structured output
# - DATE VARIABLE: Add the converted time element 'quarter 3' with the date range '2023/03/01 - 2023/06/30' and the ENTITY 'Order Date'
# - FILTER: Add the ENTITY 'Phone' with its parent 'Sub-Category'
# - MEASURE: Add the ENTITY 'Sales'
#
# Rationale:
# - The query asks for sales of a specific phone model in a particular time period (Q3). We identified the relevant components and matched them to the context. Then, we created the structured output by including the date variable, filter, and measure based on the matched components.
#
# The date reference is not utilized in this case as the query does not specifically ask for data in a particular time period. Instead, we manually convert the query's time period (Q3) into a date range (January 1, 2023 to June 30, 2023) and add it as a date variable in the structured output.
#
# Note: The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}. It is not utilized in the structured output as the query does not specifically ask for data in a particular time period.</s>
# CPU times: user 45.1 s, sys: 1.05 s, total: 46.1 s
# Wall time: 46.1 s

# %%
# %%time
user_query = "what is sales of phone in q1"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  what is sales of phone in q1
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'q1': [{'CONVERTED TIME ELEMENT': 'quarter 1', 'DATE RANGE': '2023/01/01 - 2023/03/31', 'ENTITY': 'Order Date'}]}, 'FILTER': {'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query asks for "sales of phone" in "q1".
#
# Step 2: Match components to the context
# - "sales" can be matched to the "Sales" entity in the MEASURE context.
# - "phone" can be matched to the "Phone" entity in the FILTER context with parent "Sub-Category".
# - "q1" needs to be converted into a date range for quarter 1 of 2023.
#
# Step 3: Convert date component
# - The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}.
# - Quarter 1 of 2023 has a date range of "2023/01/01 - 2023/03/31".
# - The "Order Date" entity in the DATE VARIABLE context is used to represent the sales data.
#
# Step 4: Create structured output
# - The structured output should include the identified components and their corresponding context entities.
# - For the MEASURE, include "Sales" as the entity.
# - For the FILTER, include "Phone" as the entity with its parent "Sub-Category".
# - For the DATE VARIABLE, include "Order Date" as the entity and the date range "2023/01/01 - 2023/03/31" for quarter 1 of 2023.
#
# Rationale:
# - The query asks for sales data of a specific phone model in a particular quarter.
# - The context provides the necessary entities and their relationships to represent this information.
# - The date reference is used to convert the date component "q1" into a date range for quarter 1 of 2023.
# - The structured output includes the identified components and their corresponding context entities, allowing for easy analysis and interpretation of the sales data.
#
# Note: The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}. However, since the query asks for sales data in quarter 1 of 2023, the date range used in the structured output is "2023/01/01 - 2023/03/31". The end_date in the date reference is not utilized in this case.
#
# Rating: [4/5]
# The structured output is created based on the query and context provided. The date component is converted correctly, and the identified components are included in the output with their corresponding context entities. However, the date reference is not fully utilized as the query asks for sales data in quarter 1 of 2023, which has a specific date range. A more detailed date reference could have been included to better represent the sales data.
# [MQL]
# {
#     "DATE VARIABLE": {
#         "q1": [
#             {
#                 "CONVERTED TIME ELEMENT": "quarter 1",
#
# CPU times: user 1min, sys: 1.02 s, total: 1min 1s
# Wall time: 1min 1s

# %%
# %%time
user_query = "what as sales of phone in last one and half years"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  what as sales of phone in last one and half years
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'last one and half years': [{'CONVERTED TIME ELEMENT': 'last one and half years', 'DATE RANGE': '2022/03/15 - 2023/09/15', 'ENTITY': 'Order Date'}]}, 'FILTER': {'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query asks for "sales" of "phone" in "last one and half years".
#
# Step 2: Match the components to the context
# - "sales" can be matched to the "Sales" entity in the MEASURE context.
# - "phone" can be matched to the "Phone" entity in the FILTER context with its parent "Sub-Category".
# - "last one and half years" needs to be converted into a date range.
#
# Step 3: Convert the date component
# - The date component "last one and half years" can be converted into a date range by calculating the start date and end date.
# - The end date is given in the date reference as '15/09/2023'.
# - To find the start date, we need to go back one and a half years from the end date.
# - One and a half years is equivalent to 18 months.
# - Subtracting 18 months from the end date (15/09/2023) gives us the start date (15/03/2022).
#
# Step 4: Create the structured output
# - The structured output should include the identified components and their corresponding context entities.
# - For the MEASURE, include the "Sales" entity.
# - For the FILTER, include the "Phone" entity with its parent "Sub-Category".
# - For the DATE VARIABLE, include the "Order Date" entity and the calculated date range (2022/03/15 - 2023/09/15) for the date component "last one and half years".
#
# Rationale:
# - The query asks for sales data, so the MEASURE context is used to identify the "Sales" entity.
# - The query also mentions a specific product, "phone", which is in the FILTER context with its parent "Sub-Category".
# - The date component "last one and half years" needs to be converted into a date range using the date reference provided.
# - The date reference provides a start date (01/01/2020) and an end date (15/09/2023), but the query asks for a date range that is one and a half years before the end date.
# - To calculate the start date, we subtract one and a half years (18 months) from the end date.
# - The structured output should include the identified components and their corresponding context entities, as well as the converted date range.
#
# Overall, the query is asking for sales data of the "Phone" product in the last one and half years, so the structured output includes the "Sales" entity from the MEASURE context, the "Phone" entity from the FILTER context with its parent "Sub-Category", and the converted date range (2022/03/15 - 2023/09/15) for the date component "last one and half years".</s>
# CPU times: user 59.4 s, sys: 1 s, total: 1min
# Wall time: 1min

# %%
# %%time
user_query = "what is sales of phone now"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  what is sales of phone now
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'now': [{'CONVERTED TIME ELEMENT': 'now', 'DATE RANGE': '2023/09/15 - 2023/09/15', 'ENTITY': 'Order Date'}]}, 'FILTER': {'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query asks for "sales of phone now". The components are "sales", "phone", and "now".
#
# Step 2: Match components to the context
# - "sales" can be matched to the "Sales" entity in the MEASURE context.
# - "phone" can be matched to the "Phone" entity in the FILTER context with its parent "Sub-Category".
# - "now" can be matched to the "Order Date" entity in the DATE VARIABLE context.
#
# Step 3: Convert date component
# - The query asks for "now", which is a date reference. The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}. Since the query asks for "now", we can assume it is asking for the date "15/09/2023" as it is the most recent date in the date reference.
# - The "Order Date" entity in the DATE VARIABLE context is matched to the "now" component, and its date range is set to "2023/09/15 - 2023/09/15" as it is the only date in the date reference.
#
# Step 4: Create structured output
# - The structured output is created by combining the matched components from the context with the converted date component.
# - The MEASURE section includes the "Sales" entity.
# - The FILTER section includes the "Phone" entity with its parent "Sub-Category".
# - The DATE VARIABLE section includes the "Order Date" entity with its converted date range "2023/09/15 - 2023/09/15".
#
# Rationale:
# - The query asks for the sales of the phone model now, so we need to identify the sales measure, the phone filter, and the current date.
# - The context provides the necessary information to match the components in the query to their corresponding entities.
# - The date reference is used to convert the "now" component to a specific date range.
# - The structured output is created by combining the matched components and the converted date component.
#
# The structured output provides a clear and organized representation of the query, making it easier to analyze and process the data.</s>
# CPU times: user 48.9 s, sys: 1.08 s, total: 50 s
# Wall time: 50 s

# %%
# %%time
user_query = "what is sales of phone in 1st quarter 2022"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  what is sales of phone in 1st quarter 2022
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'1st quarter 2022': [{'CONVERTED TIME ELEMENT': 'first quarter 2022', 'DATE RANGE': '2022/01/01 - 2022/03/31', 'ENTITY': 'Order Date'}]}, 'FILTER': {'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query asks for "sales" of "phone" in "1st quarter 2022".
#
# Step 2: Match components to the context
# - "sales" can be matched to the "Sales" entity in the MEASURE context.
# - "phone" can be matched to the "Phone" entity in the FILTER context with a parent of "Sub-Category".
# - "1st quarter 2022" can be matched to the "Order Date" entity in the DATE VARIABLE context.
#
# Step 3: Convert date component
# - The date component "1st quarter 2022" is converted to "first quarter 2022" and given a date range of "2022/01/01 - 2022/03/31".
#
# Step 4: Create structured output
# - The structured output is created by combining the matched components from the context.
#
# Rationale:
# - The query asks for sales data, so the MEASURE context is used to identify the "Sales" entity.
# - The query specifies a product, so the FILTER context is used to identify the "Phone" entity with a parent of "Sub-Category".
# - The query asks for sales data in a specific time period, so the DATE VARIABLE context is used to identify the "Order Date" entity and convert the date component "1st quarter 2022" into a date range.
#
# The date reference is not utilized in this conversion as the query specifically asks for sales data in "1st quarter 2022", which falls outside the date range provided in the date reference.
#
# Overall, the structured output is created by matching the components in the query to the context and converting the date component as needed. The date reference is not utilized in this conversion as the query asks for sales data in a specific time period that does not match the date reference.</s>
# CPU times: user 44 s, sys: 1.05 s, total: 45 s
# Wall time: 45 s

# %%
# %%time
user_query = "what is sales of phone in 1st quarter 2019"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  what is sales of phone in 1st quarter 2019
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'1st quarter 2019': [{'CONVERTED TIME ELEMENT': 'first quarter 2019', 'DATE RANGE': '2019/01/01 - 2019/03/31', 'ENTITY': 'Order Date'}]}, 'FILTER': {'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query asks for "sales" of "phone" in "1st quarter 2019".
#
# Step 2: Match components to the context
# - "sales" can be matched to the "Sales" entity in the MEASURE context.
# - "phone" can be matched to the "Phone" entity in the FILTER context with a parent of "Sub-Category".
# - "1st quarter 2019" can be matched to the "Order Date" entity in the DATE VARIABLE context.
#
# Step 3: Convert date component
# - The date component "1st quarter 2019" is converted to "first quarter 2019" and given a date range of "2019/01/01 - 2019/03/31".
#
# Step 4: Create structured output
# - The structured output is created by combining the matched components from the context.
#
# Step 5: Check date reference
# - The date component "1st quarter 2019" falls within the date reference provided, which is from "01/01/2020" to "15/09/2023".
#
# Rationale:
# - The query asks for sales data of a specific product (phone) in a particular time period (1st quarter 2019).
# - The context provides the necessary information to match the components in the query to relevant entities.
# - The date reference is checked to ensure the date component falls within the specified date range.
#
# The structured output is created by combining the matched components from the context, providing a clear and organized representation of the query.
#
# [MQL]
# {
#     "DATE VARIABLE": {
#         "first quarter 2019": [
#             {
#                 "CONVERTED TIME ELEMENT": "first quarter 2019",
#                 "DATE RANGE": "2019/01/01 - 2019/03/31",
#                 "ENTITY": "Order Date"
#             }
#         ]
#     },
#     "FILTER": {
#         "phone": [
#             {
#                 "ENTITY": "Phone",
#                 "PARENT": "Sub-Category"
#             }
#         ]
#     },
#     "MEASURE": {
#         "sales": [
#             {
#                 "ENTITY": "Sales"
#             }
#         ]
#     }
# }
# [/MQL]
# the date reference is checked by comparing the date component "1st quarter 2019" with the start_date and end_date provided in the date reference.
# {
#     "start_date": "01/01/2020",
#     "end_date": "15/09/2023"
# }
# since the date component "1st quarter 2019" falls within the date reference provided, the date reference is considered valid for
# CPU times: user 1min, sys: 1.04 s, total: 1min 1s
# Wall time: 1min 1s

# %%
# %%time
user_query = "what is sales of phone in q1 2023"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  what is sales of phone in q1 2023
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'q1 2023': [{'CONVERTED TIME ELEMENT': 'quarter 1 2023', 'DATE RANGE': '2023/01/01 - 2023/03/31', 'ENTITY': 'Order Date'}]}, 'FILTER': {'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query asks for "sales of phone" in "q1 2023".
#
# Step 2: Match components to the context
# - "sales" can be matched to the "Sales" entity in the MEASURE context.
# - "phone" can be matched to the "Phone" entity in the FILTER context with parent "Sub-Category".
# - "q1 2023" needs to be converted into a date range.
#
# Step 3: Convert date component
# - "q1 2023" refers to quarter 1 of the year 2023.
# - In the date reference, the start date is '01/01/2020' and the end date is '15/09/2023'.
# - Quarter 1 of 2023 falls between January 1, 2020 and March 31, 2023.
# - The date range for quarter 1 2023 is "2023/01/01 - 2023/03/31".
#
# Step 4: Create structured output
# - The structured output should include the identified components and their corresponding context entities.
# - For the MEASURE, include "Sales" as the entity.
# - For the FILTER, include "Phone" as the entity with its parent "Sub-Category".
# - For the DATE VARIABLE, include "Order Date" as the entity and the date range "2023/01/01 - 2023/03/31" for quarter 1 2023.
#
# Rationale:
# - The query asks for sales data of a specific phone model in a particular quarter of a given year.
# - The context provides the necessary entities and their relationships to create a structured output that captures the required information.
# - The date reference is used to convert the date component "q1 2023" into a date range that falls within the specified year.
# - The structured output follows the MQL format and includes the identified components and their corresponding context entities.
#
# Overall, the query is converted into a structured output by identifying the required components, matching them to the context, and converting the date component using the date reference. The structured output captures the sales data of the phone model in the specified quarter of the year.</s>
# CPU times: user 50.8 s, sys: 1.03 s, total: 51.8 s
# Wall time: 51.8 s

# %%
# %%time
user_query = "what is sales of phone in Feb 2023"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  what is sales of phone in Feb 2023
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'Feb 2023': [{'CONVERTED TIME ELEMENT': 'February 2023', 'DATE RANGE': '2023/02/01 - 2023/02/28', 'ENTITY': 'Order Date'}]}, 'FILTER': {'Phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query asks for "sales of phone" which can be broken down into "sales" and "phone".
# - The query also specifies the date component "Feb 2023".
#
# Step 2: Match the components to the context
# - "sales" can be matched to the "Sales" entity in the MEASURE context.
# - "phone" can be matched to the "Phone" entity in the FILTER context with a parent of "Sub-Category".
# - "Feb 2023" can be matched to the "Order Date" entity in the DATE VARIABLE context.
#
# Step 3: Convert the date component
# - The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}.
# - However, the query asks for sales in February 2023, which is outside the date reference provided.
# - To handle this, we need to convert the date component "Feb 2023" into a date range of "2023/02/01 - 2023/02/28".
# - This date range falls within the date reference provided, as the start date is "01/01/2020" and the end date is "15/09/2023", both of which are before February 2023.
#
# Step 4: Create the structured output
# - The structured output should include the identified and matched components from the query and context.
# - For the MEASURE, we include the "Sales" entity.
# - For the FILTER, we include the "Phone" entity with a parent of "Sub-Category".
# - For the DATE VARIABLE, we include the "Order Date" entity with the converted date range of "2023/02/01 - 2023/02/28".
#
# Rationale:
# - The query asks for sales of phone in February 2023, which requires identifying the relevant components from the query and context, converting the date component, and creating a structured output that includes these components.
# - The context provides information about the different entities, their parents, and the date reference.
# - By following the steps outlined above, we can create a structured output that accurately represents the query and provides useful insights for analysis.
# - The date reference provided is not utilized in this case as the query asks for sales in February 2023, which is outside the date reference provided. The date reference is used to ensure the date range used in the structured output is within the date reference provided.
# - The rationale is to identify the relevant components from the query and context, convert the date component, and create a structured output that includes these components. This allows for accurate and useful analysis of the sales data.</s>
# CPU times: user 57.9 s, sys: 1.03 s, total: 58.9 s
# Wall time: 58.9 s

# %%
# %%time
user_query = "what is sales of phone in Sep 2023"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  what is sales of phone in Sep 2023
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'Sep 2023': [{'CONVERTED TIME ELEMENT': 'Sep 2023', 'DATE RANGE': '2023/09/15 - 2023/09/30', 'ENTITY': 'Order Date'}]}, 'FILTER': {'Phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query asks for "sales of phone" which can be broken down into "sales" and "phone".
# - The query also specifies a date range "Sep 2023"
#
# Step 2: Match the components to the context
# - "sales" can be matched to the "Sales" entity in the MEASURE context.
# - "phone" can be matched to the "Phone" entity in the FILTER context with a parent of "Sub-Category".
# - "Sep 2023" can be matched to the "Order Date" entity in the DATE VARIABLE context.
#
# Step 3: Convert the date component
# - The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}.
# - The query asks for "Sep 2023" so we need to convert "Sep 2023" to a date range.
# - To do this, we can use the end_date provided in the date reference and assume that "Sep 2023" is on or after the end_date.
# - The end_date is '15/09/2023', so we can assume that "Sep 2023" is on or after '15/09/2023'.
# - Therefore, the date range for "Sep 2023" is "2023/09/15 - 2023/09/30".
#
# Step 4: Create the structured output
# - The structured output should include the matched components from the context and the converted date component.
# - For the MEASURE, we include the "Sales" entity.
# - For the FILTER, we include the "Phone" entity with its parent "Sub-Category".
# - For the DATE VARIABLE, we include the "Order Date" entity with the converted date range "2023/09/15 - 2023/09/30".
#
# The structured output is created based on the identified components in the query and their corresponding matches in the context, as well as the converted date component. The date reference is used to assist in converting the date component.
#
# Rationale:
# - The query asks for sales of phone in Sep 2023, so we need to include the "Sales" entity in the MEASURE, the "Phone" entity in the FILTER with its parent "Sub-Category", and the converted date range "2023/09/15 - 2023/09/30" for the "Order Date" entity in the DATE VARIABLE.
# - The date reference is used to assist in converting the date component "Sep 2023" to a date range "2023/09/15 - 2023/09/30".
# - The rationale for the date range is that the query asks for sales in
# CPU times: user 1min, sys: 1.06 s, total: 1min 1s
# Wall time: 1min 1s

# %%
# %%time
user_query = "what is sales of phone in last one and half month"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  what is sales of phone in last one and half month
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'last one and half month': [{'CONVERTED TIME ELEMENT': 'last one and half month', 'DATE RANGE': '2023/07/15 - 2023/09/15', 'ENTITY': 'Order Date'}]}, 'FILTER': {'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query asks for "sales" of "phone" in "last one and half month".
#
# Step 2: Match components to the context
# - "sales" can be matched to the "Sales" entity in the MEASURE context.
# - "phone" can be matched to the "Phone" entity in the FILTER context with its parent "Sub-Category".
# - "last one and half month" needs to be converted into a date range.
#
# Step 3: Convert date component
# - "last one and half month" can be converted into a date range of "2023/07/15 - 2023/09/15" as it is one and a half months from July 15, 2023.
#
# Step 4: Create structured output
# - The structured output should include the identified components and their respective context categories.
# - For the "DATE VARIABLE" category, the converted date range "2023/07/15 - 2023/09/15" is included along with the "Order Date" entity.
# - For the "FILTER" category, the "Phone" entity is included with its parent "Sub-Category".
# - For the "MEASURE" category, the "Sales" entity is included.
#
# Step 5: Check date reference
# - The date range "2023/07/15 - 2023/09/15" falls within the date reference provided, which is from "01/01/2020" to "15/09/2023".
#
# Rationale:
# - The query asks for sales data of a specific product (phone) in a date range.
# - The context provides the necessary entities and their relationships to identify the product and measure (sales).
# - The date reference is checked to ensure the date range requested is within the provided date reference.
# - The structured output is created by including the identified components and their respective context categories.
#
# The structured output provides a clear and organized representation of the query, making it easier to analyze and process the data.</s>
# CPU times: user 46.3 s, sys: 1.03 s, total: 47.3 s
# Wall time: 47.3 s

# %%
# %%time
user_query = "what is sales of phone in 01/2023"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  what is sales of phone in 01/2023
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'01/2023': [{'CONVERTED TIME ELEMENT': '01/2023', 'DATE RANGE': '2023/01/01 - 2023/01/31', 'ENTITY': 'Order Date'}]}, 'FILTER': {'Phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'Sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query asks for "sales of phone"
# - The date component is "01/2023"
#
# Step 2: Match the components to the context
# - "sales" can be matched to the "Sales" entity in the MEASURE context
# - "phone" can be matched to the "Phone" entity in the FILTER context with the parent "Sub-Category"
# - "01/2023" can be matched to the "Order Date" entity in the DATE VARIABLE context
#
# Step 3: Convert the date component
# - The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}.
# - Since the query asks for sales in "01/2023", we need to convert this date component to a date range.
# - "01/2023" is not within the date reference provided, so we cannot use the date reference to determine the date range.
# - Therefore, the date range for "01/2023" is not available in the structured output.
#
# Step 4: Create the structured output
# - The structured output should include the identified components and their corresponding context entities.
# - For the query "sales of phone in 01/2023", the structured output should include:
#   - "Sales": {
#     "ENTITY": "Sales"
#   }
#   - "Phone": {
#     "ENTITY": "Phone",
#     "PARENT": "Sub-Category"
#   }
#
# Rationale:
# - The query asks for sales of a specific phone model, so we include the "Sales" entity and the "Phone" entity in the structured output.
# - The date component "01/2023" is not available in the structured output as the date reference provided does not include this date.
# - The parent of the "Phone" entity is "Sub-Category", so this information is included in the structured output as well.
#
# The structured output created above is based on the identified components in the query and their corresponding context entities. The date component "01/2023" could not be converted to a date range using the date reference provided, so this information is not included in the structured output.</s>
# CPU times: user 49.2 s, sys: 1.01 s, total: 50.2 s
# Wall time: 50.2 s

# %%
# %%time
user_query = "what is sales of phone in 01/22"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  what is sales of phone in 01/22
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'01/22': [{'CONVERTED TIME ELEMENT': '01/22', 'DATE RANGE': '2023/01/22 - 2023/01/22', 'ENTITY': 'Order Date'}]}, 'FILTER': {'Phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'Sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query asks for "sales of phone"
# - The date component is "01/22"
#
# Step 2: Match components to the context
# - "sales" can be matched to the "Sales" entity in the MEASURE context
# - "phone" can be matched to the "Phone" entity in the FILTER context with parent "Sub-Category"
# - "01/22" can be matched to the "Order Date" entity in the DATE VARIABLE context
#
# Step 3: Convert date component
# - The date component "01/22" is a MM/DD format, so it needs to be converted to YY/MM/DD format.
# - In this case, "01/22" becomes "2023/01/22"
#
# Step 4: Create structured output
# - The structured output should include the identified components and their corresponding context entities.
# - For the MEASURE, it should include "Sales"
# - For the FILTER, it should include "Phone" with its parent "Sub-Category"
# - For the DATE VARIABLE, it should include "Order Date" with the converted date range "2023/01/22 - 2023/01/22"
#
# Step 5: Check against date reference
# - The date component "01/22" is within the date reference provided, which is from "01/01/2020" to "15/09/2023".
# - Since "01/22" is within the date reference, the structured output does not need to include any additional date-related information.
#
# Rationale:
# - The query asks for sales of a specific phone model, which can be identified using the FILTER context.
# - The date component "01/22" is converted to the correct format and checked against the date reference to ensure it falls within the valid date range.
# - The structured output includes the identified components and their corresponding context entities, providing a clear and organized representation of the query.
#
# The structured output is created by identifying the components in the query, matching them to the context, converting the date component, and checking against the date reference. This process ensures that the output is accurate and provides all the necessary information for understanding the query.</s>
# CPU times: user 48.5 s, sys: 1.06 s, total: 49.5 s
# Wall time: 49.5 s

# %%
# %%time
user_query = "what is sales of phone in last 2.5 years"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  what is sales of phone in last 2.5 years
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'last 2.5 years': [{'CONVERTED TIME ELEMENT': 'last 2.5 years', 'DATE RANGE': '2021-03-15/2023-09-15', 'ENTITY': 'Order Date'}]}, 'FILTER': {'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query asks for "sales of phone"
# - The query specifies a time period "last 2.5 years"
#
# Step 2: Match the components to the context
# - "sales" can be matched to the "Sales" entity in the MEASURE context
# - "phone" can be matched to the "Phone" entity in the FILTER context with a parent "Sub-Category"
# - "last 2.5 years" can be matched to the "Order Date" entity in the DATE VARIABLE context
#
# Step 3: Convert the date component
# - The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}.
# - The query asks for "last 2.5 years", which is greater than the end_date in the date reference.
# - To account for this, we need to calculate the start date of the 2.5 year period from the end_date in the date reference.
# - The end_date is '15/09/2023', so 2.5 years from this date would be '15/03/2026'.
# - The date range for the query is then '2021-03-15/2023-09-15'.
#
# Step 4: Create the structured output
# - The structured output is created by combining the matched components from the context and the converted date component.
# - The MEASURE section includes the "Sales" entity.
# - The FILTER section includes the "Phone" entity with a parent "Sub-Category".
# - The DATE VARIABLE section includes the "Order Date" entity with the calculated date range '2021-03-15/2023-09-15'.
#
# Rationale:
# - The query asks for sales of a specific phone model, so we need to include the "Phone" entity in the FILTER section with a parent "Sub-Category".
# - The query also asks for sales data over a specific time period, so we need to include the "Order Date" entity in the DATE VARIABLE section and calculate the date range based on the end_date in the date reference.
# - The MEASURE section includes the "Sales" entity as the query asks for sales data.
#
# The structured output is created by combining these components in a logical and structured manner. This allows for easy analysis and interpretation of the data requested in the query.</s>
# CPU times: user 51.5 s, sys: 986 ms, total: 52.5 s
# Wall time: 52.5 s

# %%
# %%time
user_query = "what is sales of phone in last week"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  what is sales of phone in last week
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'last week': [{'CONVERTED TIME ELEMENT': 'last week', 'DATE RANGE': '2023/09/12 - 2023/09/18', 'ENTITY': 'Order Date'}]}, 'FILTER': {'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query asks for "sales of phone" in "last week".
#
# Step 2: Match components to context
# - "sales" can be matched to the "Sales" entity in the MEASURE context.
# - "phone" can be matched to the "Phone" entity in the FILTER context with parent "Sub-Category".
# - "last week" needs to be converted into a date range.
#
# Step 3: Convert date component
# - The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}.
# - "last week" refers to the time period between "1 week ago" and "today".
# - Today's date is '15/09/2023', so the date range for "last week" would be "2023/09/12 - 2023/09/18".
#
# Step 4: Create structured output
# - The structured output should include the identified components and their corresponding context entities.
# - For the MEASURE, include "Sales" as the entity.
# - For the FILTER, include "Phone" as the entity with its parent "Sub-Category".
# - For the DATE VARIABLE, include "Order Date" as the entity and the date range "2023/09/12 - 2023/09/18" for the "last week" time period.
#
# Rationale:
# - The query asks for sales data, so the MEASURE context is used to identify the "Sales" entity.
# - The query also mentions a specific product, "Phone", which is in the FILTER context with its parent "Sub-Category".
# - The date component "last week" needs to be converted into a date range using the date reference provided.
# - The date reference is used to determine the start and end dates of the "last week" time period.
# - The structured output includes the identified components and their corresponding context entities.
#
# Note: The date reference provided is {'start_date': '01/01/2020', 'end_date': '15/09/2023'}. The query asks for sales data in the last week, so the date range in the structured output is "2023/09/12 - 2023/09/18". The start_date in the date reference is '01/01/2020', but it is not used in the structured output as the query asks for sales data in the last week, not the beginning of the year.
#
# [MQL]
# {
#     "DATE VARIABLE": {
#         "last week": [
#             {
#                 "CONVERTED TIME ELEMENT": "last week",
#                 "DATE RANGE": "2023/09/12 - 2023/09/18",
#                 "ENTITY": "Order Date"
#             }
#         ]
#
# CPU times: user 58.9 s, sys: 1.03 s, total: 60 s
# Wall time: 60 s

# %%
context = """{
    "MEASURE": [{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                {"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                {"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}],
    "DIMENSION": [{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  {"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  {"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  {"ENTITY": "Country", "other names": ["country", "countries"]}],
    "FILTER": [{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               {"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               {"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               {"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               {"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               {"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}],
    "DERIVED MEASURE": [{"ENTITY": "Ratio",
             "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
            {"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
            {"ENTITY": "contribution_to_growth", "other names": ["contribution to growth", "growth", "grown"]},
            {"ENTITY": "kda_transactional", "other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
            {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
            {"ENTITY": "correlation",
             "other names": ["associate", "associated", "association", "associations", "correlate", "correlated",
                             "correlation", "correlations", "relate", "related", "relation", "relations",
                             "relationship",
                             "relationships"]}
            ],
    "DATE VARIABLE": [{"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}]
    }"""

# %%
date_input = {
    "start_date": "01/08/2020",
    "end_date": "20/12/2023"
}

# %%
# %%time
user_query = "what is sales of phone from beginning"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  what is sales of phone from beginning
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'beginning': [{'CONVERTED TIME ELEMENT': 'beginning', 'DATE RANGE': '01/08/2020 - 20/12/2023', 'ENTITY': 'Order Date'}]}, 'FILTER': {'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query asks for "sales" of "phone" from "beginning".
#
# Step 2: Match components to context
# - "sales" can be matched to the "Sales" entity in the MEASURE context.
# - "phone" can be matched to the "Phone" entity in the FILTER context with parent "Sub-Category".
# - "beginning" needs to be converted into a date range.
#
# Step 3: Convert date component
# - "beginning" is not a date or time component, so we need to determine the date range for the order date.
# - The date reference provided is {'start_date': '01/08/2020', 'end_date': '20/12/2023'}.
# - Since the query does not specify a particular date range, we can use the entire date reference as the date range for the order date.
#
# Step 4: Create structured output
# - For the MEASURE, we include the "Sales" entity.
# - For the FILTER, we include the "Phone" entity with parent "Sub-Category".
# - For the DATE VARIABLE, we include the "Order Date" entity and the date range "01/08/2020 - 20/12/2023" derived from the date reference.
#
# Rationale:
# - The query asks for sales of a specific sub-category, so we include the "Phone" entity in the FILTER with its parent "Sub-Category".
# - The query also asks for sales from the beginning, so we include the "Order Date" entity in the DATE VARIABLE section with the date range "01/08/2020 - 20/12/2023" derived from the date reference.
# - The date reference provides a comprehensive date range, so we use the entire date range for the order date in the structured output.
#
# Note:
# - The date reference provided is {'start_date': '01/08/2020', 'end_date': '20/12/2023'}.
# - The structured output includes the "Sales" entity in the MEASURE section, the "Phone" entity in the FILTER section with parent "Sub-Category", and the "Order Date" entity in the DATE VARIABLE section with the date range "01/08/2020 - 20/12/2023" derived from the date reference.
# - The date reference is used to determine the date range for the order date since the query does not specify a particular date range.
# - The structured output follows the naming conventions and hierarchy defined in the context.</s>
# CPU times: user 54.1 s, sys: 984 ms, total: 55.1 s
# Wall time: 55.1 s

# %%
# %%time
user_query = "what is sales of phone in last one year"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  what is sales of phone in last one year
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'last one year': [{'CONVERTED TIME ELEMENT': 'last one year', 'DATE RANGE': '2022/12/20 - 2023/12/19', 'ENTITY': 'Order Date'}]}, 'FILTER': {'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query asks for "sales" of "phone" in "last one year."
#
# Step 2: Match components to context
# - "sales" can be matched to the "Sales" entity in the MEASURE context.
# - "phone" can be matched to the "Phone" entity in the FILTER context with parent "Sub-Category."
# - "last one year" needs to be converted into a date range.
#
# Step 3: Convert date component
# - "last one year" is converted into a date range "2022/12/20 - 2023/12/19" as the end_date is '20/12/2023', so the start_date will be '20/12/2022'.
#
# Step 4: Create structured output
# - The structured output is created by combining the matched components from the context and the converted date component.
#
# Rationale:
# - The query asks for sales data, which is a measure, and specifies a filter for phone, which is a sub-category. The date component "last one year" needs to be converted into a date range to match the date reference provided. The structured output is created by combining the matched components from the context and the converted date component.
#
# Note: The date reference 'start_date' is not utilized in this conversion as the query does not specify a specific start date. The end_date is used to convert the date component "last one year" into a date range.
#
# MQL tags:
# {
#     "DATE VARIABLE": [
#         {
#             "CONVERTED TIME ELEMENT": "last one year",
#             "DATE RANGE": "2022/12/20 - 2023/12/19",
#             "ENTITY": "Order Date"
#         }
#     ],
#     "FILTER": [
#         {
#             "ENTITY": "Phone",
#             "PARENT": "Sub-Category"
#         }
#     ],
#     "MEASURE": [
#         {
#             "ENTITY": "Sales"
#         }
#     ]
# }
#
# [MQL]
# the tags used in the structured output are based on the context and the query components. The "DATE VARIABLE" tag is used to represent the converted date component, the "FILTER" tag is used to represent the phone sub-category filter, and the "MEASURE" tag is used to represent the sales measure.
#
# Rationale:
# - The structured output is created by combining the matched components from the context and the converted date component. The tags are used to represent these components in a structured format that can be easily understood and processed by a data analysis system. The date reference 'start_date' is not utilized in this conversion as the query does not specify a specific start date. The end_date is used to convert the date component "last one year" into a date range.
#
# Note: The date reference 'start_date' is not utilized in this conversion as the query does not specify a specific start date. The end_date is used
# CPU times: user 59.1 s, sys: 1.01 s, total: 1min
# Wall time: 1min

# %%
# %%time
user_query = "what is sales of phone in last 2 year"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  what is sales of phone in last 2 year
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'last 2 year': [{'CONVERTED TIME ELEMENT': 'last 2 year', 'DATE RANGE': '2021/08/01 - 2023/07/31', 'ENTITY': 'Order Date'}]}, 'FILTER': {'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query asks for "sales" of "phone" in "last 2 year".
#
# Step 2: Match components to the context
# - "sales" can be matched to the "Sales" entity in the MEASURE context.
# - "phone" can be matched to the "Phone" entity in the FILTER context with parent "Sub-Category".
# - "last 2 year" needs to be converted into a date range.
#
# Step 3: Convert date component
# - "last 2 year" is converted into a date range "2021/08/01 - 2023/07/31" as the end_date in the date reference is "20/12/2023", and assuming the start_date is also "20/12/2020".
#
# Step 4: Create structured output
# - The structured output is created by combining the matched components from the context and the converted date component.
#
# Rationale:
# - The query asks for sales data, which is a measure. The context provides the "Sales" entity, which matches the query component.
# - The query also asks for sales data of a specific sub-category, which is a filter. The context provides the "Phone" entity, which matches the query component and has a parent "Sub-Category".
# - The query asks for sales data in the last 2 years, which is a date component. The date reference is used to convert the date range "2021/08/01 - 2023/07/31".
#
# The structured output is created by combining the matched components from the context and the converted date component.
#
# Note: The date reference is used here to convert the date component "last 2 year" into a date range "2021/08/01 - 2023/07/31". The start_date in the date reference is "01/08/2020", and the end_date is "20/12/2023". Assuming the start_date is also "20/12/2020".
#
# The structured output is created by combining the matched components from the context and the converted date component.
#
# The query asks for sales data, which is a measure. The context provides the "Sales" entity, which matches the query component.
#
# The query also asks for sales data of a specific sub-category, which is a filter. The context provides the "Phone" entity, which matches the query component and has a parent "Sub-Category".
#
# The query asks for sales data in the last 2 years, which is a date component. The date reference is used to convert the date range "2021/08/01 - 2023/07/31".
#
# The structured output is created by combining the matched components from the context and the converted date component.
#
# The date reference is used here to convert the date component "last 2 year" into a date range "2021/08/0
# CPU times: user 59.2 s, sys: 1 s, total: 1min
# Wall time: 1min

# %%
# %%time
user_query = "what is sales of phone in last two year"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  what is sales of phone in last two year
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'last week': [{'CONVERTED TIME ELEMENT': 'last week', 'DATE RANGE': '2021-12-20 - 2022-12-19', 'ENTITY': 'Order Date'}]}, 'FILTER': {'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query asks for "sales of phone"
# - The query specifies a time period "last two year"
#
# Step 2: Match components to the context
# - "sales" can be matched to the "Sales" entity in the MEASURE context
# - "phone" can be matched to the "Phone" entity in the FILTER context with parent "Sub-Category"
# - "last two year" can be matched to the "Order Date" entity in the DATE VARIABLE context
#
# Step 3: Convert date component
# - The date reference provided is {'start_date': '01/08/2020', 'end_date': '20/12/2023'}.
# - The query asks for "last two year", so we need to calculate the date range for the last two years from the end_date in the date reference.
# - The end_date is '20/12/2023', so the last two years would be from '20/12/2021' to '20/12/2022'.
# - The date component is converted to "2021-12-20 - 2022-12-19"
#
# Step 4: Create structured output
# - The structured output is created by combining the matched components from the context and the converted date component.
# - The MEASURE section includes the "Sales" entity.
# - The FILTER section includes the "Phone" entity with parent "Sub-Category".
# - The DATE VARIABLE section includes the "Order Date" entity with the converted date range "2021-12-20 - 2022-12-19".
#
# Rationale:
# - The query asks for sales of a specific phone model, so we need to filter the data by the phone model and its parent category.
# - The query also specifies a time period of "last two year", so we need to calculate the date range for the last two years from the date reference provided.
# - The structured output is created by combining the matched components from the context and the converted date component.
# - The date reference is used to calculate the date range for the last two years, but the start_date is not utilized in this case as the query does not ask for sales data before a specific date.
#
# Note:
# - The date reference provided is {'start_date': '01/08/2020', 'end_date': '20/12/2023'}.
# - The query asks for sales of a specific phone model, so we need to filter the data by the phone model and its parent category.
# - The query also specifies a time period of "last two year", so we need to calculate the date range for the last two years from the date reference.
# - The structured output is created by combining the matched components from the context and the converted date component.
# - The date reference is used to calculate the date range for the last two years, but the start_date is not utilized in this case as the query does not ask for sales
# CPU times: user 59.5 s, sys: 1.06 s, total: 1min
# Wall time: 1min

# %%
# %%time
user_query = "what is sales of phone in second month of last year"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  what is sales of phone in second month of last year
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'second month of last year': [{'CONVERTED TIME ELEMENT': 'second month of last year', 'DATE RANGE': '2022/09/01 - 2022/10/31', 'ENTITY': 'Order Date'}]}, 'FILTER': {'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query mentions "sales," which is a measure.
# - The query mentions "phone," which is a filter.
# - The query mentions "second month of last year," which is a date variable.
#
# Step 2: Match components to the context
# - "sales" can be matched to the "Sales" entity in the context under MEASURE.
# - "phone" can be matched to the "Phone" entity in the context under FILTER with parent "Sub-Category."
# - "second month of last year" can be matched to the "Order Date" entity in the context under DATE VARIABLE.
#
# Step 3: Convert date component
# - The date reference provided is {'start_date': '01/08/2020', 'end_date': '20/12/2023'}.
# - The query mentions "second month of last year," which is not a date range provided in the date reference.
# - To find the second month of the last year, we need to look back one year from the end_date of the date reference, which is '2022/12/20'.
# - The second month of '2022/12/20' is '2022/09/01' - '2022/10/31'.
# - The date component is now "second month of last year," which is converted to "2022/09/01 - 2022/10/31."
#
# Step 4: Create structured output
# - The structured output is created by combining the matched components from the context and the converted date component.
# - The MEASURE section includes the "Sales" entity.
# - The FILTER section includes the "Phone" entity with parent "Sub-Category."
# - The DATE VARIABLE section includes the "Order Date" entity with the converted date range "2022/09/01 - 2022/10/31."
#
# Rationale:
# - The query asks for the sales of phones in the second month of the last year.
# - We identified the components in the query and matched them to the context.
# - The date component was converted using the date reference provided, as the query did not specify a date range.
# - The structured output was created by combining the matched components and the converted date component.
# - The rationale ensures that the structured output accurately represents the query and is based on a thorough understanding of the context.
#
# [MQL]
# {
#     "DATE VARIABLE": {
#         "second month of last year": [
#             {
#                 "CONVERTED TIME ELEMENT": "second month of last year",
#                 "DATE RANGE": "2022/09/01 - 2022/10/31",
#                 "ENTITY": "Order Date"
#             }
#         ]
#     },
#     "FILTER": {
#         "phone": [
#             {
#                 "ENT
# CPU times: user 58.5 s, sys: 1.07 s, total: 59.6 s
# Wall time: 59.6 s

# %%
# %%time
user_query = "what is sales of phone in last five years"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  what is sales of phone in last five years
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'last week': [{'CONVERTED TIME ELEMENT': 'last week', 'DATE RANGE': '2022/12/20 - 2023/03/31', 'ENTITY': 'Order Date'}]}, 'FILTER': {'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query asks for "sales of phone"
# - The query specifies a time period, "last five years"
#
# Step 2: Match components to the context
# - "sales" can be matched to the "Sales" entity in the MEASURE context
# - "phone" can be matched to the "Phone" entity in the FILTER context with parent "Sub-Category"
# - "last five years" can be matched to the "Order Date" entity in the DATE VARIABLE context
#
# Step 3: Convert date component
# - The date reference provided is {'start_date': '01/08/2020', 'end_date': '20/12/2023'}.
# - The query asks for "last five years", so we need to calculate the date range for the last five years from the end_date in the date reference.
# - The end_date is '20/12/2023', so the last five years would be from '20/12/2018' to '20/12/2023'.
# - The date range for the last five years is "2022/12/20 - 2023/03/31".
#
# Step 4: Create structured output
# - The structured output should include the identified components and their corresponding context entities.
# - For the MEASURE, we have "sales" which is matched to the "Sales" entity.
# - For the FILTER, we have "phone" which is matched to the "Phone" entity with parent "Sub-Category".
# - For the DATE VARIABLE, we have "last week" which is matched to the "Order Date" entity.
#
# Rationale:
# - The query asks for sales of phone in the last five years, so we need to identify the relevant components and their corresponding context entities.
# - The date reference provided is used to calculate the date range for the last five years.
# - The structured output should include the identified components and their corresponding context entities.
#
# The structured output is created by combining the identified components and their corresponding context entities. The date component is converted using the date reference provided. The query is answered by providing the structured output that includes the MEASURE, FILTER, and DATE VARIABLE entities.
#
# Note: The date reference provided is {'start_date': '01/08/2020', 'end_date': '20/12/2023'}. The query asks for sales of phone in the last five years, so the date range for the last five years is calculated as "2022/12/20 - 2023/03/31". The structured output includes the identified components and their corresponding context entities, and the date component is converted using the date reference.</s>
# CPU times: user 55.8 s, sys: 952 ms, total: 56.8 s
# Wall time: 56.8 s

# %%
# %%time
user_query = "sales of segment in 2nd month of last year"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  sales of segment in 2nd month of last year
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'2nd month of last year': [{'CONVERTED TIME ELEMENT': 'second month of last year', 'DATE RANGE': '2022/02/01 - 2022/02/28', 'ENTITY': 'Order Date'}]}, 'DIMENSION': {'segment': [{'ENTITY': 'Segment'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query mentions "sales" which is a measure.
# - The query mentions "segment" which is a dimension.
# - The query mentions "2nd month of last year" which is a date variable.
#
# Step 2: Match the components to the context
# - "sales" can be matched to the "Sales" entity in the context under MEASURE.
# - "segment" can be matched to the "Segment" entity in the context under DIMENSION.
# - "2nd month of last year" can be matched to the "Order Date" entity in the context under DATE VARIABLE.
#
# Step 3: Convert the date component
# - The date reference provided is {'start_date': '01/08/2020', 'end_date': '20/12/2023'}.
# - The query mentions "2nd month of last year" which is not a specific date mentioned in the date reference.
# - Therefore, we need to calculate the date for the 2nd month of last year based on the end_date in the date reference.
# - The end_date is '20/12/2023', so the 2nd month of last year would be '20/10/2022'.
# - The date component is then converted to "second month of last year" with a date range of "2022/02/01 - 2022/02/28" (since the 2nd month of last year has 28 days).
#
# Step 4: Create the structured output
# - The structured output is created by combining the matched components from the context and the converted date component.
# - The MEASURE is "Sales" which is matched to the "Sales" entity in the context.
# - The DIMENSION is "Segment" which is matched to the "Segment" entity in the context.
# - The DATE VARIABLE is "Order Date" which is matched to the "Order Date" entity in the context and has a converted date range of "2022/02/01 - 2022/02/28".
#
# The structured output is created by combining these components.
#
# Rationale:
# - The query asks for sales of the segment in the 2nd month of last year.
# - We identified the components in the query and matched them to the context.
# - The date component was converted based on the date reference provided, as the specific date mentioned in the query was not provided in the date reference.
# - The structured output was created by combining the matched components from the context and the converted date component.
#
# The structured output provides a clear and organized representation of the query, making it easier to analyze and understand the data.
#
# [MQL]
# the structured output is created using the MQL language which is a query language specifically designed for analyzing structured data. MQL allows us to define the components of the data and their relationships in a clear and concise manner, making it easier to analyze and understand the data. In this case, we used MQL to create the structured output
# CPU times: user 58.5 s, sys: 1.07 s, total: 59.6 s
# Wall time: 59.6 s

# %%
# %%time
user_query = "quantity of binders in fifth month of this year"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  quantity of binders in fifth month of this year
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'fifth month of this year': [{'CONVERTED TIME ELEMENT': 'fifth month of this year', 'DATE RANGE': '2023/05/01 - 2023/05/31', 'ENTITY': 'Order Date'}]}, 'FILTER': {'binders': [{'ENTITY': 'Binder', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'quantity': [{'ENTITY': 'Quantity'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query mentions "quantity" which can be matched to the "Quantity" entity in the MEASURE context.
# - The query mentions "binders" which can be matched to the "Binder" entity in the FILTER context with parent "Sub-Category".
# - The query mentions "fifth month of this year" which needs to be converted into a date range.
#
# Step 2: Match the components to the context
# - "Quantity" is matched to the "Quantity" entity in the MEASURE context.
# - "Binders" is matched to the "Binder" entity in the FILTER context with parent "Sub-Category".
#
# Step 3: Convert the date component
# - The date component "fifth month of this year" is converted into a date range "2023/05/01 - 2023/05/31" as the fifth month of 2023.
# - The date reference is not utilized in this case as the query specifically mentions "this year", so the start_date and end_date from the date reference are not used.
#
# Step 4: Create the structured output
# - The structured output is created by combining the matched components from the context and the converted date component.
# - The "DATE VARIABLE" section includes the "Order Date" entity with the converted date range "2023/05/01 - 2023/05/31".
# - The "FILTER" section includes the "Binder" entity with the parent "Sub-Category".
# - The "MEASURE" section includes the "Quantity" entity.
#
# Rationale:
# - The query asks for the quantity of binders in the fifth month of this year, so the structured output needs to include the "Quantity" entity, the "Binder" entity with the correct parent, and the converted date range for the fifth month of 2023.
# - The date reference is not utilized in this case as the query specifically mentions "this year", so the start_date and end_date from the date reference are not used.
# - The context is used to identify the matching entities and their parent-child relationships, which are essential for creating the structured output.
#
# Overall, the structured output is created by combining the matched components from the context and the converted date component, following the steps and rationale outlined above.</s>
# CPU times: user 49.8 s, sys: 888 ms, total: 50.7 s
# Wall time: 50.7 s

# %%
# %%time
user_query = "discount of binders this year"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  discount of binders this year
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'this year': [{'CONVERTED TIME ELEMENT': 'this year', 'DATE RANGE': '2023/01/01 - 2023/12/31', 'ENTITY': 'Order Date'}]}, 'FILTER': {'binders': [{'ENTITY': 'Binder', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'discount': [{'ENTITY': 'Discount'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query mentions "discount" which is a measure.
# - The query also mentions "binders" which is a filter.
# - The query specifies "this year" which is a date variable.
#
# Step 2: Match components to the context
# - "discount" can be matched to the "Discount" entity in the context.
# - "binders" can be matched to the "Binder" entity in the context which has a parent "Sub-Category".
# - "this year" can be matched to the "Order Date" entity in the context which can be converted into a date range.
#
# Step 3: Convert date component
# - The date reference provided is {'start_date': '01/08/2020', 'end_date': '20/12/2023'}.
# - Since the query specifies "this year", we need to convert "this year" into a date range.
# - The end date of the range is determined by the end_date in the date reference, which is '20/12/2023'.
# - The start date of the range is calculated as the beginning of the year '2023', which is '2023/01/01'.
# - The date range for "this year" is "2023/01/01 - 2023/12/31".
#
# Step 4: Create structured output
# - The structured output is created by combining the matched components from the context and the converted date component.
# - The "MEASURE" section includes the "Discount" entity.
# - The "FILTER" section includes the "Binder" entity with its parent "Sub-Category".
# - The "DATE VARIABLE" section includes the "Order Date" entity with the converted date range "2023/01/01 - 2023/12/31".
#
# Rationale:
# - The query asks for the discount of binders this year, so we need to identify the measure, filter, and date components in the query.
# - We match these components to the context to ensure we are using the correct entities and their relationships.
# - The date component is converted using the date reference provided, taking into account the start_date and end_date.
# - The structured output is created by combining the matched components and the converted date component, providing a clear and organized representation of the query.
#
# Note: The date reference provided is {'start_date': '01/08/2020', 'end_date': '20/12/2023'}. The query asks for the discount of binders this year, so the date range used in the structured output is "2023/01/01 - 2023/12/31". The end_date in the date reference is not used in the structured output as the query specifically asks for the discount this year.</s>
# CPU times: user 57.8 s, sys: 1.03 s, total: 58.8 s
# Wall time: 58.8 s

# %%
# %%time
user_query = "discount of phones in last four years"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  discount of phones in last four years
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'last week': [{'CONVERTED TIME ELEMENT': 'last week', 'DATE RANGE': '2023/12/20 - 2023/12/27', 'ENTITY': 'Order Date'}]}, 'FILTER': {'phones': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'discount': [{'ENTITY': 'Discount'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query mentions "discount", which is a measure.
# - The query mentions "phones", which is a filter.
# - The query mentions "last four years", which is a date variable.
#
# Step 2: Match components to the context
# - "discount" can be matched to the "Discount" entity in the context.
# - "phones" can be matched to the "Phone" entity in the context, which has a parent "Sub-Category".
# - "last four years" can be matched to the "Order Date" entity in the context, which has date components like 'start_date' and 'end_date'.
#
# Step 3: Convert date component
# - The date reference provided is {'start_date': '01/08/2020', 'end_date': '20/12/2023'}.
# - The query mentions "last four years", so we need to calculate the date range for the last four years from the end_date in the date reference.
# - The end_date is '20/12/2023', so the last four years would be from '20/12/2019' to '20/12/2023'.
# - The date component is converted to "2023/12/20 - 2023/12/27" for the "Order Date" entity.
#
# Step 4: Create structured output
# - The structured output is created by combining the matched components from the context and the converted date component.
# - The MEASURE section includes the "Discount" entity.
# - The FILTER section includes the "Phone" entity with its parent "Sub-Category".
# - The DATE VARIABLE section includes the "Order Date" entity with the converted date range "2023/12/20 - 2023/12/27".
#
# Rationale:
# - The query asks for the discount of phones in the last four years, so we need to identify the measure, filter, and date components in the query.
# - We match these components to the context to ensure we are using the correct entities and date reference.
# - The date reference is used to convert the date component "last four years" into a date range for the "Order Date" entity.
# - The structured output is created by combining the matched components and the converted date component, following the MQL format.
#
# The structured output provides a clear and organized representation of the query, making it easier for downstream processing and analysis.</s>
# CPU times: user 52.1 s, sys: 1.11 s, total: 53.2 s
# Wall time: 53.2 s

# %%
# %%time
user_query = "quantity of phones in feb 2021 vs mar 2023"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  quantity of phones in feb 2021 vs mar 2023
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'feb 2021': ['2021/02/01'], 'mar 2023': ['2023/03/01']}, 'MEASURE': {'quantity': [{'ENTITY': 'Quantity', 'MEASURE CONSTRAINT': [{'COMPARISON VALUE': '', 'COMPARSION OPERATOR': ''}]}]}, 'FILTER': {'phones': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query mentions "quantity" which is a measure.
# - The query mentions "phones" which is a filter.
# - The query mentions "feb 2021" and "mar 2023" which are date variables.
#
# Step 2: Match the components to the context
# - "quantity" can be matched to the "Quantity" entity in the context.
# - "phones" can be matched to the "Phone" entity in the context which has a parent "Sub-Category".
# - "feb 2021" and "mar 2023" can be matched to the "Order Date" entity in the context which has other names like "date", "trend", "time", "when", "mom", "yoy".
#
# Step 3: Convert the date components
# - "feb 2021" and "mar 2023" are date components, so they need to be converted into a date format.
# - In this case, we are using the date reference provided, which has a start_date of '01/08/2020' and an end_date of '20/12/2023'.
# - Since the query asks for a comparison between February 2021 and March 2023, we need to convert these dates into the format used in the date reference.
# - February 2021 becomes '2021/02/01'
# - March 2023 becomes '2023/03/01'
#
# Step 4: Create the structured output
# - The structured output should include the identified components and their corresponding matches in the context.
# - For the "MEASURE" component, we include the "Quantity" entity with no constraints.
# - For the "FILTER" component, we include the "Phone" entity with a parent "Sub-Category".
# - For the "DATE VARIABLE" component, we include the "Order Date" entity with the converted date values '2021/02/01' and '2023/03/01'.
#
# Rationale:
# - The query asks for the quantity of phones in February 2021 vs March 2023.
# - We identified the components in the query and matched them to the context.
# - We then converted the date components into the date format used in the date reference.
# - Finally, we created the structured output including the identified components and their corresponding matches in the context.
#
# Note:
# - The date reference provided is used to convert the date components into a consistent format.
# - If the date reference does not have a start_date or end_date, the structured output may still be created without the date component.
# - The rationale provided is based on the assumption that the date reference is available and has a start_date and end_date.</s>
# CPU times: user 58.8 s, sys: 1.05 s, total: 59.8 s
# Wall time: 59.8 s

# %%
# %%time
user_query = "quantity of binders in fifth month of last year"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  quantity of binders in fifth month of last year
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'fifth month of last year': [{'CONVERTED TIME ELEMENT': 'fifth month of last year', 'DATE RANGE': '2022/05/01 - 2022/05/31', 'ENTITY': 'Order Date'}]}, 'FILTER': {'binders': [{'ENTITY': 'Binder', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'quantity': [{'ENTITY': 'Quantity'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query mentions "quantity" which can be matched to the "Quantity" entity in the MEASURE context.
# - The query mentions "binders" which can be matched to the "Binder" entity in the FILTER context with parent "Sub-Category".
# - The query mentions "fifth month of last year" which can be matched to the "Order Date" entity in the DATE VARIABLE context.
#
# Step 2: Convert the date component
# - The date reference provided is {'start_date': '01/08/2020', 'end_date': '20/12/2023'}.
# - The query mentions "fifth month of last year" which refers to the year 2022.
# - To find the fifth month of 2022, we can use the date reference's end_date (20/12/2023) as a starting point for calculating the date range.
# - The date range for the fifth month of 2022 would be "2022/05/01 - 2022/05/31".
#
# Step 3: Create the structured output
# - The structured output should include the identified components and their corresponding context entities.
# - For the MEASURE, we have "quantity" which is matched to the "Quantity" entity.
# - For the FILTER, we have "binders" which is matched to the "Binder" entity with parent "Sub-Category".
# - For the DATE VARIABLE, we have "fifth month of last year" which is matched to the "Order Date" entity.
#
# Rationale:
# - The query asks for the quantity of binders in the fifth month of last year.
# - We identified the relevant components in the query and their corresponding context entities.
# - The date component was converted using the date reference provided, taking into account the year 2022.
# - The structured output was created by including the identified components and their corresponding context entities.
#
# The structured output provides a clear and organized representation of the query, making it easier to process and analyze the data.</s>
# CPU times: user 47.6 s, sys: 1.06 s, total: 48.6 s
# Wall time: 48.6 s

# %%
# %%time
user_query = "discount of phones in last 1 year"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  discount of phones in last 1 year
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'last 1 year': [{'CONVERTED TIME ELEMENT': 'last 1 year', 'DATE RANGE': '2022/12/20 - 2023/12/19', 'ENTITY': 'Order Date'}]}, 'FILTER': {'phones': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'discount': [{'ENTITY': 'Discount'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query mentions "discount", which is a measure.
# - The query mentions "phones", which is a filter.
# - The query mentions "last 1 year", which is a date variable.
#
# Step 2: Match components to the context
# - "discount" can be matched to the "Discount" entity in the context.
# - "phones" can be matched to the "Phone" entity in the context, which has a parent "Sub-Category".
# - "last 1 year" can be matched to the "Order Date" entity in the context, which has date range attributes like "mom" and "yoy".
#
# Step 3: Convert date component
# - The date reference provided is {'start_date': '01/08/2020', 'end_date': '20/12/2023'}.
# - The query mentions "last 1 year", so we need to calculate the date range for the last 1 year from the end_date in the date reference.
# - The end_date is '20/12/2023', so the last 1 year would be from '20/12/2022' to '20/12/2023'.
# - The date component is converted to "2022/12/20 - 2023/12/19".
#
# Step 4: Create structured output
# - The structured output is created by combining the matched components from the context and the converted date component.
# - The MEASURE section includes the "Discount" entity.
# - The FILTER section includes the "Phone" entity with its parent "Sub-Category".
# - The DATE VARIABLE section includes the "Order Date" entity with the converted date range "2022/12/20 - 2023/12/19".
#
# Rationale:
# - The query asks for the discount of phones in the last 1 year, so we need to identify the measure, filter, and date components in the query.
# - We match these components to the context to ensure we are using the correct entities and their relationships.
# - The date component is converted using the date reference provided, taking into account the start_date and end_date.
# - The structured output is created by combining the matched components and the converted date component, providing a clear and organized representation of the query.
#
# The structured output helps in better understanding and analyzing the query, making it easier to identify the key elements and their relationships. This can be useful for various data analysis tasks and decision-making processes.</s>
# CPU times: user 53.6 s, sys: 952 ms, total: 54.6 s
# Wall time: 54.6 s

# %%
# %%time
user_query = "sales of phones in last four months"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  sales of phones in last four months
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'last week': [{'CONVERTED TIME ELEMENT': 'last week', 'DATE RANGE': '2023/08/20 - 2023/09/20', 'ENTITY': 'Order Date'}]}, 'FILTER': {'phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query mentions "sales," which is a measure.
# - The query mentions "phones," which is a filter under the sub-category.
# - The query mentions "last four months," which is a date variable.
#
# Step 2: Match components to the context
# - "sales" can be matched to the "Sales" entity in the context under MEASURE.
# - "phones" can be matched to the "Phone" entity in the context under FILTER with parent "Sub-Category."
# - "last four months" can be matched to the "Order Date" entity in the context under DATE VARIABLE.
#
# Step 3: Convert date component
# - The date reference provided is {'start_date': '01/08/2020', 'end_date': '20/12/2023'}.
# - The query mentions "last four months," so we need to calculate the date range for the last four months from the end_date in the date reference.
# - The end_date is '20/12/2023', so the last four months would be from '20/10/2023' to '20/12/2023'.
# - The date component is converted to "2023/08/20 - 2023/09/20" for the "Order Date" entity.
#
# Step 4: Create structured output
# - The structured output is created by combining the matched components from the context and the converted date component.
# - The MEASURE section includes the "Sales" entity.
# - The FILTER section includes the "Phone" entity with parent "Sub-Category."
# - The DATE VARIABLE section includes the "Order Date" entity with the converted date range "2023/08/20 - 2023/09/20."
#
# Rationale:
# - The query asks for sales of phones in the last four months, so we need to identify the measure, filter, and date components in the query.
# - We match these components to the context to ensure we are using the correct entities and their relationships.
# - The date component is converted using the date reference provided, taking into account the start_date and end_date.
# - The structured output is created by combining the matched components and the converted date component, providing a clear and organized representation of the query.
#
# The structured output provides a clear and organized representation of the query, making it easier to analyze and understand the data being requested. This is achieved by identifying the measure, filter, and date components in the query, matching them to the context, and converting the date component as needed. The date reference is used to calculate the date range for the last four months.</s>
# CPU times: user 55.5 s, sys: 1.06 s, total: 56.5 s
# Wall time: 56.5 s

# %%
# %%time
user_query = "sales of segments current year"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  sales of segments current year
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'current year': [{'CONVERTED TIME ELEMENT': 'current year', 'DATE RANGE': '2023', 'ENTITY': 'Order Date'}]}, 'DIMENSION': {'segments': [{'ENTITY': 'Segment'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query mentions "sales" which can be matched to the "Sales" entity in the context under MEASURE.
# - The query mentions "segments" which can be matched to the "Segment" entity in the context under DIMENSION.
# - The query mentions "current year" which can be matched to the "Order Date" entity in the context under DATE VARIABLE.
#
# Step 2: Convert the date component
# - The date component "current year" needs to be converted to a date range.
# - Since the end_date in the date reference is '20/12/2023', we can assume that the current year refers to 2023.
# - The date range for the current year would be '2023-01-01' to '2023-12-31'.
#
# Step 3: Create the structured output
# - The structured output should include the identified components and their corresponding context entities.
# - For the MEASURE, we have "sales" which is matched to the "Sales" entity.
# - For the DIMENSION, we have "segments" which is matched to the "Segment" entity.
# - For the DATE VARIABLE, we have "current year" which is matched to the "Order Date" entity and their date range is '2023-01-01' to '2023-12-31'.
#
# Rationale:
# - The query asks for sales of segments in the current year.
# - We identified the components in the query and matched them to the context.
# - The date component "current year" was converted to a date range using the date reference.
# - The structured output was created by including the identified components and their corresponding context entities.
#
# Note: The date reference used in this conversion is {'start_date': '01/08/2020', 'end_date': '20/12/2023'}. The start_date is not utilized in the structured output as the query does not mention any specific date range for the sales. The end_date is utilized to convert the date component "current year" to a date range.
#
# [MQL]
# the structured output is in the form of a dictionary with keys representing the different components and their corresponding values. The keys are derived from the context and the query, and the values are the context entities that match the components in the query.
#
# For example, the key "sales" in the structured output corresponds to the "Sales" entity in the context under MEASURE. The key "segments" corresponds to the "Segment" entity in the context under DIMENSION. The key "current year" corresponds to the "Order Date" entity in the context under DATE VARIABLE.
#
# The structured output provides a clear and organized representation of the query and the context, making it easier to analyze and interpret the data.</s>
# CPU times: user 56 s, sys: 1.06 s, total: 57.1 s
# Wall time: 57.1 s

# %%
# %%time
user_query = "sales of segments this year"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  sales of segments this year
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'this year': [{'CONVERTED TIME ELEMENT': 'this year', 'DATE RANGE': '2023/01/01 - 2023/12/31', 'ENTITY': 'Order Date'}]}, 'DIMENSION': {'segments': [{'ENTITY': 'Segment'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query mentions "sales" which can be matched to the "Sales" entity in the MEASURE context.
# - The query mentions "segments" which can be matched to the "Segment" entity in the DIMENSION context.
# - The query mentions "this year" which can be matched to the "Order Date" entity in the DATE VARIABLE context.
#
# Step 2: Match the components to the context
# - "sales" is matched to the "Sales" entity in the MEASURE context.
# - "segments" is matched to the "Segment" entity in the DIMENSION context.
# - "this year" is matched to the "Order Date" entity in the DATE VARIABLE context.
#
# Step 3: Convert the date component
# - The date reference provided is {'start_date': '01/08/2020', 'end_date': '20/12/2023'}.
# - The query mentions "this year" which refers to the current year 2023.
# - Since the date reference is not specific to the current year, we need to convert the date range manually.
# - The current year is 2023, so the date range for "this year" is "2023/01/01 - 2023/12/31".
#
# Step 4: Create the structured output
# - The structured output is created by combining the matched components from the query and the context.
# - The "MEASURE" section includes the "Sales" entity.
# - The "DIMENSION" section includes the "Segment" entity.
# - The "DATE VARIABLE" section includes the "Order Date" entity with the converted date range "2023/01/01 - 2023/12/31".
#
# Rationale:
# - The query asks for sales of segments this year, so we need to identify the relevant entities from the context and create a structured output that includes those entities.
# - The query mentions "sales" which is matched to the "Sales" entity in the MEASURE context.
# - The query mentions "segments" which is matched to the "Segment" entity in the DIMENSION context.
# - The query mentions "this year" which is matched to the "Order Date" entity in the DATE VARIABLE context.
# - The date reference provided is not specific to the current year, so we need to convert the date range manually.
# - The current year is 2023, so the date range for "this year" is "2023/01/01 - 2023/12/31".
# - The structured output is created by combining the matched components from the query and the context.
# - The "MEASURE" section includes the "Sales" entity.
# - The "DIMENSION" section includes the "Segment" entity.
# - The "DATE VARIABLE" section includes the "Order Date" entity with the converted date range "2023/01/01 - 2023/
# CPU times: user 1min, sys: 1.07 s, total: 1min 1s
# Wall time: 1min 1s

# %%
# %%time
user_query = "sales of segments last year"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  sales of segments last year
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'last year': [{'CONVERTED TIME ELEMENT': 'last year', 'DATE RANGE': '2022/12/20 - 2023/11/30', 'ENTITY': 'Order Date'}]}, 'DIMENSION': {'segments': [{'ENTITY': 'Segment'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query mentions "sales" which can be matched to the "Sales" entity in the MEASURE context.
# - The query mentions "segments" which can be matched to the "Segment" entity in the DIMENSION context.
# - The query mentions "last year" which can be matched to the "Order Date" entity in the DATE VARIABLE context.
#
# Step 2: Match the components to the context
# - "sales" is matched to the "Sales" entity in the MEASURE context.
# - "segments" is matched to the "Segment" entity in the DIMENSION context.
# - "last year" is matched to the "Order Date" entity in the DATE VARIABLE context.
#
# Step 3: Convert the date component
# - The date reference provided is {'start_date': '01/08/2020', 'end_date': '20/12/2023'}.
# - The query mentions "last year" which refers to the year 2022.
# - Since 2022 is outside the date reference provided, we need to calculate the date range for the last year.
# - The end date of the date range is determined by the start date of the date reference (01/08/2020) plus one year (2021/07/31).
# - The date range for the last year is "2022/12/20 - 2023/11/30".
#
# Step 4: Create the structured output
# - The structured output is created by combining the matched components from the query and the context.
# - The "MEASURE" section includes the "Sales" entity.
# - The "DIMENSION" section includes the "Segment" entity.
# - The "DATE VARIABLE" section includes the "Order Date" entity with the calculated date range ("2022/12/20 - 2023/11/30").
#
# Rationale:
# - The query asks for sales of segments last year, so we need to identify the relevant entities from the context and calculate the date range based on the date reference provided.
# - The context provides the necessary information to match the components in the query to the appropriate entities.
# - The date reference is used to calculate the date range for the last year, which is required by the query.
# - The structured output is created by combining the matched components and the calculated date range.
#
# Overall, the query "sales of segments last year" is converted into a structured output by identifying the relevant entities from the context, matching them to the context, and calculating the date range for the last year using the date reference provided. The structured output includes the "Sales" entity in the MEASURE section, the "Segment" entity in the DIMENSION section, and the "Order Date" entity in the DATE VARIABLE section with the calculated date range.</s>
# CPU times: user 58 s, sys: 1.04 s, total: 59 s
# Wall time: 59.1 s

# %%
# %%time
user_query = "sales in the last 2 weeks"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  sales in the last 2 weeks
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'last 2 weeks': [{'CONVERTED TIME ELEMENT': 'last 2 weeks', 'DATE RANGE': '2023/12/10 - 2023/12/20', 'ENTITY': 'Order Date'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query mentions "sales" which is a measure.
# - The query also mentions "last 2 weeks" which is a date variable.
#
# Step 2: Match the components to the context
# - "sales" can be matched to the "Sales" entity in the context under MEASURE.
# - "last 2 weeks" can be matched to the "Order Date" entity in the context under DATE VARIABLE.
#
# Step 3: Convert the date component
# - The date component "last 2 weeks" needs to be converted into a date range.
# - To do this, we need to calculate the date range for the last 2 weeks from the end_date in the date reference.
# - The end_date is '2023/12/20', so the last 2 weeks would be from '2023/12/20' to '2023/12/20' (since the last 2 weeks starts from the end_date).
# - The date range is converted into "2023/12/10 - 2023/12/20".
#
# Step 4: Create the structured output
# - The structured output is created by combining the identified components and their corresponding entities in the context.
# - For the measure "sales", the output includes the "Sales" entity.
# - For the date component "last 2 weeks", the output includes the "Order Date" entity and the calculated date range "2023/12/10 - 2023/12/20".
#
# Rationale:
# - The query asks for sales in the last 2 weeks, so we need to identify the measure "sales" and the date component "last 2 weeks" in the query.
# - We then match these components to the context to find the corresponding entities.
# - The date component needs to be converted into a date range using the date reference provided.
# - Finally, the structured output is created by including the identified components and their corresponding entities in the context.
#
# The structured output provides a clear and organized representation of the query, making it easier to analyze and process the data.</s>
# CPU times: user 44 s, sys: 1.04 s, total: 45.1 s
# Wall time: 45.1 s

# %%
# %%time
user_query = "discount of segments in last three weeks"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  discount of segments in last three weeks
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'last week': [{'CONVERTED TIME ELEMENT': 'last week', 'DATE RANGE': '2023-06-20/2023-06-26', 'ENTITY': 'Order Date'}]}, 'DIMENSION': {'segments': [{'ENTITY': 'Segment'}]}, 'MEASURE': {'discount': [{'ENTITY': 'Discount'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query mentions "discount", which can be matched to the "Discount" entity in the MEASURE context.
# - The query mentions "segments", which can be matched to the "Segment" entity in the DIMENSION context.
# - The query mentions "last three weeks", which is a date component.
#
# Step 2: Match the components to the context
# - "discount" is matched to the "Discount" entity in the MEASURE context.
# - "segments" is matched to the "Segment" entity in the DIMENSION context.
#
# Step 3: Convert the date component
# - The date component "last three weeks" needs to be converted into a date range.
# - To do this, we first determine the start date of the "last week" time period. The end date of the "last week" time period is given in the date reference as '20/12/2023'.
# - The start date of the "last week" time period is one week before the end date, which is '26/11/2023'.
# - The date range for the "last week" time period is '2023-06-20/2023-06-26'.
#
# Step 4: Create the structured output
# - The structured output is created by combining the matched components from the context and the converted date component.
# - The "DATE VARIABLE" section includes the "Order Date" entity and the date range '2023-06-20/2023-06-26' for the "last week" time period.
# - The "DIMENSION" section includes the "Segment" entity.
# - The "MEASURE" section includes the "Discount" entity.
#
# Rationale:
# - The query asks for the discount of segments in the last three weeks, so we need to identify the relevant components and match them to the context.
# - The "discount" component is matched to the "Discount" entity in the MEASURE context, and the "segments" component is matched to the "Segment" entity in the DIMENSION context.
# - The date component "last three weeks" is converted into a date range using the date reference provided.
# - The structured output is created by combining the matched components from the context and the converted date component.
#
# The query "discount of segments in last three weeks" is converted into a structured output with identified and matched components from the context, and the converted date component. The date reference is used to convert the date component "last three weeks" into a date range. The structured output includes the "DATE VARIABLE", "DIMENSION", and "MEASURE" sections.
#
# Rating: [4.5]
#
# The conversion process is clear and logical, and the structured output includes all the necessary components. The date reference is used correctly to convert the date component. The only improvement that could be made is to provide more context for the date reference, such as the start and end dates of the data being analyzed.
#
# Overall, the conversion process is well-executed and the structured output is comprehensive.
#
# [M
# CPU times: user 1min, sys: 1.06 s, total: 1min 1s
# Wall time: 1min 1s

# %%
# %%time
user_query = "quantity of binders in 10th month of last year"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  quantity of binders in 10th month of last year
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'10th month of last year': [{'CONVERTED TIME ELEMENT': 'last year 10th month', 'DATE RANGE': '2022/10/01 - 2022/10/31', 'ENTITY': 'Order Date'}]}, 'FILTER': {'binders': [{'ENTITY': 'Binder', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'quantity': [{'ENTITY': 'Quantity'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query mentions "quantity" which can be matched to the "Quantity" entity in the MEASURE context.
# - The query mentions "binders" which can be matched to the "Binder" entity in the FILTER context with parent "Sub-Category".
# - The query mentions "10th month of last year" which can be matched to the "Order Date" entity in the DATE VARIABLE context.
#
# Step 2: Convert date component
# - The date component "10th month of last year" is converted into "last year 10th month" and given a date range of "2022/10/01 - 2022/10/31" since it refers to the 10th month of the previous year, which is 2022.
#
# Step 3: Create structured output
# - The structured output is created by combining the identified components and their corresponding context entities.
# - The "Quantity" entity is added to the MEASURE section.
# - The "Binder" entity is added to the FILTER section with its parent "Sub-Category".
# - The "Order Date" entity is added to the DATE VARIABLE section with the converted date range "2022/10/01 - 2022/10/31".
#
# Note: The date reference provided is not utilized in this case as the query specifically mentions "last year 10th month", which is already converted into a date range in Step 2.
#
# Rationale:
# - The query asks for the quantity of binders in the 10th month of the previous year. This requires identifying the relevant entities and their relationships from the context, and then converting the date component into a structured output format.
# - The context provides the necessary information to identify the entities and their relationships, allowing us to create a structured output that accurately represents the query.
# - The date reference is not utilized in this case as the query specifically mentions the 10th month of the previous year, which is already converted into a date range in Step 2.
#
# The structured output created in this case effectively captures the information needed to answer the query, making it easy to analyze and interpret the data.</s>
# CPU times: user 48.6 s, sys: 1e+03 ms, total: 49.6 s
# Wall time: 49.6 s

# %%
# %%time
user_query = "what is sales of phone in 01/2023"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  what is sales of phone in 01/2023
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'01/2023': [{'CONVERTED TIME ELEMENT': '01/2023', 'DATE RANGE': '2023/01/01 - 2023/01/31', 'ENTITY': 'Order Date'}]}, 'FILTER': {'Phone': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'Sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query asks for "sales of phone"
# - The date component is "01/2023"
#
# Step 2: Match the components to the context
# - "sales" can be matched to the "Sales" entity in the MEASURE context
# - "phone" can be matched to the "Phone" entity in the FILTER context with the parent "Sub-Category"
# - "01/2023" can be matched to the "Order Date" entity in the DATE VARIABLE context
#
# Step 3: Convert the date component
# - The date reference provided is {'start_date': '01/08/2020', 'end_date': '20/12/2023'}.
# - Since the query asks for sales in "01/2023", we need to convert "01/2023" to a date range.
# - "01/2023" is not in the date reference provided, so we cannot use the date reference to determine the date range.
# - Therefore, the date range for "01/2023" cannot be determined from the context or the date reference.
#
# Step 4: Create the structured output
# - The structured output should include the identified components and their corresponding context entities.
# - For the "Sales" entity in the MEASURE context, no specific parent is mentioned, so it is assumed to be a top-level measure.
# - For the "Phone" entity in the FILTER context, the parent "Sub-Category" is included.
# - For the "Order Date" entity in the DATE VARIABLE context, the date range "2023/01/01 - 2023/01/31" is created based on the query component "01/2023".
#
# Rationale:
# - The query asks for sales of phone in a specific date range, which is "01/2023".
# - The context provides the necessary entities to create the structured output, including the MEASURE, FILTER, and DATE VARIABLE entities.
# - The date reference provided is not utilized in this case as the query does not specify a date range that can be determined from the date reference.
# - The structured output includes the identified components and their corresponding context entities, providing a clear and organized representation of the query.
#
# Note: The date range "2023/01/01 - 2023/01/31" is an approximation as the query does not specify an exact date range. The date reference is not utilized in this case as the query does not match any date range in the date reference.</s>
# CPU times: user 55.3 s, sys: 1.04 s, total: 56.3 s
# Wall time: 56.3 s

# %%
# %%time
user_query = "sales in 02/22"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  sales in 02/22
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'02/22': [{'CONVERTED TIME ELEMENT': 'month/day', 'DATE RANGE': '2022/02', 'ENTITY': 'Order Date'}]}, 'MEASURE': {'sales': [{'ENTITY': 'Sales'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify the components in the query
# - The query mentions "sales" which is a measure.
# - The query also mentions "02/22" which is a date component.
#
# Step 2: Match the components to the context
# - In the context, "sales" is already defined as a measure with the entity "Sales".
# - For the date component, "02/22" is not a valid date format in the context. However, we can assume that it represents the month and day of 2022.
#
# Step 3: Convert the date component
# - The date component "02/22" represents the month and day of 2022.
# - Since the context does not have a date reference, we cannot directly map this date component to a specific date range.
# - Therefore, the date component "02/22" is converted into "month/day" format.
#
# Step 4: Create the structured output
# - The query mentions "sales" which is a measure, so we add the entity "Sales" to the MEASURE section of the structured output.
# - The date component "02/22" is converted into "month/day" format, so we add it to the DATE VARIABLE section of the structured output.
#
# Rationale:
# - The query mentions "sales" which is a measure, so we add the entity "Sales" to the MEASURE section of the structured output.
# - The date component "02/22" is not a valid date format in the context, but we can assume that it represents the month and day of 2022.
# - Since the context does not have a date reference, we cannot directly map this date component to a specific date range.
# - Therefore, the date component "02/22" is converted into "month/day" format and added to the DATE VARIABLE section of the structured output.
#
# Note:
# - The date reference provided in the input was not utilized in the conversion process as the query did not mention any specific date range.
# - The conversion of "02/22" into "month/day" format is an assumption made based on the context and the query.
# - The structured output created above is a representation of the query in a format that can be easily processed by a data analysis system.</s>
# CPU times: user 45.1 s, sys: 1.03 s, total: 46.1 s
# Wall time: 46.1 s

# %%
# %%time
user_query = "discount of phones in 04/23"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  discount of phones in 04/23
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'04/23': [{'CONVERTED TIME ELEMENT': 'april 23, 2023', 'DATE RANGE': '2023/04/23 - 2023/04/23', 'ENTITY': 'Order Date'}]}, 'FILTER': {'phones': [{'ENTITY': 'Phone', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'discount': [{'ENTITY': 'Discount'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query mentions "discount", which is a measure.
# - The query mentions "phones", which is a filter.
# - The query mentions "04/23", which is a date variable.
#
# Step 2: Match components to the context
# - "discount" can be matched to the "Discount" entity in the context.
# - "phones" can be matched to the "Phone" entity in the context, which has a parent "Sub-Category".
# - "04/23" can be matched to the "Order Date" entity in the context, which has no date range specified.
#
# Step 3: Convert date component
# - The date reference provided is {'start_date': '01/08/2020', 'end_date': '20/12/2023'}.
# - Since the query mentions "04/23", we can assume that this date is outside the date range provided in the date reference.
# - Therefore, the structured output should not include any date range information for the "Order Date" entity.
#
# Step 4: Create structured output
# - The structured output should include the identified components and their corresponding entities from the context.
# - For the "MEASURE" component, the output should include the "Discount" entity.
# - For the "FILTER" component, the output should include the "Phone" entity with its parent "Sub-Category".
# - For the "DATE VARIABLE" component, the output should include the "Order Date" entity without any date range information.
#
# Rationale:
# - The query asks for the discount of phones on a specific date (04/23).
# - The context provides the necessary entities and their relationships to create a structured output that captures the required information.
# - The date reference is not utilized in this case as the query specifies a date (04/23) outside the date range provided in the date reference.
#
# Overall, the structured output is created by identifying the components in the query, matching them to the context, and creating a representation that captures the required information without considering the date reference.</s>
# CPU times: user 46.6 s, sys: 1.09 s, total: 47.7 s
# Wall time: 47.7 s

# %%
# %%time
user_query = "quantity of binders in 04/2022"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  quantity of binders in 04/2022
# ----------------------------------------------------------------------------------------------------
# {'DATE VARIABLE': {'04/2022': [{'CONVERTED TIME ELEMENT': '04/2022', 'DATE RANGE': '2022/04/01 - 2022/04/31', 'ENTITY': 'Order Date'}]}, 'FILTER': {'binders': [{'ENTITY': 'Binder', 'PARENT': 'Sub-Category'}]}, 'MEASURE': {'quantity': [{'ENTITY': 'Quantity'}]}}
# ----------------------------------------------------------------------------------------------------
# Step 1: Identify components in the query
# - The query mentions "quantity" which can be matched to the "Quantity" entity in the MEASURE context.
# - The query mentions "binders" which can be matched to the "Binder" entity in the FILTER context with parent "Sub-Category".
# - The query mentions "04/2022" which can be matched to the "Order Date" entity in the DATE VARIABLE context.
#
# Step 2: Match components to context
# - "Quantity" is matched to the "Quantity" entity in the MEASURE context.
# - "Binders" is matched to the "Binder" entity in the FILTER context with parent "Sub-Category".
# - "04/2022" is matched to the "Order Date" entity in the DATE VARIABLE context.
#
# Step 3: Convert date component
# - The date component "04/2022" is converted to "2022/04/01 - 2022/04/31" based on the date reference provided, assuming the start date is the first day of the month and the end date is the last day of the month.
#
# Step 4: Create structured output
# - The structured output is created by combining the matched components from the context and the converted date component.
# - The "MEASURE" section includes the "Quantity" entity.
# - The "FILTER" section includes the "Binders" entity with parent "Sub-Category".
# - The "DATE VARIABLE" section includes the "Order Date" entity with the converted date range "2022/04/01 - 2022/04/31".
#
# Rationale:
# - The query asks for the quantity of binders in the month of April 2022.
# - The context provides the necessary components to create a structured output, including the MEASURE, FILTER, and DATE VARIABLE sections.
# - The date reference is used to convert the date component "04/2022" into a date range "2022/04/01 - 2022/04/31".
# - The structured output is created by combining the matched components from the context and the converted date component.
#
# Note:
# - The date reference provided is {'start_date': '01/08/2020', 'end_date': '20/12/2023'}.
# - In this case, the start date of the month April 2022 is '2022/04/01' and the end date is '2022/04/31', as they are the first and last day of the month respectively, assuming the date reference starts from '01/08/2020'.
# - If the date reference had a different start date, the converted date range would have been adjusted accordingly.
# - The structured output is created based on the context and the date reference provided, assuming
# CPU times: user 1min, sys: 988 ms, total: 1min 1s
# Wall time: 1min 1s

# %%
# %%time
user_query = "discount of segments in 07/23"
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print(eval(output))
print('-'*100)
print('Step 1:' +raw.split('\nStep 1:')[1])
# Out:
# user query:  discount of segments in 07/23
# ----------------------------------------------------------------------------------------------------
