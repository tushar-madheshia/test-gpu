# %%
# !sudo pip install -q transformers --upgrade

# %%
# !sudo conda install cuda -c nvidia -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.5.0
#   latest version: 23.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.11.0
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - cuda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.08.22 |       h06a4308_0         123 KB
#     certifi-2023.11.17         |   py38h06a4308_0         158 KB
#     cuda-12.3.1                |                0           2 KB  nvidia
#     cuda-cccl-12.3.101         |                0         1.4 MB  nvidia
#     cuda-command-line-tools-12.3.1|                0           2 KB  nvidia
#     cuda-compiler-12.3.1       |                0           2 KB  nvidia
#     cuda-cudart-12.3.101       |                0         197 KB  nvidia
#     cuda-cudart-dev-12.3.101   |                0         401 KB  nvidia
#     cuda-cudart-static-12.3.101|                0         1.1 MB  nvidia
#     cuda-cuobjdump-12.3.101    |                0         243 KB  nvidia
#     cuda-cupti-12.3.101        |                0        15.3 MB  nvidia
#     cuda-cupti-static-12.3.101 |                0        11.5 MB  nvidia
#     cuda-cuxxfilt-12.3.101     |                0         295 KB  nvidia
#     cuda-demo-suite-12.3.101   |                0         5.0 MB  nvidia
#     cuda-documentation-12.3.101|                0          89 KB  nvidia
#     cuda-driver-dev-12.3.101   |                0          18 KB  nvidia
#     cuda-gdb-12.3.101          |                0         5.3 MB  nvidia
#     cuda-libraries-12.3.1      |                0           2 KB  nvidia
#     cuda-libraries-dev-12.3.1  |                0           2 KB  nvidia
#     cuda-libraries-static-12.3.1|                0           2 KB  nvidia
#     cuda-nsight-12.3.101       |                0       113.7 MB  nvidia
#     cuda-nsight-compute-12.3.1 |                0           2 KB  nvidia
#     cuda-nvcc-12.3.103         |                0        58.1 MB  nvidia
#     cuda-nvdisasm-12.3.101     |                0        47.9 MB  nvidia
#     cuda-nvml-dev-12.3.101     |                0          92 KB  nvidia
#     cuda-nvprof-12.3.101       |                0         4.8 MB  nvidia
#     cuda-nvprune-12.3.101      |                0          65 KB  nvidia
#     cuda-nvrtc-12.3.103        |                0        21.3 MB  nvidia
#     cuda-nvrtc-dev-12.3.103    |                0          12 KB  nvidia
#     cuda-nvrtc-static-12.3.103 |                0        18.5 MB  nvidia
#     cuda-nvtx-12.3.101         |                0          58 KB  nvidia
#     cuda-nvvp-12.3.101         |                0       114.5 MB  nvidia
#     cuda-opencl-12.3.101       |                0          11 KB  nvidia
#     cuda-opencl-dev-12.3.101   |                0          59 KB  nvidia
#     cuda-profiler-api-12.3.101 |                0          19 KB  nvidia
#     cuda-runtime-12.3.1        |                0           2 KB  nvidia
#     cuda-sanitizer-api-12.3.101|                0        17.1 MB  nvidia
#     cuda-toolkit-12.3.1        |                0           2 KB  nvidia
#     cuda-tools-12.3.1          |                0           2 KB  nvidia
#     cuda-visual-tools-12.3.1   |                0           2 KB  nvidia
#     gds-tools-1.8.1.2          |                0        40.8 MB  nvidia
#     libcublas-12.3.4.1         |                0       351.3 MB  nvidia
#     libcublas-dev-12.3.4.1     |                0          75 KB  nvidia
#     libcublas-static-12.3.4.1  |                0       389.5 MB  nvidia
#     libcufft-11.0.12.1         |                0        83.1 MB  nvidia
#     libcufft-dev-11.0.12.1     |                0          14 KB  nvidia
#     libcufft-static-11.0.12.1  |                0       167.5 MB  nvidia
#     libcufile-1.8.1.2          |                0         1.0 MB  nvidia
#     libcufile-dev-1.8.1.2      |                0          15 KB  nvidia
#     libcufile-static-1.8.1.2   |                0         3.6 MB  nvidia
#     libcurand-10.3.4.101       |                0        51.8 MB  nvidia
#     libcurand-dev-10.3.4.101   |                0         450 KB  nvidia
#     libcurand-static-10.3.4.101|                0        51.9 MB  nvidia
#     libcusolver-11.5.4.101     |                0       111.3 MB  nvidia
#     libcusolver-dev-11.5.4.101 |                0          50 KB  nvidia
#     libcusolver-static-11.5.4.101|                0        72.8 MB  nvidia
#     libcusparse-12.2.0.103     |                0       170.4 MB  nvidia
#     libcusparse-dev-12.2.0.103 |                0       170.2 MB  nvidia
#     libcusparse-static-12.2.0.103|                0       177.2 MB  nvidia
#     libnpp-12.2.3.2            |                0       144.7 MB  nvidia
#     libnpp-dev-12.2.3.2        |                0         538 KB  nvidia
#     libnpp-static-12.2.3.2     |                0       141.8 MB  nvidia
#     libnvjitlink-12.3.101      |                0        17.7 MB  nvidia
#     libnvjitlink-dev-12.3.101  |                0        14.7 MB  nvidia
#     libnvjpeg-12.3.0.81        |                0         3.0 MB  nvidia
#     libnvjpeg-dev-12.3.0.81    |                0          13 KB  nvidia
#     libnvjpeg-static-12.3.0.81 |                0         2.7 MB  nvidia
#     nsight-compute-2023.3.1.1  |                0       808.1 MB  nvidia
#     openssl-3.0.12             |       h7f8727e_0         5.2 MB
#     ------------------------------------------------------------
#                                            Total:        3.34 GB
#
# The following NEW packages will be INSTALLED:
#
#   cuda               nvidia/linux-64::cuda-12.3.1-0
#   cuda-cccl          nvidia/linux-64::cuda-cccl-12.3.101-0
#   cuda-command-line~ nvidia/linux-64::cuda-command-line-tools-12.3.1-0
#   cuda-compiler      nvidia/linux-64::cuda-compiler-12.3.1-0
#   cuda-cudart        nvidia/linux-64::cuda-cudart-12.3.101-0
#   cuda-cudart-dev    nvidia/linux-64::cuda-cudart-dev-12.3.101-0
#   cuda-cudart-static nvidia/linux-64::cuda-cudart-static-12.3.101-0
#   cuda-cuobjdump     nvidia/linux-64::cuda-cuobjdump-12.3.101-0
#   cuda-cupti         nvidia/linux-64::cuda-cupti-12.3.101-0
#   cuda-cupti-static  nvidia/linux-64::cuda-cupti-static-12.3.101-0
#   cuda-cuxxfilt      nvidia/linux-64::cuda-cuxxfilt-12.3.101-0
#   cuda-demo-suite    nvidia/linux-64::cuda-demo-suite-12.3.101-0
#   cuda-documentation nvidia/linux-64::cuda-documentation-12.3.101-0
#   cuda-driver-dev    nvidia/linux-64::cuda-driver-dev-12.3.101-0
#   cuda-gdb           nvidia/linux-64::cuda-gdb-12.3.101-0
#   cuda-libraries     nvidia/linux-64::cuda-libraries-12.3.1-0
#   cuda-libraries-dev nvidia/linux-64::cuda-libraries-dev-12.3.1-0
#   cuda-libraries-st~ nvidia/linux-64::cuda-libraries-static-12.3.1-0
#   cuda-nsight        nvidia/linux-64::cuda-nsight-12.3.101-0
#   cuda-nsight-compu~ nvidia/linux-64::cuda-nsight-compute-12.3.1-0
#   cuda-nvcc          nvidia/linux-64::cuda-nvcc-12.3.103-0
#   cuda-nvdisasm      nvidia/linux-64::cuda-nvdisasm-12.3.101-0
#   cuda-nvml-dev      nvidia/linux-64::cuda-nvml-dev-12.3.101-0
#   cuda-nvprof        nvidia/linux-64::cuda-nvprof-12.3.101-0
#   cuda-nvprune       nvidia/linux-64::cuda-nvprune-12.3.101-0
#   cuda-nvrtc         nvidia/linux-64::cuda-nvrtc-12.3.103-0
#   cuda-nvrtc-dev     nvidia/linux-64::cuda-nvrtc-dev-12.3.103-0
#   cuda-nvrtc-static  nvidia/linux-64::cuda-nvrtc-static-12.3.103-0
#   cuda-nvtx          nvidia/linux-64::cuda-nvtx-12.3.101-0
#   cuda-nvvp          nvidia/linux-64::cuda-nvvp-12.3.101-0
#   cuda-opencl        nvidia/linux-64::cuda-opencl-12.3.101-0
#   cuda-opencl-dev    nvidia/linux-64::cuda-opencl-dev-12.3.101-0
#   cuda-profiler-api  nvidia/linux-64::cuda-profiler-api-12.3.101-0
#   cuda-runtime       nvidia/linux-64::cuda-runtime-12.3.1-0
#   cuda-sanitizer-api nvidia/linux-64::cuda-sanitizer-api-12.3.101-0
#   cuda-toolkit       nvidia/linux-64::cuda-toolkit-12.3.1-0
#   cuda-tools         nvidia/linux-64::cuda-tools-12.3.1-0
#   cuda-visual-tools  nvidia/linux-64::cuda-visual-tools-12.3.1-0
#   gds-tools          nvidia/linux-64::gds-tools-1.8.1.2-0
#   libcublas          nvidia/linux-64::libcublas-12.3.4.1-0
#   libcublas-dev      nvidia/linux-64::libcublas-dev-12.3.4.1-0
#   libcublas-static   nvidia/linux-64::libcublas-static-12.3.4.1-0
#   libcufft           nvidia/linux-64::libcufft-11.0.12.1-0
#   libcufft-dev       nvidia/linux-64::libcufft-dev-11.0.12.1-0
#   libcufft-static    nvidia/linux-64::libcufft-static-11.0.12.1-0
#   libcufile          nvidia/linux-64::libcufile-1.8.1.2-0
#   libcufile-dev      nvidia/linux-64::libcufile-dev-1.8.1.2-0
#   libcufile-static   nvidia/linux-64::libcufile-static-1.8.1.2-0
#   libcurand          nvidia/linux-64::libcurand-10.3.4.101-0
#   libcurand-dev      nvidia/linux-64::libcurand-dev-10.3.4.101-0
#   libcurand-static   nvidia/linux-64::libcurand-static-10.3.4.101-0
#   libcusolver        nvidia/linux-64::libcusolver-11.5.4.101-0
#   libcusolver-dev    nvidia/linux-64::libcusolver-dev-11.5.4.101-0
#   libcusolver-static nvidia/linux-64::libcusolver-static-11.5.4.101-0
#   libcusparse        nvidia/linux-64::libcusparse-12.2.0.103-0
#   libcusparse-dev    nvidia/linux-64::libcusparse-dev-12.2.0.103-0
#   libcusparse-static nvidia/linux-64::libcusparse-static-12.2.0.103-0
#   libnpp             nvidia/linux-64::libnpp-12.2.3.2-0
#   libnpp-dev         nvidia/linux-64::libnpp-dev-12.2.3.2-0
#   libnpp-static      nvidia/linux-64::libnpp-static-12.2.3.2-0
#   libnvjitlink       nvidia/linux-64::libnvjitlink-12.3.101-0
#   libnvjitlink-dev   nvidia/linux-64::libnvjitlink-dev-12.3.101-0
#   libnvjpeg          nvidia/linux-64::libnvjpeg-12.3.0.81-0
#   libnvjpeg-dev      nvidia/linux-64::libnvjpeg-dev-12.3.0.81-0
#   libnvjpeg-static   nvidia/linux-64::libnvjpeg-static-12.3.0.81-0
#   nsight-compute     nvidia/linux-64::nsight-compute-2023.3.1.1-0
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2023.05.30-h06a4308_0 --> 2023.08.22-h06a4308_0
#   certifi                           2023.5.7-py38h06a4308_0 --> 2023.11.17-py38h06a4308_0
#   openssl                                  3.0.8-h7f8727e_0 --> 3.0.12-h7f8727e_0
#
#
#
# Downloading and Extracting Packages
# cuda-sanitizer-api-1 | 17.1 MB   |                                       |   0%
# cuda-libraries-12.3. | 2 KB      |                                       |   0%
#
# cuda-runtime-12.3.1  | 2 KB      |                                       |   0%
#
#
# cuda-visual-tools-12 | 2 KB      |                                       |   0%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  |                                       |   0%
#
#
#
#
# libcurand-static-10. | 51.9 MB   |                                       |   0%
#
#
#
#
#
# libnvjpeg-12.3.0.81  | 3.0 MB    |                                       |   0%
#
#
#
#
#
#
# cuda-12.3.1          | 2 KB      |                                       |   0%
#
#
#
#
#
#
#
# cuda-libraries-stati | 2 KB      |                                       |   0%
#
#
#
#
#
#
#
#
# cuda-cupti-12.3.101  | 15.3 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
# cuda-opencl-dev-12.3 | 59 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# libcusolver-dev-11.5 | 50 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.4.101 | 51.8 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-tools-12.3.1    | 2 KB      |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.4 | 450 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-static-12 | 18.5 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-dev-12. | 14.7 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvprof-12.3.101 | 4.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-cudart-static-1 | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2023.11.17   | 158 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufile-static-1.8 | 3.6 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   |                                       |   0%
#  ... (more hidden) ...
#
#
# cuda-visual-tools-12 | 2 KB      | ##################################### | 100%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  |                                       |   0%
#
#
# cuda-visual-tools-12 | 2 KB      | ##################################### | 100%
#
# cuda-runtime-12.3.1  | 2 KB      | ##################################### | 100%
#
# cuda-sanitizer-api-1 | 17.1 MB   |                                       |   0%
# cuda-libraries-12.3. | 2 KB      | ##################################### | 100%
# cuda-libraries-12.3. | 2 KB      | ##################################### | 100%
#
#
#
#
# libcurand-static-10. | 51.9 MB   |                                       |   0%
#
#
#
#
#
# libnvjpeg-12.3.0.81  | 3.0 MB    | 1                                     |   1%
#
#
#
#
#
#
# cuda-12.3.1          | 2 KB      | ##################################### | 100%
#
#
#
#
#
#
# cuda-12.3.1          | 2 KB      | ##################################### | 100%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | #8                                    |   5%
#
#
#
#
#
#
#
# cuda-sanitizer-api-1 | 17.1 MB   | ########7                             |  24%
#
#
#
#
#
#
#
# cuda-libraries-stati | 2 KB      | ##################################### | 100%
#
#
#
#
# libcurand-static-10. | 51.9 MB   | ##5                                   |   7%
#
#
#
#
#
#
#
#
# cuda-cupti-12.3.101  | 15.3 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
# cuda-opencl-dev-12.3 | 59 KB     | ##########1                           |  27%
#
#
#
# cuda-sanitizer-api-1 | 17.1 MB   | #################7                    |  48%
#
#
#
#
#
#
#
#
#
#
# libcusolver-dev-11.5 | 50 KB     | ###########9                          |  32%
#
#
#
#
#
#
#
#
#
# cuda-opencl-dev-12.3 | 59 KB     | ##################################### | 100%
#
#
#
#
# libcurand-static-10. | 51.9 MB   | #####3                                |  15%
#
#
#
#
#
#
#
#
# cuda-cupti-12.3.101  | 15.3 MB   | ######4                               |  17%
#
#
#
#
#
#
#
#
#
#
# libcusolver-dev-11.5 | 50 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# cuda-sanitizer-api-1 | 17.1 MB   | ########################7             |  67%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | ####3                                 |  12%
#
#
#
#
# libcurand-static-10. | 51.9 MB   | #######5                              |  20%
#
#
#
#
#
#
#
#
# cuda-cupti-12.3.101  | 15.3 MB   | #############5                        |  37%
#
#
#
#
#
#
#
#
#
#
#
# cuda-sanitizer-api-1 | 17.1 MB   | ################################      |  87%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | #####5                                |  15%
#
#
#
#
# libcurand-static-10. | 51.9 MB   | ##########                            |  27%
#
#
#
#
#
#
#
#
# cuda-cupti-12.3.101  | 15.3 MB   | ######################2               |  60%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | #7                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.4.101 | 51.8 MB   |                                       |   0%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | ######6                               |  18%
#
#
#
#
# libcurand-static-10. | 51.9 MB   | ############4                         |  34%
#
#
#
#
#
#
#
#
# cuda-cupti-12.3.101  | 15.3 MB   | ##############################2       |  82%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ##6                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.4.101 | 51.8 MB   | ##5                                   |   7%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | #######8                              |  21%
#
#
#
#
# libcurand-static-10. | 51.9 MB   | ##############8                       |  40%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ###5                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-tools-12.3.1    | 2 KB      | ##################################### | 100%
#
#
#
#
#
# libnvjpeg-12.3.0.81  | 3.0 MB    | ##################################### | 100%
#
#
#
#
#
# libnvjpeg-12.3.0.81  | 3.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.4.101 | 51.8 MB   | ####6                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.4 | 450 KB    | #3                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-tools-12.3.1    | 2 KB      | ##################################### | 100%
#
#
#
#
# libcurand-static-10. | 51.9 MB   | #################1                    |  46%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | ########9                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-static-12 | 18.5 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ####3                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.4.101 | 51.8 MB   | ######7                               |  18%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | #########9                            |  27%
#
#
#
#
# libcurand-static-10. | 51.9 MB   | ###################3                  |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-static-12 | 18.5 MB   | #####7                                |  16%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | #####1                                |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.4 | 450 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-dev-10.3.4 | 450 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.4.101 | 51.8 MB   | #########                             |  25%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | ###########                           |  30%
#
#
#
#
# libcurand-static-10. | 51.9 MB   | #####################6                |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-static-12 | 18.5 MB   | ###########9                          |  32%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ######                                |  16%
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.4.101 | 51.8 MB   | ###########6                          |  32%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | ############2                         |  33%
#
#
#
#
# libcurand-static-10. | 51.9 MB   | ########################2             |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-static-12 | 18.5 MB   | ##################6                   |  51%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | #######                               |  19%
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.4.101 | 51.8 MB   | ##############3                       |  39%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | #############4                        |  36%
#
#
#
#
# libcurand-static-10. | 51.9 MB   | ##########################8           |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-static-12 | 18.5 MB   | #########################2            |  68%
# libnpp-static-12.2.3 | 141.8 MB  | ########                              |  22%
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.4.101 | 51.8 MB   | ################7                     |  45%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | ##############5                       |  39%
#
#
#
#
# libcurand-static-10. | 51.9 MB   | #############################4        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-static-12 | 18.5 MB   | ###############################8      |  86%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ########9                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.4.101 | 51.8 MB   | ###################1                  |  52%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | ###############6                      |  42%
#
#
#
#
# libcurand-static-10. | 51.9 MB   | ###############################8      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-dev-12. | 14.7 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | #########7                            |  26%
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.4.101 | 51.8 MB   | #####################5                |  58%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | ################7                     |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-dev-12. | 14.7 MB   | ######5                               |  18%
#
#
#
#
# libcurand-static-10. | 51.9 MB   | ##################################1   |  92%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ##########6                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.4.101 | 51.8 MB   | #######################7              |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-dev-12. | 14.7 MB   | #############8                        |  37%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | #################7                    |  48%
#
#
#
#
# libcurand-static-10. | 51.9 MB   | ####################################3 |  98%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ###########4                          |  31%
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.4.101 | 51.8 MB   | #########################9            |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvprof-12.3.101 | 4.8 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-dev-12. | 14.7 MB   | #####################1                |  57%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | ##################7                   |  51%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ############1                         |  33%
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.4.101 | 51.8 MB   | ############################          |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvprof-12.3.101 | 4.8 MB    | ######################4               |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-dev-12. | 14.7 MB   | ############################6         |  77%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | ###################7                  |  53%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ############9                         |  35%
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.4.101 | 51.8 MB   | ##############################1       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-cudart-static-1 | 1.1 MB    | 5                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-dev-12. | 14.7 MB   | ####################################3 |  98%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | ####################8                 |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufile-static-1.8 | 3.6 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | #############8                        |  37%
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.4.101 | 51.8 MB   | ################################7     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2023.11.17   | 158 KB    | ###7                                  |  10%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | #####################9                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufile-static-1.8 | 3.6 MB    | ################################9     |  89%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ##############7                       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.4.101 | 51.8 MB   | ###################################1  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | #######################               |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   | #5                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ###############5                      |  42%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | ########################1             |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   | ###                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ################3                     |  44%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | #########################2            |  68%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   | ####4                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | #################2                    |  47%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | ##########################3           |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   | #####8                                |  16%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ##################                    |  49%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | ###########################3          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   | #######2                              |  20%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ##################9                   |  51%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | ############################4         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   | ########6                             |  24%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ###################7                  |  53%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | #############################4        |  80%
# libcufft-11.0.12.1   | 83.1 MB   | ##########                            |  27%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ####################5                 |  56%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | ##############################4       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   | ###########4                          |  31%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | #####################4                |  58%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | ###############################4      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   | ############8                         |  35%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ######################2               |  60%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | ################################4     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   | ##############2                       |  39%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | #######################               |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   | ###############6                      |  42%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | #################################4    |  91%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | #######################8              |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   | ################9                     |  46%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | ##################################4   |  93%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ########################6             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   | ##################3                   |  49%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | ###################################3  |  96%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | #########################3            |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   | ###################6                  |  53%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | ####################################3 |  98%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ##########################1           |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   | #####################                 |  57%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ###########################           |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   | ######################4               |  61%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ###########################8          |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   | #######################7              |  64%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ############################6         |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   | #########################1            |  68%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | #############################4        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-sanitizer-api-1 | 17.1 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ##############################2       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   | ###########################7          |  75%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ###############################       |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   | #############################1        |  79%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ###############################8      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   | ##############################5       |  82%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ################################6     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   | ###############################8      |  86%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | #################################3    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   | #################################1    |  90%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ##################################1   |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   | ##################################5   |  93%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ##################################9   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   | ###################################8  |  97%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ###################################6  |  96%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ####################################4 |  99%
#
#
#
#
#
#
#
#
# cuda-cupti-12.3.101  | 15.3 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvprof-12.3.101 | 4.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvprof-12.3.101 | 4.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-static-12 | 18.5 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-cudart-static-1 | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-cudart-static-1 | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2023.11.17   | 158 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2023.11.17   | 158 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufile-static-1.8 | 3.6 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libnvjitlink-dev-12. | 14.7 MB   | ##################################### | 100%
#
#
#
#
# libcurand-static-10. | 51.9 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.4.101 | 51.8 MB   | ##################################### | 100%
#
#
#
# cuda-nvvp-12.3.101   | 114.5 MB  | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-11.0.12.1   | 83.1 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libnpp-static-12.2.3 | 141.8 MB  | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Fri_Nov__3_17:16:49_PDT_2023
# Cuda compilation tools, release 12.3, V12.3.103
# Build cuda_12.3.r12.3/compiler.33492891_0

# %%
# !pip install deepspeed
# Out:
# Collecting deepspeed
#   Downloading https://files.pythonhosted.org/packages/b8/a2/201f57d766b23af6b66769d7dc633816ca766f79ba37e0e4a325eca763b0/deepspeed-0.12.4.tar.gz (1.2MB)
#      |████████████████████████████████| 1.2MB 7.1MB/s eta 0:00:01
# Collecting hjson
#   Downloading https://files.pythonhosted.org/packages/1f/7f/13cd798d180af4bf4c0ceddeefba2b864a63c71645abc0308b768d67bb81/hjson-3.1.0-py3-none-any.whl (54kB)
#      |████████████████████████████████| 61kB 26.4MB/s eta 0:00:01
# Collecting ninja
#   Downloading https://files.pythonhosted.org/packages/6d/92/8d7aebd4430ab5ff65df2bfee6d5745f95c004284db2d8ca76dcbfd9de47/ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307kB)
#      |████████████████████████████████| 307kB 38.7MB/s eta 0:00:01
# Collecting numpy
#   Downloading https://files.pythonhosted.org/packages/98/5d/5738903efe0ecb73e51eb44feafba32bdba2081263d40c5043568ff60faf/numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3MB)
#      |████████████████████████████████| 17.3MB 43.9MB/s eta 0:00:01
# Collecting packaging>=20.0
#   Downloading https://files.pythonhosted.org/packages/ec/1a/610693ac4ee14fcdf2d9bf3c493370e4f2ef7ae2e19217d7a237ff42367d/packaging-23.2-py3-none-any.whl (53kB)
#      |████████████████████████████████| 61kB 32.8MB/s eta 0:00:01
# Collecting psutil
#   Downloading https://files.pythonhosted.org/packages/19/06/4e3fa3c1b79271e933c5ddbad3a48aa2c3d5f592a0fb7c037f3e0f619f4d/psutil-5.9.6-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (283kB)
#      |████████████████████████████████| 286kB 99.5MB/s eta 0:00:01
# Collecting py-cpuinfo
#   Downloading https://files.pythonhosted.org/packages/e0/a9/023730ba63db1e494a271cb018dcd361bd2c917ba7004c3e49d5daf795a2/py_cpuinfo-9.0.0-py3-none-any.whl
# Collecting pydantic
#   Downloading https://files.pythonhosted.org/packages/0a/2b/64066de1c4cf3d4ed623beeb3bbf3f8d0cc26661f1e7d180ec5eb66b75a5/pydantic-2.5.2-py3-none-any.whl (381kB)
#      |████████████████████████████████| 389kB 98.4MB/s eta 0:00:01
# Collecting pynvml
#   Downloading https://files.pythonhosted.org/packages/5b/9c/adb8070059caaa15d5a572b66bccd95900d8c1b9fa54d6ecea6ae97448d1/pynvml-11.5.0-py3-none-any.whl (53kB)
#      |████████████████████████████████| 61kB 34.4MB/s eta 0:00:01
# Collecting torch
#   Downloading https://files.pythonhosted.org/packages/9b/d9/8508dcdf4b7d81bf48d6f8cc0db4fd979ee1204de62ddb93b36f6b8577ea/torch-2.1.1-cp38-cp38-manylinux1_x86_64.whl (670.2MB)
#      |███████████████                 | 315.0MB 139.6MB/s eta 0:00:03     |█████                           | 104.2MB 105.5MB/s eta 0:00:06
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#      |███████████████████████▍        | 490.8MB 129.8MB/s eta 0:00:02
#      |███████████████████████▊        | 497.8MB 129.8MB/s eta 0:00:02
#      |████████████████████████        | 504.7MB 129.8MB/s eta 0:00:02
#      |████████████████████████▍       | 511.7MB 129.8MB/s eta 0:00:02
#      |████████████████████████▊       | 518.8MB 129.8MB/s eta 0:00:02
#      |█████████████████████████       | 525.8MB 129.8MB/s eta 0:00:02
#      |█████████████████████████▍      | 532.8MB 129.8MB/s eta 0:00:02
#      |█████████████████████████▉      | 539.9MB 129.8MB/s eta 0:00:02
#      |██████████████████████████▏     | 546.9MB 129.8MB/s eta 0:00:01
#      |██████████████████████████▌     | 554.0MB 141.0MB/s eta 0:00:01
#      |██████████████████████████▉     | 561.0MB 141.0MB/s eta 0:00:01
#      |███████████████████████████▏    | 568.1MB 141.0MB/s eta 0:00:01
#      |███████████████████████████▌    | 575.2MB 141.0MB/s eta 0:00:01
#      |███████████████████████████▉    | 582.2MB 141.0MB/s eta 0:00:01
#      |████████████████████████████▏   | 589.1MB 141.0MB/s eta 0:00:01
#      |████████████████████████████▌   | 596.2MB 141.0MB/s eta 0:00:01
#      |████████████████████████████▉   | 603.2MB 141.0MB/s eta 0:00:01
#      |█████████████████████████████▏  | 610.3MB 141.0MB/s eta 0:00:01
#      |█████████████████████████████▌  | 617.3MB 141.0MB/s eta 0:00:01
#      |█████████████████████████████▉  | 624.4MB 141.0MB/s eta 0:00:01
#      |██████████████████████████████▏ | 631.4MB 141.0MB/s eta 0:00:01
#      |██████████████████████████████▌ | 638.4MB 141.0MB/s eta 0:00:01
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#      |████████████████████████████████| 670.2MB 141kB/s

# %%
import os
import torch
from datasets import load_dataset
from datasets import Dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    TrainingArguments,
    pipeline,
    logging,
)
# from peft import LoraConfig, PeftModel
# from trl import SFTTrainer
import pandas as pd
import torch

# %%
model_name = "/data/mistral/query-to-mql/exp-10/nov-20/merged-model"

# %%
# Load base model
model = AutoModelForCausalLM.from_pretrained(model_name,torch_dtype=torch.bfloat16,device_map="auto")
model.config.use_cache = False
model.config.pretraining_tp = 1

# %%
# Load LLaMA tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True,
                                          # add_eos_token=True,
                                          use_fast=False)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

# %%
query_template_v1 = """Given the context : {context} and date reference: {date_input}, the query: {user_query}, is converted into below shown structured output.
[MQL]
"""

# %%
def predict_template_query_v1(user_query):
    inp = query_template_v1.format(context=context,
                                   user_query=user_query,
                                  date_input=date_input)
    _inputs = tokenizer.encode(inp, return_tensors="pt")
    outputs = model.generate(input_ids=_inputs, max_length= 1200, pad_token_id=tokenizer.eos_token_id)
    output = tokenizer.decode(outputs[0])
    output_new = output.split('[MQL]\n')[1]
    return output_new.split('\n[/MQL]')[0], output

# %%
import time
start = time.time()
user_query = 'what is purchase across segments'
print('user query: ', user_query)
print('-'*100)
output, raw = predict_template_query_v1(user_query=user_query)
print("time taken : ", time.time()-start)
print(eval(output))

# %%
context = """{
    "MEASURE": [{"ENTITY": "Discount", "other names": ["discount", "discount rate", "discount value", "deduction"]},
                {"ENTITY": "Purchase Vol", "other names": ["purchase", "purchase value", "purchase model"]},
                {"ENTITY": "Quantity", "other names": ["quantity", "volume"]},
                {"ENTITY": "Sales", "other names": ["sales", "sale"]}],
    "DIMENSION": [{"ENTITY": "Sub-Category", "other names": ["sub-category", "sub category", "categories", "section"]},
                  {"ENTITY": "Segment", "other names": ["segment", "segments", "units", "divisions"]},
                  {"ENTITY": "Parts", "other names": ["parts", "part", "section", "divisions"]},
                  {"ENTITY": "Country", "other names": ["country", "countries"]}],
    "FILTER": [{"ENTITY": "Consumer", "other names": ["consumers", "consumer"], "parent": "Segment"},
               {"ENTITY": "Phone", "other names": ["phone", "phones", "mobile phones"], "parent": "Sub-Category"},
               {"ENTITY": "Binder", "other names": ["binders", "binder"], "parent": "Sub-Category"},
               {"ENTITY": "Corporate", "other names": ["corporates", "corporate"], "parent": "Segment"},
               {"ENTITY": "India", "other names": ["india"], "parent": "Country"},
               {"ENTITY": "Dubai", "other names": ["dubai"], "parent": "Country"}],
    "DERIVED MEASURE": [{"ENTITY": "Ratio",
             "other names": ["ratio", "share", "contribution", "percentage", "proportion", "contributing"]},
            {"ENTITY": "Why", "other names": ["why", "cause of", "reason for", "diagnose"]},
            {"ENTITY": "contribution_to_growth", "other names": ["contribution to growth", "growth", "grown"]},
            {"ENTITY": "kda_transactional", "other names": ["kda", "key drivers", "key driver", "drivers", "driver"]},
            {"ENTITY": "Growth Rate", "other names": ["growth rate", "growth", "grown"]},
            {"ENTITY": "correlation",
             "other names": ["associate", "associated", "association", "associations", "correlate", "correlated",
                             "correlation", "correlations", "relate", "related", "relation", "relations",
                             "relationship",
                             "relationships"]}
            ],
    "DATE VARIABLE": [{"ENTITY": "Order Date", "other names": ["order date", "date", "trend", "time", "when", "mom", "yoy"]}]
    }"""

date_input = {
    "start_date": "01/01/2020",
    "end_date": "15/09/2023"
}
